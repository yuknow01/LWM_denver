# %% [markdown]
# ## dataset denver download if you download than pass

# %%
# !pip install deepmimo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: deepmimo in /home/dlghdbs200/.local/lib/python3.10/site-packages (4.0.0b10)
# Requirement already satisfied: scipy>=1.6.2 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from deepmimo) (1.15.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from deepmimo) (2.32.4)
# Requirement already satisfied: tqdm>=4.59.0 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from deepmimo) (4.67.1)
# Requirement already satisfied: matplotlib>=3.8.2 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from deepmimo) (3.10.3)
# Requirement already satisfied: numpy<2.3,>=1.19.5 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from deepmimo) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.2->deepmimo) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.8.2->deepmimo) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from matplotlib>=3.8.2->deepmimo) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from matplotlib>=3.8.2->deepmimo) (1.3.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from matplotlib>=3.8.2->deepmimo) (1.4.8)
# Requirement already satisfied: fonttools>=4.22.0 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from matplotlib>=3.8.2->deepmimo) (4.58.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.2->deepmimo) (2.9.0.post0)
# Requirement already satisfied: pillow>=8 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from matplotlib>=3.8.2->deepmimo) (11.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->deepmimo) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->deepmimo) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->deepmimo) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->deepmimo) (2020.6.20)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8.2->deepmimo) (1.16.0)

# %%
import deepmimo as dm

# Search for scenarios matching criteria
scenarios = dm.search()

# %%
import deepmimo as dm

# Download a specific scenario
dm.download('city_18_denver_28')
# Out:
# Scenario "city_18_denver_28" already exists in /home/dlghdbs200/LWM_denver/deepmimo_scenarios

# %%
from .summary import summary, plot_summary
print(summary.__file__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 from .summary import summary, plot_summary
#       2 print(summary.__file__)
#
# ImportError: attempted relative import with no known parent package

# %% [markdown]
# # library

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import TensorDataset, DataLoader, random_split
import DeepMIMOv3
import numpy as np
from pprint import pprint

import matplotlib.pyplot as plt
import time
import math
import torch
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import IterableDataset
import numpy as np
import time, gc
from tqdm import tqdm
import numpy as np
import torch
import random
import torch.nn as nn
from lwm_model import lwm
from torch.optim import Adam
from pathlib import Path
import torch, time

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # dataset load

# %%
import deepmimo as dm

# Load dataset
dataset = dm.load("city_18_denver_28")

# Access dataset properties
aoa_az = dataset.aoa_az
aoa_el = dataset.aoa_el
inter_pos = dataset.inter_pos

# Compute specific channel information
# los = dataset.compute_los()
channels = dataset.compute_channels()
pl = dataset.compute_pathloss()
# Out:
# Loading TXRX PAIR: TXset 1 (tx_idx 0) & RXset 0 (rx_idxs 43248)
# Loading TXRX PAIR: TXset 2 (tx_idx 0) & RXset 0 (rx_idxs 43248)
# Loading TXRX PAIR: TXset 3 (tx_idx 0) & RXset 0 (rx_idxs 43248)
# Generating channels: 100%|█████████████████████████████████████████████████████| 43248/43248 [00:01<00:00, 23229.70it/s]
# Generating channels: 100%|█████████████████████████████████████████████████████| 43248/43248 [00:02<00:00, 21164.58it/s]
# Generating channels: 100%|█████████████████████████████████████████████████████| 43248/43248 [00:01<00:00, 24018.50it/s]

# %% [markdown]
# # Datashape
# deepmimo/generator/dataset.py def compute_channels in here channel data shape
#
#             numpy.ndarray: MIMO channel matrix with shape [n_users, n_rx_ant, n_tx_ant, n_subcarriers]
#                           if freq_domain=True, otherwise [n_users, n_rx_ant, n_tx_ant, n_paths]

# %% [markdown]
# # three TxSet(1,2,3)
# “For 43,248 users, 1 user antenna, 8 BS antennas, and 1 propagation path.”
# (users, user antenna, BS antennas, PL)

# %%
channels[1].shape
# Out:
# (43248, 1, 8, 1)

# %%
channels[0]
# Out:
# array([[[[-4.0636469e-10-2.4687419e-10j],
#          [ 4.0486328e-10+2.4921543e-10j],
#          [-4.0334483e-10-2.5152960e-10j],
#          ...,
#          [ 3.9869291e-10+2.5830790e-10j],
#          [-3.9711204e-10-2.6051203e-10j],
#          [ 3.9551701e-10+2.6268823e-10j]]],
#
#
#        [[[ 1.5214810e-10-7.0644335e-10j],
#          [-1.5652508e-10+7.0226053e-10j],
#          [ 1.6082487e-10-6.9803024e-10j],
#          ...,
#          [-1.7325429e-10+6.8506756e-10j],
#          [ 1.7723865e-10-6.8066053e-10j],
#          [-1.8114261e-10+6.7621270e-10j]]],
#
#
#        [[[ 7.6910278e-10+1.6763185e-11j],
#          [-7.6921619e-10-1.8937532e-11j],
#          [ 7.6933526e-10+2.1130594e-11j],
#          ...,
#          [-7.6972168e-10-2.7824850e-11j],
#          [ 7.6985857e-10+3.0095502e-11j],
#          [-7.6999856e-10-3.2386184e-11j]]],
#
#
#        ...,
#
#
#        [[[ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          ...,
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j]]],
#
#
#        [[[ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          ...,
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j]]],
#
#
#        [[[ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          ...,
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j]]]],
#       shape=(43248, 1, 8, 1), dtype=complex64)

# %%
len(channels[0][0][0])
# Out:
# 8

# %%
channels[1][2][0][3]
# Out:
# array([1.3398023e-09-1.4365638e-09j], dtype=complex64)

# %% [markdown]
# # data preprocessing

# %% [markdown]
# ## How to predict
# Autoencoder version: Reconstructs the entire channel response using identical input and output (global reconstruction).<br>
# H1,H2,H3 -> all data union

# %%
H1, H2, H3 = channels[0], channels[1], channels[2]
X = np.concatenate([H1,H2,H3], axis = 0)
y = X.copy()


# separate real/imaginary
X = np.stack([X.real, X.imag], axis=-1).astype(np.float32) # (N,1,8,1,2) add dimension to the back
y = np.stack([y.real, y.imag], axis=-1)

# 1) Numpy -> Tensor (+ float32) & (optional) per-sample normalization
X_t = torch.from_numpy(X).float()
y_t = torch.from_numpy(y).float()

eps = 1e-8
# L2 norm => normalization
scale = torch.linalg.vector_norm(X_t.view(X_t.size(0), -1), dim=1, keepdim=True).clamp_min(eps)
X_t = X_t / scale.view(-1,1,1,1,1)
y_t = y_t / scale.view(-1,1,1,1,1)

# 2) Split only by users (inputs=H1,H2; label=H3)
dataset = TensorDataset(X_t, y_t)
N = len(dataset)
n_tr = int(N*0.75)         # e.g., 75% train, 25% val
n_val = N - n_tr

# random seed 42 fixed
train_set, val_set = random_split(dataset, [n_tr, n_val], generator=torch.Generator().manual_seed(42))
train_loader = DataLoader(train_set, batch_size=1024, shuffle=True)
val_loader   = DataLoader(val_set,   batch_size=2048, shuffle=False)

print(f"Train samples: {len(train_set)}, Val samples: {len(val_set)}")
# Out:
# Train samples: 97308, Val samples: 32436

# %%
X.shape
# Out:
# (129744, 1, 8, 1, 2)

# %%
y.shape
# Out:
# (129744, 1, 8, 1, 2)

# %%
val_set[12000]
# Out:
# (tensor([[[[-0.3372,  0.0823]],
#
#           [[ 0.3120,  0.0524]],
#
#           [[-0.3008, -0.1282]],
#
#           [[ 0.2441,  0.2517]],
#
#           [[-0.1549, -0.2929]],
#
#           [[ 0.0792,  0.3708]],
#
#           [[ 0.0843, -0.3778]],
#
#           [[-0.1843,  0.3351]]]]),
#  tensor([[[[-0.3372,  0.0823]],
#
#           [[ 0.3120,  0.0524]],
#
#           [[-0.3008, -0.1282]],
#
#           [[ 0.2441,  0.2517]],
#
#           [[-0.1549, -0.2929]],
#
#           [[ 0.0792,  0.3708]],
#
#           [[ 0.0843, -0.3778]],
#
#           [[-0.1843,  0.3351]]]]))

# %%
x_single.shape
# Out:
# torch.Size([1, 1, 8, 1, 2])

# %% [markdown]
# # Model define

# %%
# ============================================================
# 3) Models (same interface as your run())  [D=2 version]
# ============================================================

class MLP(nn.Module):
    def __init__(self, hidden=256, depth=3, pdrop=0.1):
        super().__init__()
        layers, d = [], 16   # (8 antennas × 2 channels)
        for _ in range(depth - 1):
            layers += [nn.Linear(d, hidden), nn.ReLU(), nn.Dropout(pdrop)]
            d = hidden
        layers += [nn.Linear(d, 16)]  # output: (8×2)
        self.net = nn.Sequential(*layers)

    def forward(self, x):  # x: (B, 1, 8, 1, 2)
        x = x.view(x.size(0), -1)   # (B, 16)
        y = self.net(x)             # (B, 16)
        return y.view(-1, 1, 8, 1, 2)  # (B, 1, 8, 1, 2)


class CNN1D(nn.Module):
    def __init__(self):
        super().__init__()
        self.feat = nn.Sequential(
            nn.Conv1d(2, 32, 3, padding=1), nn.ReLU(),   # in_channels=2 (real+imag)
            nn.Conv1d(32, 64, 3, padding=1), nn.ReLU(),
            nn.Conv1d(64, 64, 3, padding=1), nn.ReLU(),
        )
        self.head = nn.Sequential(
            nn.AdaptiveAvgPool1d(1),  # (B,64,8) -> (B,64,1)
            nn.Flatten(),             # (B,64)
            nn.Linear(64, 64), nn.ReLU(),
            nn.Linear(64, 16)         # output: (8×2)
        )

    def forward(self, x):  # x: (B, 1, 8, 1, 2)
        x = x.squeeze(1).squeeze(-2).permute(0, 2, 1)  # (B, 2, 8)
        h = self.feat(x)                               # (B, 64, 8)
        y = self.head(h)                               # (B, 16)
        return y.view(-1, 1, 8, 1, 2)                  # (B, 1, 8, 1, 2)

# %%
class LWM_denver(nn.Module):
    def __init__(self, d_model=64, n_layers=12, max_len=129):
        super().__init__()
        # The actual LWM model (Transformer) will be built later (lazy initialization)
        self.core = None

        # Store configuration values for later use
        # These will be used when building the LWM model dynamically
        self.config = {
            "d_model": d_model,
            "n_layers": n_layers,
            "max_len": max_len
        }

    def build_core(self, L, D, device):
        """
        Build the actual LWM model ("core") dynamically when the first input is received.
        - L: sequence length (usually equal to the number of Tx antennas)
        - D: feature dimension per token (e.g., 2 for real/imag)
        - device: which device (CPU/GPU) to place the model on
        """
        self.core = lwm(
            element_length=D,                   # Input feature dimension (D=2)
            d_model=self.config["d_model"],     # Hidden size of the Transformer
            max_len=self.config["max_len"],     # Maximum positional embedding length
            n_layers=self.config["n_layers"]    # Number of encoder layers
        ).to(device)

    def forward(self, x):
        """
        Forward pass for the model.

        Input tensor x shape:
            [B, n_rx_ant, n_tx_ant, n_paths, D]
        Example: [batch_size, 1, 8, 1, 2]

        Steps:
        1. Extract B, L (number of Tx antennas), D (feature dimension)
        2. Convert 5D input -> 3D sequence [B, L, D]
        3. Build the core model if not already created
        4. Feed the input into LWM (self.core)
        5. Reconstruct back to 5D output shape [B, 1, L, 1, D]
        """

        B, _, L, _, D = x.shape  # (B,1,8,1,2)
        x_seq = x.squeeze(1).squeeze(-2).float()  # -> (B, L, D)

        # Build the core model only once (lazy initialization)
        if self.core is None:
            self.build_core(L, D, x.device)

        # Generate mask positions for full-sequence prediction
        masked_pos = torch.arange(L, device=x.device).unsqueeze(0).repeat(B, 1)  # [B, L]

        # Forward pass through the LWM model
        y_hat, _ = self.core(x_seq, masked_pos)  # Output: [B, L, D]

        # Reshape back to 5D for consistency with MLP/CNN outputs
        return y_hat.unsqueeze(1).unsqueeze(-2)  # [B, 1, L, 1, D]

# %% [markdown]
# # Evaluate

# %%
def train_one_epoch(model, dataloader, criterion, optimizer):
    model.train()
    total_loss = 0.0
    for x, y in dataloader:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        pred = model(x)
        loss = criterion(pred, y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * x.size(0)
    return total_loss / len(dataloader.dataset)


def evaluate(model, dataloader, criterion):
    model.eval()
    total_loss, total_mse, total_nmse = 0.0, 0.0, 0.0
    with torch.no_grad():
        for x, y in dataloader:
            x, y = x.to(device), y.to(device)
            pred = model(x)
            loss = criterion(pred, y)
            mse = torch.mean((pred - y) ** 2).item()
            nmse = mse / torch.mean(y ** 2).item()
            total_loss += loss.item() * x.size(0)
            total_mse += mse * x.size(0)
            total_nmse += nmse * x.size(0)

    avg_loss = total_loss / len(dataloader.dataset)
    avg_rmse = (total_mse / len(dataloader.dataset)) ** 0.5
    avg_nmse = total_nmse / len(dataloader.dataset)
    avg_nmse_db = 10 * np.log10(avg_nmse + 1e-12)
    return avg_loss, avg_rmse, avg_nmse, avg_nmse_db

# %%
def run(model, epochs=150, lr=1e-3, weight_decay=0.0, show_every=1):
    model = model.to(device)
    criterion = nn.MSELoss(reduction="mean")
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

    best_loss = float("inf")
    best_nmse = float("inf")
    best_rmse = float("inf")
    best_nmse_db = float("inf")

    best_epoch_loss = 0
    best_epoch_nmse = 0
    best_epoch_rmse = 0
    best_epoch_nmse_db = 0

    for ep in range(1, epochs + 1):
        t0 = time.time()
        train_loss = train_one_epoch(model, train_loader, criterion, optimizer)
        val_loss, rmse, nmse, nmse_db = evaluate(model, val_loader, criterion)
        dt = time.time() - t0

        # Track best values
        if val_loss < best_loss:
            best_loss = val_loss
            best_epoch_loss = ep

        if nmse < best_nmse:
            best_nmse = nmse
            best_epoch_nmse = ep

        if rmse < best_rmse:
            best_rmse = rmse
            best_epoch_rmse = ep

        if nmse_db < best_nmse_db:
            best_nmse_db = nmse_db
            best_epoch_nmse_db = ep

        # Logging
        if ep % show_every == 0:
            print(f"[{ep:02d}/{epochs:03d}] "
                  f"TrainLoss: {train_loss:.6f}  "
                  f"ValLoss: {val_loss:.6f}  "
                  f"Val RMSE: {rmse:.4f}  "
                  f"Val NMSE: {nmse:.4f}  "
                  f"Val NMSE_dB: {nmse_db:.6f} dB  "
                  f"TrainTime: {dt:.2f}s")

    # Summary of best metrics
    print("=" * 60)
    print(f"=> Best ValLoss   : {best_loss:.6f}   (epoch {best_epoch_loss})")
    print(f"=> Best Val NMSE  : {best_nmse:.4f}   (epoch {best_epoch_nmse})")
    print(f"=> Best Val RMSE  : {best_rmse:.4f}   (epoch {best_epoch_rmse})")
    print(f"=> Best Val NMSE_dB: {best_nmse_db:.4f} dB (epoch {best_epoch_nmse_db})")
    print("=" * 60)

    return model

# %%
import sys, os, contextlib
device = "cuda" if torch.cuda.is_available() else "cpu"
epochs = 1000

# --- Tee that mirrors stdout to both console and a file ---
class Tee:
    def __init__(self, filename, mode="w", encoding="utf-8"):
        os.makedirs(os.path.dirname(filename), exist_ok=True)
        self.file = open(filename, mode, encoding=encoding)
        self.stdout = sys.stdout

    def write(self, data):
        self.file.write(data)
        self.stdout.write(data)

    def flush(self):
        self.file.flush()
        self.stdout.flush()

    def close(self):
        self.file.close()

    # context manager support
    def __enter__(self):
        return self

    def __exit__(self, exc_type, exc, tb):
        self.close()
        # don't suppress exceptions
        return False

# ----------------------------------------------------------
# 
base_dir = "/home/dlghdbs200/LWM_denver"

print("=== MLP Training ===")
mlp = MLP(hidden=256, depth=3, pdrop=0.1)
mlp_path = os.path.join(base_dir, "MLP_epoch1000_user.txt")
with Tee(mlp_path, "w") as tee:
    with contextlib.redirect_stdout(tee):
        print("=== Training MLP ===")
        run(mlp, epochs=epochs, lr=1e-3)
print(f"\nMLP training log saved to {mlp_path}")

print("\n=== CNN Training ===")
cnn = CNN1D()
cnn_path = os.path.join(base_dir, "CNN_epoch1000_user.txt")
with Tee(cnn_path, "w") as tee:
    with contextlib.redirect_stdout(tee):
        print("=== Training CNN ===")
        run(cnn, epochs=epochs, lr=1e-3)
print(f"\nCNN training log saved to {cnn_path}")

print("\n=== LWM Training ===")

lwm_model = LWM_denver(d_model=64, n_layers=12)
lwm_path = os.path.join(base_dir, "LWM_epoch1000_user.txt")
with Tee(lwm_path, "w") as tee:
    with contextlib.redirect_stdout(tee):
        print("=== Training LWM ===")
        sample_x, _ = next(iter(train_loader))
        L = sample_x.shape[2]
        D = sample_x.shape[-1]
        lwm_model.build_core(L=L, D=D, device=device)
        run(lwm_model, epochs=epochs, lr=1e-3)
print(f"\nLWM training log saved to {lwm_path}")
# Out:
# === MLP Training ===
# === Training MLP ===
# [01/1000] TrainLoss: 0.005900  ValLoss: 0.000285  Val RMSE: 0.0169  Val NMSE: 0.0102  Val NMSE_dB: -19.912825 dB  TrainTime: 2.38s
# [02/1000] TrainLoss: 0.001174  ValLoss: 0.000181  Val RMSE: 0.0135  Val NMSE: 0.0065  Val NMSE_dB: -21.872620 dB  TrainTime: 1.20s
# [03/1000] TrainLoss: 0.000983  ValLoss: 0.000145  Val RMSE: 0.0120  Val NMSE: 0.0052  Val NMSE_dB: -22.844071 dB  TrainTime: 1.25s
# [04/1000] TrainLoss: 0.000903  ValLoss: 0.000130  Val RMSE: 0.0114  Val NMSE: 0.0047  Val NMSE_dB: -23.322098 dB  TrainTime: 1.09s
# [05/1000] TrainLoss: 0.000861  ValLoss: 0.000131  Val RMSE: 0.0114  Val NMSE: 0.0047  Val NMSE_dB: -23.291535 dB  TrainTime: 1.14s
# [06/1000] TrainLoss: 0.000827  ValLoss: 0.000115  Val RMSE: 0.0107  Val NMSE: 0.0041  Val NMSE_dB: -23.844355 dB  TrainTime: 1.13s
# [07/1000] TrainLoss: 0.000805  ValLoss: 0.000123  Val RMSE: 0.0111  Val NMSE: 0.0044  Val NMSE_dB: -23.568835 dB  TrainTime: 1.15s
# [08/1000] TrainLoss: 0.000788  ValLoss: 0.000141  Val RMSE: 0.0119  Val NMSE: 0.0051  Val NMSE_dB: -22.953506 dB  TrainTime: 3.72s
# [09/1000] TrainLoss: 0.000779  ValLoss: 0.000105  Val RMSE: 0.0102  Val NMSE: 0.0038  Val NMSE_dB: -24.248068 dB  TrainTime: 1.25s
# [10/1000] TrainLoss: 0.000767  ValLoss: 0.000133  Val RMSE: 0.0116  Val NMSE: 0.0048  Val NMSE_dB: -23.203946 dB  TrainTime: 1.19s
# [11/1000] TrainLoss: 0.000758  ValLoss: 0.000127  Val RMSE: 0.0113  Val NMSE: 0.0046  Val NMSE_dB: -23.401191 dB  TrainTime: 1.13s
# [12/1000] TrainLoss: 0.000746  ValLoss: 0.000118  Val RMSE: 0.0108  Val NMSE: 0.0042  Val NMSE_dB: -23.749547 dB  TrainTime: 1.28s
# [13/1000] TrainLoss: 0.000740  ValLoss: 0.000121  Val RMSE: 0.0110  Val NMSE: 0.0043  Val NMSE_dB: -23.644415 dB  TrainTime: 1.18s
# [14/1000] TrainLoss: 0.000735  ValLoss: 0.000110  Val RMSE: 0.0105  Val NMSE: 0.0039  Val NMSE_dB: -24.048145 dB  TrainTime: 1.21s
# [15/1000] TrainLoss: 0.000732  ValLoss: 0.000108  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.109385 dB  TrainTime: 1.17s
# [16/1000] TrainLoss: 0.000722  ValLoss: 0.000126  Val RMSE: 0.0112  Val NMSE: 0.0045  Val NMSE_dB: -23.434911 dB  TrainTime: 1.35s
# [17/1000] TrainLoss: 0.000724  ValLoss: 0.000133  Val RMSE: 0.0115  Val NMSE: 0.0048  Val NMSE_dB: -23.222558 dB  TrainTime: 1.22s
# [18/1000] TrainLoss: 0.000717  ValLoss: 0.000147  Val RMSE: 0.0121  Val NMSE: 0.0053  Val NMSE_dB: -22.791721 dB  TrainTime: 1.13s
# [19/1000] TrainLoss: 0.000714  ValLoss: 0.000149  Val RMSE: 0.0122  Val NMSE: 0.0053  Val NMSE_dB: -22.721605 dB  TrainTime: 1.36s
# [20/1000] TrainLoss: 0.000715  ValLoss: 0.000114  Val RMSE: 0.0107  Val NMSE: 0.0041  Val NMSE_dB: -23.870256 dB  TrainTime: 1.16s
# [21/1000] TrainLoss: 0.000708  ValLoss: 0.000113  Val RMSE: 0.0106  Val NMSE: 0.0040  Val NMSE_dB: -23.926158 dB  TrainTime: 1.22s
# [22/1000] TrainLoss: 0.000703  ValLoss: 0.000137  Val RMSE: 0.0117  Val NMSE: 0.0049  Val NMSE_dB: -23.093383 dB  TrainTime: 1.17s
# [23/1000] TrainLoss: 0.000703  ValLoss: 0.000122  Val RMSE: 0.0110  Val NMSE: 0.0044  Val NMSE_dB: -23.602193 dB  TrainTime: 1.29s
# [24/1000] TrainLoss: 0.000696  ValLoss: 0.000108  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.121845 dB  TrainTime: 1.21s
# [25/1000] TrainLoss: 0.000693  ValLoss: 0.000108  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.137946 dB  TrainTime: 1.14s
# [26/1000] TrainLoss: 0.000692  ValLoss: 0.000141  Val RMSE: 0.0119  Val NMSE: 0.0051  Val NMSE_dB: -22.948813 dB  TrainTime: 1.17s
# [27/1000] TrainLoss: 0.000694  ValLoss: 0.000107  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.157252 dB  TrainTime: 1.33s
# [28/1000] TrainLoss: 0.000690  ValLoss: 0.000105  Val RMSE: 0.0102  Val NMSE: 0.0038  Val NMSE_dB: -24.254703 dB  TrainTime: 1.22s
# [29/1000] TrainLoss: 0.000687  ValLoss: 0.000098  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.521322 dB  TrainTime: 1.20s
# [30/1000] TrainLoss: 0.000686  ValLoss: 0.000102  Val RMSE: 0.0101  Val NMSE: 0.0037  Val NMSE_dB: -24.348126 dB  TrainTime: 1.31s
# [31/1000] TrainLoss: 0.000686  ValLoss: 0.000103  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.309948 dB  TrainTime: 1.19s
# [32/1000] TrainLoss: 0.000683  ValLoss: 0.000113  Val RMSE: 0.0106  Val NMSE: 0.0041  Val NMSE_dB: -23.914892 dB  TrainTime: 1.16s
# [33/1000] TrainLoss: 0.000679  ValLoss: 0.000131  Val RMSE: 0.0114  Val NMSE: 0.0047  Val NMSE_dB: -23.296060 dB  TrainTime: 1.15s
# [34/1000] TrainLoss: 0.000682  ValLoss: 0.000082  Val RMSE: 0.0091  Val NMSE: 0.0029  Val NMSE_dB: -25.306897 dB  TrainTime: 1.31s
# [35/1000] TrainLoss: 0.000679  ValLoss: 0.000102  Val RMSE: 0.0101  Val NMSE: 0.0036  Val NMSE_dB: -24.377915 dB  TrainTime: 3.48s
# [36/1000] TrainLoss: 0.000673  ValLoss: 0.000105  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.261304 dB  TrainTime: 1.20s
# [37/1000] TrainLoss: 0.000674  ValLoss: 0.000130  Val RMSE: 0.0114  Val NMSE: 0.0047  Val NMSE_dB: -23.322384 dB  TrainTime: 1.17s
# [38/1000] TrainLoss: 0.000682  ValLoss: 0.000112  Val RMSE: 0.0106  Val NMSE: 0.0040  Val NMSE_dB: -23.975361 dB  TrainTime: 1.34s
# [39/1000] TrainLoss: 0.000677  ValLoss: 0.000131  Val RMSE: 0.0115  Val NMSE: 0.0047  Val NMSE_dB: -23.271343 dB  TrainTime: 1.28s
# [40/1000] TrainLoss: 0.000675  ValLoss: 0.000116  Val RMSE: 0.0108  Val NMSE: 0.0042  Val NMSE_dB: -23.815500 dB  TrainTime: 1.18s
# [41/1000] TrainLoss: 0.000671  ValLoss: 0.000108  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.134983 dB  TrainTime: 1.18s
# [42/1000] TrainLoss: 0.000672  ValLoss: 0.000124  Val RMSE: 0.0111  Val NMSE: 0.0045  Val NMSE_dB: -23.515975 dB  TrainTime: 1.17s
# [43/1000] TrainLoss: 0.000676  ValLoss: 0.000109  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.098351 dB  TrainTime: 1.17s
# [44/1000] TrainLoss: 0.000666  ValLoss: 0.000102  Val RMSE: 0.0101  Val NMSE: 0.0037  Val NMSE_dB: -24.373505 dB  TrainTime: 1.37s
# [45/1000] TrainLoss: 0.000662  ValLoss: 0.000108  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.101554 dB  TrainTime: 1.19s
# [46/1000] TrainLoss: 0.000664  ValLoss: 0.000111  Val RMSE: 0.0105  Val NMSE: 0.0040  Val NMSE_dB: -24.005730 dB  TrainTime: 1.19s
# [47/1000] TrainLoss: 0.000665  ValLoss: 0.000115  Val RMSE: 0.0107  Val NMSE: 0.0041  Val NMSE_dB: -23.859991 dB  TrainTime: 1.21s
# [48/1000] TrainLoss: 0.000663  ValLoss: 0.000101  Val RMSE: 0.0101  Val NMSE: 0.0036  Val NMSE_dB: -24.407757 dB  TrainTime: 1.14s
# [49/1000] TrainLoss: 0.000662  ValLoss: 0.000109  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.091932 dB  TrainTime: 1.13s
# [50/1000] TrainLoss: 0.000662  ValLoss: 0.000120  Val RMSE: 0.0110  Val NMSE: 0.0043  Val NMSE_dB: -23.663771 dB  TrainTime: 1.29s
# [51/1000] TrainLoss: 0.000662  ValLoss: 0.000113  Val RMSE: 0.0106  Val NMSE: 0.0041  Val NMSE_dB: -23.914522 dB  TrainTime: 1.18s
# [52/1000] TrainLoss: 0.000660  ValLoss: 0.000105  Val RMSE: 0.0102  Val NMSE: 0.0038  Val NMSE_dB: -24.252654 dB  TrainTime: 1.18s
# [53/1000] TrainLoss: 0.000660  ValLoss: 0.000112  Val RMSE: 0.0106  Val NMSE: 0.0040  Val NMSE_dB: -23.977266 dB  TrainTime: 1.15s
# [54/1000] TrainLoss: 0.000656  ValLoss: 0.000129  Val RMSE: 0.0114  Val NMSE: 0.0046  Val NMSE_dB: -23.352791 dB  TrainTime: 1.14s
# [55/1000] TrainLoss: 0.000661  ValLoss: 0.000124  Val RMSE: 0.0111  Val NMSE: 0.0044  Val NMSE_dB: -23.524147 dB  TrainTime: 1.31s
# [56/1000] TrainLoss: 0.000657  ValLoss: 0.000118  Val RMSE: 0.0109  Val NMSE: 0.0042  Val NMSE_dB: -23.737400 dB  TrainTime: 1.21s
# [57/1000] TrainLoss: 0.000653  ValLoss: 0.000106  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.212536 dB  TrainTime: 1.13s
# [58/1000] TrainLoss: 0.000649  ValLoss: 0.000107  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.156561 dB  TrainTime: 1.10s
# [59/1000] TrainLoss: 0.000653  ValLoss: 0.000103  Val RMSE: 0.0101  Val NMSE: 0.0037  Val NMSE_dB: -24.346624 dB  TrainTime: 1.13s
# [60/1000] TrainLoss: 0.000652  ValLoss: 0.000105  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.223756 dB  TrainTime: 1.44s
# [61/1000] TrainLoss: 0.000650  ValLoss: 0.000121  Val RMSE: 0.0110  Val NMSE: 0.0044  Val NMSE_dB: -23.612965 dB  TrainTime: 1.22s
# [62/1000] TrainLoss: 0.000652  ValLoss: 0.000110  Val RMSE: 0.0105  Val NMSE: 0.0039  Val NMSE_dB: -24.047790 dB  TrainTime: 3.57s
# [63/1000] TrainLoss: 0.000651  ValLoss: 0.000097  Val RMSE: 0.0098  Val NMSE: 0.0035  Val NMSE_dB: -24.595142 dB  TrainTime: 1.24s
# [64/1000] TrainLoss: 0.000643  ValLoss: 0.000113  Val RMSE: 0.0106  Val NMSE: 0.0040  Val NMSE_dB: -23.936792 dB  TrainTime: 1.40s
# [65/1000] TrainLoss: 0.000649  ValLoss: 0.000116  Val RMSE: 0.0108  Val NMSE: 0.0042  Val NMSE_dB: -23.800179 dB  TrainTime: 1.15s
# [66/1000] TrainLoss: 0.000646  ValLoss: 0.000111  Val RMSE: 0.0105  Val NMSE: 0.0040  Val NMSE_dB: -24.008879 dB  TrainTime: 1.21s
# [67/1000] TrainLoss: 0.000646  ValLoss: 0.000129  Val RMSE: 0.0114  Val NMSE: 0.0046  Val NMSE_dB: -23.337671 dB  TrainTime: 1.20s
# [68/1000] TrainLoss: 0.000651  ValLoss: 0.000114  Val RMSE: 0.0107  Val NMSE: 0.0041  Val NMSE_dB: -23.888549 dB  TrainTime: 1.28s
# [69/1000] TrainLoss: 0.000649  ValLoss: 0.000119  Val RMSE: 0.0109  Val NMSE: 0.0043  Val NMSE_dB: -23.701029 dB  TrainTime: 1.26s
# [70/1000] TrainLoss: 0.000646  ValLoss: 0.000089  Val RMSE: 0.0094  Val NMSE: 0.0032  Val NMSE_dB: -24.967373 dB  TrainTime: 1.19s
# [71/1000] TrainLoss: 0.000642  ValLoss: 0.000128  Val RMSE: 0.0113  Val NMSE: 0.0046  Val NMSE_dB: -23.368070 dB  TrainTime: 1.41s
# [72/1000] TrainLoss: 0.000646  ValLoss: 0.000106  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.204807 dB  TrainTime: 1.15s
# [73/1000] TrainLoss: 0.000645  ValLoss: 0.000124  Val RMSE: 0.0111  Val NMSE: 0.0044  Val NMSE_dB: -23.537506 dB  TrainTime: 1.21s
# [74/1000] TrainLoss: 0.000640  ValLoss: 0.000105  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.259961 dB  TrainTime: 1.18s
# [75/1000] TrainLoss: 0.000641  ValLoss: 0.000152  Val RMSE: 0.0123  Val NMSE: 0.0054  Val NMSE_dB: -22.645145 dB  TrainTime: 1.28s
# [76/1000] TrainLoss: 0.000648  ValLoss: 0.000089  Val RMSE: 0.0094  Val NMSE: 0.0032  Val NMSE_dB: -24.963574 dB  TrainTime: 1.18s
# [77/1000] TrainLoss: 0.000638  ValLoss: 0.000101  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.419221 dB  TrainTime: 1.16s
# [78/1000] TrainLoss: 0.000634  ValLoss: 0.000114  Val RMSE: 0.0107  Val NMSE: 0.0041  Val NMSE_dB: -23.902963 dB  TrainTime: 1.15s
# [79/1000] TrainLoss: 0.000641  ValLoss: 0.000105  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.223955 dB  TrainTime: 1.31s
# [80/1000] TrainLoss: 0.000643  ValLoss: 0.000125  Val RMSE: 0.0112  Val NMSE: 0.0045  Val NMSE_dB: -23.484261 dB  TrainTime: 1.20s
# [81/1000] TrainLoss: 0.000643  ValLoss: 0.000121  Val RMSE: 0.0110  Val NMSE: 0.0043  Val NMSE_dB: -23.641263 dB  TrainTime: 1.19s
# [82/1000] TrainLoss: 0.000642  ValLoss: 0.000128  Val RMSE: 0.0113  Val NMSE: 0.0046  Val NMSE_dB: -23.369573 dB  TrainTime: 1.33s
# [83/1000] TrainLoss: 0.000642  ValLoss: 0.000097  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.583895 dB  TrainTime: 1.20s
# [84/1000] TrainLoss: 0.000637  ValLoss: 0.000096  Val RMSE: 0.0098  Val NMSE: 0.0034  Val NMSE_dB: -24.638160 dB  TrainTime: 1.15s
# [85/1000] TrainLoss: 0.000639  ValLoss: 0.000105  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.224107 dB  TrainTime: 1.23s
# [86/1000] TrainLoss: 0.000640  ValLoss: 0.000085  Val RMSE: 0.0092  Val NMSE: 0.0031  Val NMSE_dB: -25.141287 dB  TrainTime: 1.33s
# [87/1000] TrainLoss: 0.000636  ValLoss: 0.000109  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.082615 dB  TrainTime: 1.24s
# [88/1000] TrainLoss: 0.000641  ValLoss: 0.000112  Val RMSE: 0.0106  Val NMSE: 0.0040  Val NMSE_dB: -23.972537 dB  TrainTime: 3.50s
# [89/1000] TrainLoss: 0.000639  ValLoss: 0.000108  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.111517 dB  TrainTime: 1.16s
# [90/1000] TrainLoss: 0.000633  ValLoss: 0.000107  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.167826 dB  TrainTime: 1.26s
# [91/1000] TrainLoss: 0.000635  ValLoss: 0.000109  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.097858 dB  TrainTime: 1.18s
# [92/1000] TrainLoss: 0.000636  ValLoss: 0.000112  Val RMSE: 0.0106  Val NMSE: 0.0040  Val NMSE_dB: -23.970541 dB  TrainTime: 1.19s
# [93/1000] TrainLoss: 0.000631  ValLoss: 0.000100  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.468139 dB  TrainTime: 1.20s
# [94/1000] TrainLoss: 0.000637  ValLoss: 0.000110  Val RMSE: 0.0105  Val NMSE: 0.0040  Val NMSE_dB: -24.029353 dB  TrainTime: 1.15s
# [95/1000] TrainLoss: 0.000632  ValLoss: 0.000097  Val RMSE: 0.0098  Val NMSE: 0.0035  Val NMSE_dB: -24.604590 dB  TrainTime: 1.07s
# [96/1000] TrainLoss: 0.000636  ValLoss: 0.000096  Val RMSE: 0.0098  Val NMSE: 0.0035  Val NMSE_dB: -24.620583 dB  TrainTime: 1.35s
# [97/1000] TrainLoss: 0.000633  ValLoss: 0.000101  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.426689 dB  TrainTime: 1.26s
# [98/1000] TrainLoss: 0.000638  ValLoss: 0.000090  Val RMSE: 0.0095  Val NMSE: 0.0032  Val NMSE_dB: -24.928700 dB  TrainTime: 1.22s
# [99/1000] TrainLoss: 0.000629  ValLoss: 0.000106  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.208408 dB  TrainTime: 1.19s
# [100/1000] TrainLoss: 0.000632  ValLoss: 0.000134  Val RMSE: 0.0116  Val NMSE: 0.0048  Val NMSE_dB: -23.188038 dB  TrainTime: 1.09s
# [101/1000] TrainLoss: 0.000633  ValLoss: 0.000090  Val RMSE: 0.0095  Val NMSE: 0.0032  Val NMSE_dB: -24.903944 dB  TrainTime: 1.10s
# [102/1000] TrainLoss: 0.000633  ValLoss: 0.000099  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.513195 dB  TrainTime: 1.33s
# [103/1000] TrainLoss: 0.000630  ValLoss: 0.000110  Val RMSE: 0.0105  Val NMSE: 0.0039  Val NMSE_dB: -24.055613 dB  TrainTime: 1.24s
# [104/1000] TrainLoss: 0.000635  ValLoss: 0.000132  Val RMSE: 0.0115  Val NMSE: 0.0047  Val NMSE_dB: -23.258616 dB  TrainTime: 1.21s
# [105/1000] TrainLoss: 0.000641  ValLoss: 0.000102  Val RMSE: 0.0101  Val NMSE: 0.0036  Val NMSE_dB: -24.380061 dB  TrainTime: 1.19s
# [106/1000] TrainLoss: 0.000633  ValLoss: 0.000100  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.437445 dB  TrainTime: 1.16s
# [107/1000] TrainLoss: 0.000631  ValLoss: 0.000103  Val RMSE: 0.0101  Val NMSE: 0.0037  Val NMSE_dB: -24.336347 dB  TrainTime: 1.36s
# [108/1000] TrainLoss: 0.000630  ValLoss: 0.000101  Val RMSE: 0.0101  Val NMSE: 0.0036  Val NMSE_dB: -24.409391 dB  TrainTime: 1.25s
# [109/1000] TrainLoss: 0.000628  ValLoss: 0.000103  Val RMSE: 0.0101  Val NMSE: 0.0037  Val NMSE_dB: -24.339366 dB  TrainTime: 1.20s
# [110/1000] TrainLoss: 0.000635  ValLoss: 0.000115  Val RMSE: 0.0107  Val NMSE: 0.0041  Val NMSE_dB: -23.856031 dB  TrainTime: 1.16s
# [111/1000] TrainLoss: 0.000633  ValLoss: 0.000101  Val RMSE: 0.0101  Val NMSE: 0.0036  Val NMSE_dB: -24.392050 dB  TrainTime: 1.14s
# [112/1000] TrainLoss: 0.000631  ValLoss: 0.000108  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.126132 dB  TrainTime: 1.35s
# [113/1000] TrainLoss: 0.000626  ValLoss: 0.000102  Val RMSE: 0.0101  Val NMSE: 0.0037  Val NMSE_dB: -24.376237 dB  TrainTime: 1.24s
# [114/1000] TrainLoss: 0.000629  ValLoss: 0.000088  Val RMSE: 0.0094  Val NMSE: 0.0032  Val NMSE_dB: -24.993242 dB  TrainTime: 1.19s
# [115/1000] TrainLoss: 0.000622  ValLoss: 0.000096  Val RMSE: 0.0098  Val NMSE: 0.0034  Val NMSE_dB: -24.649365 dB  TrainTime: 3.39s
# [116/1000] TrainLoss: 0.000628  ValLoss: 0.000101  Val RMSE: 0.0101  Val NMSE: 0.0036  Val NMSE_dB: -24.393502 dB  TrainTime: 1.40s
# [117/1000] TrainLoss: 0.000627  ValLoss: 0.000127  Val RMSE: 0.0113  Val NMSE: 0.0046  Val NMSE_dB: -23.419744 dB  TrainTime: 1.24s
# [118/1000] TrainLoss: 0.000631  ValLoss: 0.000094  Val RMSE: 0.0097  Val NMSE: 0.0034  Val NMSE_dB: -24.717176 dB  TrainTime: 1.14s
# [119/1000] TrainLoss: 0.000626  ValLoss: 0.000112  Val RMSE: 0.0106  Val NMSE: 0.0040  Val NMSE_dB: -23.971202 dB  TrainTime: 1.18s
# [120/1000] TrainLoss: 0.000628  ValLoss: 0.000098  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.537242 dB  TrainTime: 1.37s
# [121/1000] TrainLoss: 0.000627  ValLoss: 0.000084  Val RMSE: 0.0092  Val NMSE: 0.0030  Val NMSE_dB: -25.214667 dB  TrainTime: 1.19s
# [122/1000] TrainLoss: 0.000624  ValLoss: 0.000093  Val RMSE: 0.0097  Val NMSE: 0.0033  Val NMSE_dB: -24.752477 dB  TrainTime: 1.25s
# [123/1000] TrainLoss: 0.000629  ValLoss: 0.000085  Val RMSE: 0.0092  Val NMSE: 0.0030  Val NMSE_dB: -25.179311 dB  TrainTime: 1.40s
# [124/1000] TrainLoss: 0.000629  ValLoss: 0.000096  Val RMSE: 0.0098  Val NMSE: 0.0034  Val NMSE_dB: -24.649452 dB  TrainTime: 1.14s
# [125/1000] TrainLoss: 0.000625  ValLoss: 0.000097  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.580856 dB  TrainTime: 1.16s
# [126/1000] TrainLoss: 0.000623  ValLoss: 0.000095  Val RMSE: 0.0098  Val NMSE: 0.0034  Val NMSE_dB: -24.673009 dB  TrainTime: 1.23s
# [127/1000] TrainLoss: 0.000623  ValLoss: 0.000090  Val RMSE: 0.0095  Val NMSE: 0.0032  Val NMSE_dB: -24.891806 dB  TrainTime: 1.37s
# [128/1000] TrainLoss: 0.000626  ValLoss: 0.000098  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.548507 dB  TrainTime: 1.15s
# [129/1000] TrainLoss: 0.000625  ValLoss: 0.000101  Val RMSE: 0.0101  Val NMSE: 0.0036  Val NMSE_dB: -24.395436 dB  TrainTime: 1.23s
# [130/1000] TrainLoss: 0.000620  ValLoss: 0.000104  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.298240 dB  TrainTime: 1.18s
# [131/1000] TrainLoss: 0.000627  ValLoss: 0.000101  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.429879 dB  TrainTime: 1.39s
# [132/1000] TrainLoss: 0.000627  ValLoss: 0.000089  Val RMSE: 0.0094  Val NMSE: 0.0032  Val NMSE_dB: -24.983269 dB  TrainTime: 1.20s
# [133/1000] TrainLoss: 0.000621  ValLoss: 0.000103  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.312622 dB  TrainTime: 1.17s
# [134/1000] TrainLoss: 0.000622  ValLoss: 0.000106  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.183438 dB  TrainTime: 1.34s
# [135/1000] TrainLoss: 0.000619  ValLoss: 0.000090  Val RMSE: 0.0095  Val NMSE: 0.0032  Val NMSE_dB: -24.925785 dB  TrainTime: 1.16s
# [136/1000] TrainLoss: 0.000620  ValLoss: 0.000130  Val RMSE: 0.0114  Val NMSE: 0.0047  Val NMSE_dB: -23.301789 dB  TrainTime: 1.16s
# [137/1000] TrainLoss: 0.000627  ValLoss: 0.000114  Val RMSE: 0.0107  Val NMSE: 0.0041  Val NMSE_dB: -23.901463 dB  TrainTime: 1.30s
# [138/1000] TrainLoss: 0.000623  ValLoss: 0.000098  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.549656 dB  TrainTime: 1.48s
# [139/1000] TrainLoss: 0.000623  ValLoss: 0.000092  Val RMSE: 0.0096  Val NMSE: 0.0033  Val NMSE_dB: -24.797456 dB  TrainTime: 1.22s
# [140/1000] TrainLoss: 0.000624  ValLoss: 0.000104  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.276581 dB  TrainTime: 1.20s
# [141/1000] TrainLoss: 0.000621  ValLoss: 0.000088  Val RMSE: 0.0094  Val NMSE: 0.0032  Val NMSE_dB: -24.997283 dB  TrainTime: 3.64s
# [142/1000] TrainLoss: 0.000616  ValLoss: 0.000113  Val RMSE: 0.0106  Val NMSE: 0.0040  Val NMSE_dB: -23.935104 dB  TrainTime: 1.36s
# [143/1000] TrainLoss: 0.000622  ValLoss: 0.000109  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.091513 dB  TrainTime: 1.28s
# [144/1000] TrainLoss: 0.000624  ValLoss: 0.000101  Val RMSE: 0.0101  Val NMSE: 0.0036  Val NMSE_dB: -24.390037 dB  TrainTime: 1.19s
# [145/1000] TrainLoss: 0.000623  ValLoss: 0.000087  Val RMSE: 0.0093  Val NMSE: 0.0031  Val NMSE_dB: -25.074790 dB  TrainTime: 1.29s
# [146/1000] TrainLoss: 0.000614  ValLoss: 0.000108  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.123446 dB  TrainTime: 1.29s
# [147/1000] TrainLoss: 0.000617  ValLoss: 0.000080  Val RMSE: 0.0089  Val NMSE: 0.0029  Val NMSE_dB: -25.430615 dB  TrainTime: 1.18s
# [148/1000] TrainLoss: 0.000614  ValLoss: 0.000076  Val RMSE: 0.0087  Val NMSE: 0.0027  Val NMSE_dB: -25.629338 dB  TrainTime: 1.43s
# [149/1000] TrainLoss: 0.000614  ValLoss: 0.000095  Val RMSE: 0.0097  Val NMSE: 0.0034  Val NMSE_dB: -24.694028 dB  TrainTime: 1.26s
# [150/1000] TrainLoss: 0.000618  ValLoss: 0.000095  Val RMSE: 0.0098  Val NMSE: 0.0034  Val NMSE_dB: -24.667648 dB  TrainTime: 1.20s
# [151/1000] TrainLoss: 0.000617  ValLoss: 0.000089  Val RMSE: 0.0094  Val NMSE: 0.0032  Val NMSE_dB: -24.970728 dB  TrainTime: 1.17s
# [152/1000] TrainLoss: 0.000617  ValLoss: 0.000090  Val RMSE: 0.0095  Val NMSE: 0.0032  Val NMSE_dB: -24.917482 dB  TrainTime: 1.33s
# [153/1000] TrainLoss: 0.000615  ValLoss: 0.000086  Val RMSE: 0.0093  Val NMSE: 0.0031  Val NMSE_dB: -25.125775 dB  TrainTime: 1.30s
# [154/1000] TrainLoss: 0.000625  ValLoss: 0.000094  Val RMSE: 0.0097  Val NMSE: 0.0034  Val NMSE_dB: -24.709813 dB  TrainTime: 1.34s
# [155/1000] TrainLoss: 0.000615  ValLoss: 0.000108  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.104477 dB  TrainTime: 1.14s
# [156/1000] TrainLoss: 0.000625  ValLoss: 0.000082  Val RMSE: 0.0091  Val NMSE: 0.0030  Val NMSE_dB: -25.291000 dB  TrainTime: 1.22s
# [157/1000] TrainLoss: 0.000611  ValLoss: 0.000084  Val RMSE: 0.0092  Val NMSE: 0.0030  Val NMSE_dB: -25.213544 dB  TrainTime: 1.25s
# [158/1000] TrainLoss: 0.000617  ValLoss: 0.000093  Val RMSE: 0.0097  Val NMSE: 0.0033  Val NMSE_dB: -24.753274 dB  TrainTime: 1.23s
# [159/1000] TrainLoss: 0.000616  ValLoss: 0.000099  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.499064 dB  TrainTime: 1.44s
# [160/1000] TrainLoss: 0.000614  ValLoss: 0.000132  Val RMSE: 0.0115  Val NMSE: 0.0047  Val NMSE_dB: -23.249537 dB  TrainTime: 1.28s
# [161/1000] TrainLoss: 0.000612  ValLoss: 0.000092  Val RMSE: 0.0096  Val NMSE: 0.0033  Val NMSE_dB: -24.811433 dB  TrainTime: 1.29s
# [162/1000] TrainLoss: 0.000616  ValLoss: 0.000112  Val RMSE: 0.0106  Val NMSE: 0.0040  Val NMSE_dB: -23.969144 dB  TrainTime: 1.24s
# [163/1000] TrainLoss: 0.000617  ValLoss: 0.000085  Val RMSE: 0.0092  Val NMSE: 0.0030  Val NMSE_dB: -25.167154 dB  TrainTime: 1.14s
# [164/1000] TrainLoss: 0.000608  ValLoss: 0.000102  Val RMSE: 0.0101  Val NMSE: 0.0036  Val NMSE_dB: -24.384261 dB  TrainTime: 1.41s
# [165/1000] TrainLoss: 0.000614  ValLoss: 0.000082  Val RMSE: 0.0091  Val NMSE: 0.0029  Val NMSE_dB: -25.312107 dB  TrainTime: 1.29s
# [166/1000] TrainLoss: 0.000611  ValLoss: 0.000102  Val RMSE: 0.0101  Val NMSE: 0.0036  Val NMSE_dB: -24.383846 dB  TrainTime: 1.27s
# [167/1000] TrainLoss: 0.000619  ValLoss: 0.000080  Val RMSE: 0.0089  Val NMSE: 0.0029  Val NMSE_dB: -25.441399 dB  TrainTime: 3.52s
# [168/1000] TrainLoss: 0.000612  ValLoss: 0.000099  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.516196 dB  TrainTime: 1.46s
# [169/1000] TrainLoss: 0.000614  ValLoss: 0.000092  Val RMSE: 0.0096  Val NMSE: 0.0033  Val NMSE_dB: -24.833837 dB  TrainTime: 1.25s
# [170/1000] TrainLoss: 0.000611  ValLoss: 0.000090  Val RMSE: 0.0095  Val NMSE: 0.0032  Val NMSE_dB: -24.931311 dB  TrainTime: 1.20s
# [171/1000] TrainLoss: 0.000609  ValLoss: 0.000084  Val RMSE: 0.0092  Val NMSE: 0.0030  Val NMSE_dB: -25.219349 dB  TrainTime: 1.22s
# [172/1000] TrainLoss: 0.000611  ValLoss: 0.000112  Val RMSE: 0.0106  Val NMSE: 0.0040  Val NMSE_dB: -23.972470 dB  TrainTime: 1.44s
# [173/1000] TrainLoss: 0.000614  ValLoss: 0.000097  Val RMSE: 0.0098  Val NMSE: 0.0035  Val NMSE_dB: -24.586651 dB  TrainTime: 1.26s
# [174/1000] TrainLoss: 0.000609  ValLoss: 0.000083  Val RMSE: 0.0091  Val NMSE: 0.0030  Val NMSE_dB: -25.279438 dB  TrainTime: 1.27s
# [175/1000] TrainLoss: 0.000607  ValLoss: 0.000103  Val RMSE: 0.0101  Val NMSE: 0.0037  Val NMSE_dB: -24.337508 dB  TrainTime: 1.43s
# [176/1000] TrainLoss: 0.000609  ValLoss: 0.000110  Val RMSE: 0.0105  Val NMSE: 0.0040  Val NMSE_dB: -24.021760 dB  TrainTime: 1.26s
# [177/1000] TrainLoss: 0.000615  ValLoss: 0.000118  Val RMSE: 0.0109  Val NMSE: 0.0042  Val NMSE_dB: -23.725307 dB  TrainTime: 1.23s
# [178/1000] TrainLoss: 0.000615  ValLoss: 0.000111  Val RMSE: 0.0106  Val NMSE: 0.0040  Val NMSE_dB: -23.981700 dB  TrainTime: 1.16s
# [179/1000] TrainLoss: 0.000613  ValLoss: 0.000103  Val RMSE: 0.0101  Val NMSE: 0.0037  Val NMSE_dB: -24.334874 dB  TrainTime: 1.35s
# [180/1000] TrainLoss: 0.000609  ValLoss: 0.000090  Val RMSE: 0.0095  Val NMSE: 0.0032  Val NMSE_dB: -24.907267 dB  TrainTime: 1.30s
# [181/1000] TrainLoss: 0.000605  ValLoss: 0.000104  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.281264 dB  TrainTime: 1.22s
# [182/1000] TrainLoss: 0.000608  ValLoss: 0.000082  Val RMSE: 0.0091  Val NMSE: 0.0030  Val NMSE_dB: -25.293505 dB  TrainTime: 1.28s
# [183/1000] TrainLoss: 0.000605  ValLoss: 0.000113  Val RMSE: 0.0106  Val NMSE: 0.0041  Val NMSE_dB: -23.914271 dB  TrainTime: 1.38s
# [184/1000] TrainLoss: 0.000607  ValLoss: 0.000103  Val RMSE: 0.0101  Val NMSE: 0.0037  Val NMSE_dB: -24.334842 dB  TrainTime: 1.21s
# [185/1000] TrainLoss: 0.000604  ValLoss: 0.000099  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.491816 dB  TrainTime: 1.21s
# [186/1000] TrainLoss: 0.000604  ValLoss: 0.000105  Val RMSE: 0.0102  Val NMSE: 0.0038  Val NMSE_dB: -24.258421 dB  TrainTime: 1.38s
# [187/1000] TrainLoss: 0.000606  ValLoss: 0.000104  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.286313 dB  TrainTime: 1.20s
# [188/1000] TrainLoss: 0.000607  ValLoss: 0.000100  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.447225 dB  TrainTime: 1.10s
# [189/1000] TrainLoss: 0.000610  ValLoss: 0.000086  Val RMSE: 0.0093  Val NMSE: 0.0031  Val NMSE_dB: -25.100901 dB  TrainTime: 1.15s
# [190/1000] TrainLoss: 0.000606  ValLoss: 0.000100  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.455088 dB  TrainTime: 1.37s
# [191/1000] TrainLoss: 0.000604  ValLoss: 0.000083  Val RMSE: 0.0091  Val NMSE: 0.0030  Val NMSE_dB: -25.289740 dB  TrainTime: 1.20s
# [192/1000] TrainLoss: 0.000602  ValLoss: 0.000084  Val RMSE: 0.0092  Val NMSE: 0.0030  Val NMSE_dB: -25.204774 dB  TrainTime: 3.39s
# [193/1000] TrainLoss: 0.000602  ValLoss: 0.000100  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.455884 dB  TrainTime: 1.14s
# [194/1000] TrainLoss: 0.000608  ValLoss: 0.000081  Val RMSE: 0.0090  Val NMSE: 0.0029  Val NMSE_dB: -25.350207 dB  TrainTime: 1.34s
# [195/1000] TrainLoss: 0.000604  ValLoss: 0.000103  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.317933 dB  TrainTime: 1.26s
# [196/1000] TrainLoss: 0.000602  ValLoss: 0.000093  Val RMSE: 0.0097  Val NMSE: 0.0033  Val NMSE_dB: -24.763976 dB  TrainTime: 1.20s
# [197/1000] TrainLoss: 0.000605  ValLoss: 0.000083  Val RMSE: 0.0091  Val NMSE: 0.0030  Val NMSE_dB: -25.244029 dB  TrainTime: 1.19s
# [198/1000] TrainLoss: 0.000602  ValLoss: 0.000101  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.426198 dB  TrainTime: 1.14s
# [199/1000] TrainLoss: 0.000604  ValLoss: 0.000086  Val RMSE: 0.0092  Val NMSE: 0.0031  Val NMSE_dB: -25.133718 dB  TrainTime: 1.16s
# [200/1000] TrainLoss: 0.000602  ValLoss: 0.000087  Val RMSE: 0.0093  Val NMSE: 0.0031  Val NMSE_dB: -25.059718 dB  TrainTime: 1.34s
# [201/1000] TrainLoss: 0.000603  ValLoss: 0.000096  Val RMSE: 0.0098  Val NMSE: 0.0034  Val NMSE_dB: -24.634362 dB  TrainTime: 1.18s
# [202/1000] TrainLoss: 0.000599  ValLoss: 0.000095  Val RMSE: 0.0098  Val NMSE: 0.0034  Val NMSE_dB: -24.657698 dB  TrainTime: 1.12s
# [203/1000] TrainLoss: 0.000599  ValLoss: 0.000097  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.572929 dB  TrainTime: 1.15s
# [204/1000] TrainLoss: 0.000599  ValLoss: 0.000094  Val RMSE: 0.0097  Val NMSE: 0.0034  Val NMSE_dB: -24.705891 dB  TrainTime: 1.14s
# [205/1000] TrainLoss: 0.000607  ValLoss: 0.000087  Val RMSE: 0.0093  Val NMSE: 0.0031  Val NMSE_dB: -25.039256 dB  TrainTime: 1.17s
# [206/1000] TrainLoss: 0.000603  ValLoss: 0.000097  Val RMSE: 0.0098  Val NMSE: 0.0035  Val NMSE_dB: -24.599379 dB  TrainTime: 1.34s
# [207/1000] TrainLoss: 0.000598  ValLoss: 0.000109  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.090676 dB  TrainTime: 1.18s
# [208/1000] TrainLoss: 0.000603  ValLoss: 0.000102  Val RMSE: 0.0101  Val NMSE: 0.0036  Val NMSE_dB: -24.381463 dB  TrainTime: 1.18s
# [209/1000] TrainLoss: 0.000599  ValLoss: 0.000079  Val RMSE: 0.0089  Val NMSE: 0.0028  Val NMSE_dB: -25.469890 dB  TrainTime: 1.12s
# [210/1000] TrainLoss: 0.000600  ValLoss: 0.000078  Val RMSE: 0.0088  Val NMSE: 0.0028  Val NMSE_dB: -25.561135 dB  TrainTime: 1.16s
# [211/1000] TrainLoss: 0.000600  ValLoss: 0.000085  Val RMSE: 0.0092  Val NMSE: 0.0030  Val NMSE_dB: -25.178522 dB  TrainTime: 1.31s
# [212/1000] TrainLoss: 0.000604  ValLoss: 0.000084  Val RMSE: 0.0092  Val NMSE: 0.0030  Val NMSE_dB: -25.192466 dB  TrainTime: 1.21s
# [213/1000] TrainLoss: 0.000598  ValLoss: 0.000084  Val RMSE: 0.0092  Val NMSE: 0.0030  Val NMSE_dB: -25.218512 dB  TrainTime: 1.17s
# [214/1000] TrainLoss: 0.000597  ValLoss: 0.000099  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.511825 dB  TrainTime: 1.16s
# [215/1000] TrainLoss: 0.000601  ValLoss: 0.000120  Val RMSE: 0.0110  Val NMSE: 0.0043  Val NMSE_dB: -23.656701 dB  TrainTime: 1.12s
# [216/1000] TrainLoss: 0.000601  ValLoss: 0.000081  Val RMSE: 0.0090  Val NMSE: 0.0029  Val NMSE_dB: -25.368409 dB  TrainTime: 1.28s
# [217/1000] TrainLoss: 0.000596  ValLoss: 0.000089  Val RMSE: 0.0094  Val NMSE: 0.0032  Val NMSE_dB: -24.978286 dB  TrainTime: 1.20s
# [218/1000] TrainLoss: 0.000599  ValLoss: 0.000083  Val RMSE: 0.0091  Val NMSE: 0.0030  Val NMSE_dB: -25.275068 dB  TrainTime: 1.17s
# [219/1000] TrainLoss: 0.000601  ValLoss: 0.000099  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.517648 dB  TrainTime: 3.41s
# [220/1000] TrainLoss: 0.000600  ValLoss: 0.000099  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.490808 dB  TrainTime: 1.38s
# [221/1000] TrainLoss: 0.000601  ValLoss: 0.000104  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.273620 dB  TrainTime: 1.27s
# [222/1000] TrainLoss: 0.000598  ValLoss: 0.000100  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.448923 dB  TrainTime: 1.21s
# [223/1000] TrainLoss: 0.000599  ValLoss: 0.000109  Val RMSE: 0.0105  Val NMSE: 0.0039  Val NMSE_dB: -24.063631 dB  TrainTime: 1.19s
# [224/1000] TrainLoss: 0.000599  ValLoss: 0.000099  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.518980 dB  TrainTime: 1.31s
# [225/1000] TrainLoss: 0.000597  ValLoss: 0.000135  Val RMSE: 0.0116  Val NMSE: 0.0048  Val NMSE_dB: -23.164418 dB  TrainTime: 1.22s
# [226/1000] TrainLoss: 0.000600  ValLoss: 0.000084  Val RMSE: 0.0092  Val NMSE: 0.0030  Val NMSE_dB: -25.202692 dB  TrainTime: 1.21s
# [227/1000] TrainLoss: 0.000596  ValLoss: 0.000099  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.513409 dB  TrainTime: 1.37s
# [228/1000] TrainLoss: 0.000597  ValLoss: 0.000102  Val RMSE: 0.0101  Val NMSE: 0.0036  Val NMSE_dB: -24.382162 dB  TrainTime: 1.17s
# [229/1000] TrainLoss: 0.000594  ValLoss: 0.000119  Val RMSE: 0.0109  Val NMSE: 0.0043  Val NMSE_dB: -23.711370 dB  TrainTime: 1.16s
# [230/1000] TrainLoss: 0.000600  ValLoss: 0.000085  Val RMSE: 0.0092  Val NMSE: 0.0030  Val NMSE_dB: -25.168048 dB  TrainTime: 1.12s
# [231/1000] TrainLoss: 0.000593  ValLoss: 0.000093  Val RMSE: 0.0097  Val NMSE: 0.0033  Val NMSE_dB: -24.751970 dB  TrainTime: 1.36s
# [232/1000] TrainLoss: 0.000598  ValLoss: 0.000075  Val RMSE: 0.0086  Val NMSE: 0.0027  Val NMSE_dB: -25.718216 dB  TrainTime: 1.18s
# [233/1000] TrainLoss: 0.000598  ValLoss: 0.000077  Val RMSE: 0.0088  Val NMSE: 0.0028  Val NMSE_dB: -25.578925 dB  TrainTime: 1.15s
# [234/1000] TrainLoss: 0.000593  ValLoss: 0.000122  Val RMSE: 0.0110  Val NMSE: 0.0044  Val NMSE_dB: -23.602981 dB  TrainTime: 1.20s
# [235/1000] TrainLoss: 0.000595  ValLoss: 0.000128  Val RMSE: 0.0113  Val NMSE: 0.0046  Val NMSE_dB: -23.394592 dB  TrainTime: 1.39s
# [236/1000] TrainLoss: 0.000599  ValLoss: 0.000099  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.514332 dB  TrainTime: 1.17s
# [237/1000] TrainLoss: 0.000597  ValLoss: 0.000098  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.554380 dB  TrainTime: 1.09s
# [238/1000] TrainLoss: 0.000594  ValLoss: 0.000082  Val RMSE: 0.0091  Val NMSE: 0.0030  Val NMSE_dB: -25.294307 dB  TrainTime: 1.35s
# [239/1000] TrainLoss: 0.000598  ValLoss: 0.000094  Val RMSE: 0.0097  Val NMSE: 0.0034  Val NMSE_dB: -24.723181 dB  TrainTime: 1.19s
# [240/1000] TrainLoss: 0.000593  ValLoss: 0.000086  Val RMSE: 0.0093  Val NMSE: 0.0031  Val NMSE_dB: -25.091414 dB  TrainTime: 1.13s
# [241/1000] TrainLoss: 0.000598  ValLoss: 0.000095  Val RMSE: 0.0097  Val NMSE: 0.0034  Val NMSE_dB: -24.692216 dB  TrainTime: 1.19s
# [242/1000] TrainLoss: 0.000595  ValLoss: 0.000080  Val RMSE: 0.0090  Val NMSE: 0.0029  Val NMSE_dB: -25.413844 dB  TrainTime: 1.34s
# [243/1000] TrainLoss: 0.000596  ValLoss: 0.000079  Val RMSE: 0.0089  Val NMSE: 0.0028  Val NMSE_dB: -25.466135 dB  TrainTime: 1.21s
# [244/1000] TrainLoss: 0.000593  ValLoss: 0.000091  Val RMSE: 0.0095  Val NMSE: 0.0032  Val NMSE_dB: -24.885216 dB  TrainTime: 1.20s
# [245/1000] TrainLoss: 0.000591  ValLoss: 0.000097  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.568509 dB  TrainTime: 3.43s
# [246/1000] TrainLoss: 0.000590  ValLoss: 0.000093  Val RMSE: 0.0097  Val NMSE: 0.0034  Val NMSE_dB: -24.746990 dB  TrainTime: 1.31s
# [247/1000] TrainLoss: 0.000594  ValLoss: 0.000083  Val RMSE: 0.0091  Val NMSE: 0.0030  Val NMSE_dB: -25.267376 dB  TrainTime: 1.20s
# [248/1000] TrainLoss: 0.000590  ValLoss: 0.000084  Val RMSE: 0.0092  Val NMSE: 0.0030  Val NMSE_dB: -25.188688 dB  TrainTime: 1.22s
# [249/1000] TrainLoss: 0.000589  ValLoss: 0.000135  Val RMSE: 0.0116  Val NMSE: 0.0048  Val NMSE_dB: -23.148925 dB  TrainTime: 1.20s
# [250/1000] TrainLoss: 0.000594  ValLoss: 0.000117  Val RMSE: 0.0108  Val NMSE: 0.0042  Val NMSE_dB: -23.778703 dB  TrainTime: 1.17s
# [251/1000] TrainLoss: 0.000596  ValLoss: 0.000104  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.273836 dB  TrainTime: 1.12s
# [252/1000] TrainLoss: 0.000587  ValLoss: 0.000115  Val RMSE: 0.0107  Val NMSE: 0.0041  Val NMSE_dB: -23.841020 dB  TrainTime: 1.28s
# [253/1000] TrainLoss: 0.000592  ValLoss: 0.000127  Val RMSE: 0.0113  Val NMSE: 0.0046  Val NMSE_dB: -23.410394 dB  TrainTime: 1.20s
# [254/1000] TrainLoss: 0.000593  ValLoss: 0.000108  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.135324 dB  TrainTime: 1.14s
# [255/1000] TrainLoss: 0.000593  ValLoss: 0.000100  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.467410 dB  TrainTime: 1.23s
# [256/1000] TrainLoss: 0.000593  ValLoss: 0.000127  Val RMSE: 0.0113  Val NMSE: 0.0046  Val NMSE_dB: -23.408475 dB  TrainTime: 1.25s
# [257/1000] TrainLoss: 0.000593  ValLoss: 0.000101  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.412374 dB  TrainTime: 1.24s
# [258/1000] TrainLoss: 0.000590  ValLoss: 0.000120  Val RMSE: 0.0110  Val NMSE: 0.0043  Val NMSE_dB: -23.662041 dB  TrainTime: 1.35s
# [259/1000] TrainLoss: 0.000591  ValLoss: 0.000099  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.502912 dB  TrainTime: 1.13s
# [260/1000] TrainLoss: 0.000594  ValLoss: 0.000105  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.239014 dB  TrainTime: 1.22s
# [261/1000] TrainLoss: 0.000592  ValLoss: 0.000094  Val RMSE: 0.0097  Val NMSE: 0.0034  Val NMSE_dB: -24.741679 dB  TrainTime: 1.27s
# [262/1000] TrainLoss: 0.000591  ValLoss: 0.000108  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.115691 dB  TrainTime: 1.22s
# [263/1000] TrainLoss: 0.000594  ValLoss: 0.000092  Val RMSE: 0.0096  Val NMSE: 0.0033  Val NMSE_dB: -24.824481 dB  TrainTime: 1.39s
# [264/1000] TrainLoss: 0.000584  ValLoss: 0.000099  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.508450 dB  TrainTime: 1.20s
# [265/1000] TrainLoss: 0.000598  ValLoss: 0.000112  Val RMSE: 0.0106  Val NMSE: 0.0040  Val NMSE_dB: -23.944572 dB  TrainTime: 1.16s
# [266/1000] TrainLoss: 0.000593  ValLoss: 0.000103  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.325093 dB  TrainTime: 1.28s
# [267/1000] TrainLoss: 0.000589  ValLoss: 0.000085  Val RMSE: 0.0092  Val NMSE: 0.0030  Val NMSE_dB: -25.173073 dB  TrainTime: 1.29s
# [268/1000] TrainLoss: 0.000589  ValLoss: 0.000108  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.109194 dB  TrainTime: 1.47s
# [269/1000] TrainLoss: 0.000589  ValLoss: 0.000100  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.438386 dB  TrainTime: 1.23s
# [270/1000] TrainLoss: 0.000593  ValLoss: 0.000116  Val RMSE: 0.0108  Val NMSE: 0.0042  Val NMSE_dB: -23.818361 dB  TrainTime: 1.19s
# [271/1000] TrainLoss: 0.000593  ValLoss: 0.000097  Val RMSE: 0.0098  Val NMSE: 0.0035  Val NMSE_dB: -24.605114 dB  TrainTime: 1.22s
# [272/1000] TrainLoss: 0.000587  ValLoss: 0.000088  Val RMSE: 0.0094  Val NMSE: 0.0032  Val NMSE_dB: -25.007371 dB  TrainTime: 3.81s
# [273/1000] TrainLoss: 0.000583  ValLoss: 0.000087  Val RMSE: 0.0093  Val NMSE: 0.0031  Val NMSE_dB: -25.084938 dB  TrainTime: 1.15s
# [274/1000] TrainLoss: 0.000585  ValLoss: 0.000101  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.417797 dB  TrainTime: 1.22s
# [275/1000] TrainLoss: 0.000590  ValLoss: 0.000102  Val RMSE: 0.0101  Val NMSE: 0.0037  Val NMSE_dB: -24.359482 dB  TrainTime: 1.25s
# [276/1000] TrainLoss: 0.000586  ValLoss: 0.000106  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.195708 dB  TrainTime: 1.36s
# [277/1000] TrainLoss: 0.000589  ValLoss: 0.000107  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.172469 dB  TrainTime: 1.24s
# [278/1000] TrainLoss: 0.000582  ValLoss: 0.000090  Val RMSE: 0.0095  Val NMSE: 0.0032  Val NMSE_dB: -24.912899 dB  TrainTime: 1.26s
# [279/1000] TrainLoss: 0.000588  ValLoss: 0.000102  Val RMSE: 0.0101  Val NMSE: 0.0036  Val NMSE_dB: -24.378742 dB  TrainTime: 1.38s
# [280/1000] TrainLoss: 0.000585  ValLoss: 0.000103  Val RMSE: 0.0101  Val NMSE: 0.0037  Val NMSE_dB: -24.339185 dB  TrainTime: 1.20s
# [281/1000] TrainLoss: 0.000587  ValLoss: 0.000103  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.306230 dB  TrainTime: 1.20s
# [282/1000] TrainLoss: 0.000588  ValLoss: 0.000088  Val RMSE: 0.0094  Val NMSE: 0.0032  Val NMSE_dB: -25.005907 dB  TrainTime: 1.19s
# [283/1000] TrainLoss: 0.000585  ValLoss: 0.000097  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.575454 dB  TrainTime: 1.34s
# [284/1000] TrainLoss: 0.000583  ValLoss: 0.000095  Val RMSE: 0.0098  Val NMSE: 0.0034  Val NMSE_dB: -24.655427 dB  TrainTime: 1.22s
# [285/1000] TrainLoss: 0.000586  ValLoss: 0.000081  Val RMSE: 0.0090  Val NMSE: 0.0029  Val NMSE_dB: -25.368124 dB  TrainTime: 1.18s
# [286/1000] TrainLoss: 0.000585  ValLoss: 0.000129  Val RMSE: 0.0114  Val NMSE: 0.0046  Val NMSE_dB: -23.334650 dB  TrainTime: 1.18s
# [287/1000] TrainLoss: 0.000587  ValLoss: 0.000100  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.474038 dB  TrainTime: 1.35s
# [288/1000] TrainLoss: 0.000581  ValLoss: 0.000104  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.274938 dB  TrainTime: 1.30s
# [289/1000] TrainLoss: 0.000588  ValLoss: 0.000110  Val RMSE: 0.0105  Val NMSE: 0.0039  Val NMSE_dB: -24.057733 dB  TrainTime: 1.37s
# [290/1000] TrainLoss: 0.000586  ValLoss: 0.000094  Val RMSE: 0.0097  Val NMSE: 0.0034  Val NMSE_dB: -24.716340 dB  TrainTime: 1.44s
# [291/1000] TrainLoss: 0.000584  ValLoss: 0.000105  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.229309 dB  TrainTime: 1.13s
# [292/1000] TrainLoss: 0.000594  ValLoss: 0.000094  Val RMSE: 0.0097  Val NMSE: 0.0034  Val NMSE_dB: -24.706584 dB  TrainTime: 1.43s
# [293/1000] TrainLoss: 0.000584  ValLoss: 0.000109  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.096227 dB  TrainTime: 1.43s
# [294/1000] TrainLoss: 0.000578  ValLoss: 0.000096  Val RMSE: 0.0098  Val NMSE: 0.0035  Val NMSE_dB: -24.611247 dB  TrainTime: 1.40s
# [295/1000] TrainLoss: 0.000583  ValLoss: 0.000081  Val RMSE: 0.0090  Val NMSE: 0.0029  Val NMSE_dB: -25.353435 dB  TrainTime: 1.14s
# [296/1000] TrainLoss: 0.000580  ValLoss: 0.000115  Val RMSE: 0.0107  Val NMSE: 0.0041  Val NMSE_dB: -23.836559 dB  TrainTime: 1.39s
# [297/1000] TrainLoss: 0.000579  ValLoss: 0.000087  Val RMSE: 0.0093  Val NMSE: 0.0031  Val NMSE_dB: -25.050866 dB  TrainTime: 3.95s
# [298/1000] TrainLoss: 0.000584  ValLoss: 0.000085  Val RMSE: 0.0092  Val NMSE: 0.0031  Val NMSE_dB: -25.147716 dB  TrainTime: 1.41s
# [299/1000] TrainLoss: 0.000586  ValLoss: 0.000105  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.232844 dB  TrainTime: 1.19s
# [300/1000] TrainLoss: 0.000583  ValLoss: 0.000121  Val RMSE: 0.0110  Val NMSE: 0.0044  Val NMSE_dB: -23.614916 dB  TrainTime: 1.20s
# [301/1000] TrainLoss: 0.000587  ValLoss: 0.000082  Val RMSE: 0.0090  Val NMSE: 0.0029  Val NMSE_dB: -25.334073 dB  TrainTime: 1.13s
# [302/1000] TrainLoss: 0.000585  ValLoss: 0.000104  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.274583 dB  TrainTime: 1.21s
# [303/1000] TrainLoss: 0.000583  ValLoss: 0.000119  Val RMSE: 0.0109  Val NMSE: 0.0043  Val NMSE_dB: -23.700401 dB  TrainTime: 1.20s
# [304/1000] TrainLoss: 0.000591  ValLoss: 0.000099  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.515063 dB  TrainTime: 1.51s
# [305/1000] TrainLoss: 0.000584  ValLoss: 0.000106  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.211225 dB  TrainTime: 1.16s
# [306/1000] TrainLoss: 0.000580  ValLoss: 0.000098  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.550390 dB  TrainTime: 1.23s
# [307/1000] TrainLoss: 0.000580  ValLoss: 0.000089  Val RMSE: 0.0094  Val NMSE: 0.0032  Val NMSE_dB: -24.978322 dB  TrainTime: 1.24s
# [308/1000] TrainLoss: 0.000578  ValLoss: 0.000097  Val RMSE: 0.0098  Val NMSE: 0.0035  Val NMSE_dB: -24.595113 dB  TrainTime: 1.24s
# [309/1000] TrainLoss: 0.000580  ValLoss: 0.000082  Val RMSE: 0.0091  Val NMSE: 0.0029  Val NMSE_dB: -25.310981 dB  TrainTime: 1.15s
# [310/1000] TrainLoss: 0.000580  ValLoss: 0.000126  Val RMSE: 0.0112  Val NMSE: 0.0045  Val NMSE_dB: -23.437658 dB  TrainTime: 1.34s
# [311/1000] TrainLoss: 0.000583  ValLoss: 0.000086  Val RMSE: 0.0093  Val NMSE: 0.0031  Val NMSE_dB: -25.114615 dB  TrainTime: 1.22s
# [312/1000] TrainLoss: 0.000585  ValLoss: 0.000095  Val RMSE: 0.0097  Val NMSE: 0.0034  Val NMSE_dB: -24.689846 dB  TrainTime: 1.19s
# [313/1000] TrainLoss: 0.000581  ValLoss: 0.000067  Val RMSE: 0.0082  Val NMSE: 0.0024  Val NMSE_dB: -26.167112 dB  TrainTime: 1.21s
# [314/1000] TrainLoss: 0.000579  ValLoss: 0.000086  Val RMSE: 0.0093  Val NMSE: 0.0031  Val NMSE_dB: -25.117228 dB  TrainTime: 1.20s
# [315/1000] TrainLoss: 0.000583  ValLoss: 0.000103  Val RMSE: 0.0101  Val NMSE: 0.0037  Val NMSE_dB: -24.346209 dB  TrainTime: 1.36s
# [316/1000] TrainLoss: 0.000588  ValLoss: 0.000100  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.449028 dB  TrainTime: 1.24s
# [317/1000] TrainLoss: 0.000586  ValLoss: 0.000114  Val RMSE: 0.0107  Val NMSE: 0.0041  Val NMSE_dB: -23.876082 dB  TrainTime: 1.23s
# [318/1000] TrainLoss: 0.000577  ValLoss: 0.000090  Val RMSE: 0.0095  Val NMSE: 0.0032  Val NMSE_dB: -24.909193 dB  TrainTime: 1.23s
# [319/1000] TrainLoss: 0.000578  ValLoss: 0.000100  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.447551 dB  TrainTime: 1.25s
# [320/1000] TrainLoss: 0.000583  ValLoss: 0.000092  Val RMSE: 0.0096  Val NMSE: 0.0033  Val NMSE_dB: -24.811332 dB  TrainTime: 1.38s
# [321/1000] TrainLoss: 0.000583  ValLoss: 0.000083  Val RMSE: 0.0091  Val NMSE: 0.0030  Val NMSE_dB: -25.244818 dB  TrainTime: 1.23s
# [322/1000] TrainLoss: 0.000577  ValLoss: 0.000128  Val RMSE: 0.0113  Val NMSE: 0.0046  Val NMSE_dB: -23.395029 dB  TrainTime: 1.22s
# [323/1000] TrainLoss: 0.000580  ValLoss: 0.000090  Val RMSE: 0.0095  Val NMSE: 0.0032  Val NMSE_dB: -24.921907 dB  TrainTime: 3.69s
# [324/1000] TrainLoss: 0.000581  ValLoss: 0.000083  Val RMSE: 0.0091  Val NMSE: 0.0030  Val NMSE_dB: -25.257113 dB  TrainTime: 1.38s
# [325/1000] TrainLoss: 0.000579  ValLoss: 0.000100  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.440549 dB  TrainTime: 1.24s
# [326/1000] TrainLoss: 0.000582  ValLoss: 0.000106  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.221915 dB  TrainTime: 1.22s
# [327/1000] TrainLoss: 0.000579  ValLoss: 0.000097  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.574320 dB  TrainTime: 1.24s
# [328/1000] TrainLoss: 0.000585  ValLoss: 0.000090  Val RMSE: 0.0095  Val NMSE: 0.0032  Val NMSE_dB: -24.916951 dB  TrainTime: 1.37s
# [329/1000] TrainLoss: 0.000579  ValLoss: 0.000103  Val RMSE: 0.0101  Val NMSE: 0.0037  Val NMSE_dB: -24.329885 dB  TrainTime: 1.17s
# [330/1000] TrainLoss: 0.000581  ValLoss: 0.000074  Val RMSE: 0.0086  Val NMSE: 0.0026  Val NMSE_dB: -25.782047 dB  TrainTime: 1.18s
# [331/1000] TrainLoss: 0.000578  ValLoss: 0.000106  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.213330 dB  TrainTime: 1.33s
# [332/1000] TrainLoss: 0.000578  ValLoss: 0.000087  Val RMSE: 0.0093  Val NMSE: 0.0031  Val NMSE_dB: -25.054474 dB  TrainTime: 1.24s
# [333/1000] TrainLoss: 0.000579  ValLoss: 0.000107  Val RMSE: 0.0103  Val NMSE: 0.0038  Val NMSE_dB: -24.175899 dB  TrainTime: 1.21s
# [334/1000] TrainLoss: 0.000578  ValLoss: 0.000100  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.463939 dB  TrainTime: 1.30s
# [335/1000] TrainLoss: 0.000579  ValLoss: 0.000134  Val RMSE: 0.0116  Val NMSE: 0.0048  Val NMSE_dB: -23.193140 dB  TrainTime: 1.40s
# [336/1000] TrainLoss: 0.000580  ValLoss: 0.000093  Val RMSE: 0.0097  Val NMSE: 0.0033  Val NMSE_dB: -24.758503 dB  TrainTime: 1.22s
# [337/1000] TrainLoss: 0.000579  ValLoss: 0.000080  Val RMSE: 0.0090  Val NMSE: 0.0029  Val NMSE_dB: -25.418108 dB  TrainTime: 1.14s
# [338/1000] TrainLoss: 0.000577  ValLoss: 0.000116  Val RMSE: 0.0108  Val NMSE: 0.0042  Val NMSE_dB: -23.794085 dB  TrainTime: 1.09s
# [339/1000] TrainLoss: 0.000584  ValLoss: 0.000111  Val RMSE: 0.0105  Val NMSE: 0.0040  Val NMSE_dB: -23.996628 dB  TrainTime: 1.34s
# [340/1000] TrainLoss: 0.000580  ValLoss: 0.000113  Val RMSE: 0.0106  Val NMSE: 0.0041  Val NMSE_dB: -23.915340 dB  TrainTime: 1.18s
# [341/1000] TrainLoss: 0.000574  ValLoss: 0.000085  Val RMSE: 0.0092  Val NMSE: 0.0031  Val NMSE_dB: -25.149404 dB  TrainTime: 1.20s
# [342/1000] TrainLoss: 0.000579  ValLoss: 0.000126  Val RMSE: 0.0112  Val NMSE: 0.0045  Val NMSE_dB: -23.454935 dB  TrainTime: 1.37s
# [343/1000] TrainLoss: 0.000579  ValLoss: 0.000089  Val RMSE: 0.0094  Val NMSE: 0.0032  Val NMSE_dB: -24.952334 dB  TrainTime: 1.23s
# [344/1000] TrainLoss: 0.000579  ValLoss: 0.000093  Val RMSE: 0.0097  Val NMSE: 0.0033  Val NMSE_dB: -24.750211 dB  TrainTime: 1.23s
# [345/1000] TrainLoss: 0.000576  ValLoss: 0.000115  Val RMSE: 0.0107  Val NMSE: 0.0041  Val NMSE_dB: -23.843226 dB  TrainTime: 1.21s
# [346/1000] TrainLoss: 0.000580  ValLoss: 0.000119  Val RMSE: 0.0109  Val NMSE: 0.0043  Val NMSE_dB: -23.712079 dB  TrainTime: 1.37s
# [347/1000] TrainLoss: 0.000575  ValLoss: 0.000099  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.484600 dB  TrainTime: 1.21s
# [348/1000] TrainLoss: 0.000575  ValLoss: 0.000104  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.289764 dB  TrainTime: 1.26s
# [349/1000] TrainLoss: 0.000577  ValLoss: 0.000101  Val RMSE: 0.0100  Val NMSE: 0.0036  Val NMSE_dB: -24.416250 dB  TrainTime: 3.66s
# [350/1000] TrainLoss: 0.000578  ValLoss: 0.000102  Val RMSE: 0.0101  Val NMSE: 0.0037  Val NMSE_dB: -24.369449 dB  TrainTime: 1.34s
# [351/1000] TrainLoss: 0.000575  ValLoss: 0.000118  Val RMSE: 0.0109  Val NMSE: 0.0042  Val NMSE_dB: -23.731238 dB  TrainTime: 1.20s
# [352/1000] TrainLoss: 0.000574  ValLoss: 0.000116  Val RMSE: 0.0108  Val NMSE: 0.0042  Val NMSE_dB: -23.813859 dB  TrainTime: 1.18s
# [353/1000] TrainLoss: 0.000577  ValLoss: 0.000094  Val RMSE: 0.0097  Val NMSE: 0.0034  Val NMSE_dB: -24.737628 dB  TrainTime: 1.20s
# [354/1000] TrainLoss: 0.000577  ValLoss: 0.000077  Val RMSE: 0.0088  Val NMSE: 0.0028  Val NMSE_dB: -25.566947 dB  TrainTime: 1.22s
# [355/1000] TrainLoss: 0.000571  ValLoss: 0.000098  Val RMSE: 0.0099  Val NMSE: 0.0035  Val NMSE_dB: -24.539151 dB  TrainTime: 1.19s
# [356/1000] TrainLoss: 0.000574  ValLoss: 0.000104  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.300862 dB  TrainTime: 1.33s
# [357/1000] TrainLoss: 0.000577  ValLoss: 0.000122  Val RMSE: 0.0111  Val NMSE: 0.0044  Val NMSE_dB: -23.582015 dB  TrainTime: 1.20s
# [358/1000] TrainLoss: 0.000577  ValLoss: 0.000096  Val RMSE: 0.0098  Val NMSE: 0.0034  Val NMSE_dB: -24.648332 dB  TrainTime: 1.18s
# [359/1000] TrainLoss: 0.000570  ValLoss: 0.000102  Val RMSE: 0.0101  Val NMSE: 0.0036  Val NMSE_dB: -24.386519 dB  TrainTime: 1.17s
# [360/1000] TrainLoss: 0.000574  ValLoss: 0.000109  Val RMSE: 0.0104  Val NMSE: 0.0039  Val NMSE_dB: -24.092377 dB  TrainTime: 1.16s
# [361/1000] TrainLoss: 0.000572  ValLoss: 0.000104  Val RMSE: 0.0102  Val NMSE: 0.0037  Val NMSE_dB: -24.291690 dB  TrainTime: 1.18s
# [362/1000] TrainLoss: 0.000579  ValLoss: 0.000089  Val RMSE: 0.0094  Val NMSE: 0.0032  Val NMSE_dB: -24.983042 dB  TrainTime: 1.30s
# [363/1000] TrainLoss: 0.000576  ValLoss: 0.000110  Val RMSE: 0.0105  Val NMSE: 0.0039  Val NMSE_dB: -24.048227 dB  TrainTime: 1.19s
# [364/1000] TrainLoss: 0.000576  ValLoss: 0.000105  Val RMSE: 0.0102  Val NMSE: 0.0038  Val NMSE_dB: -24.245560 dB  TrainTime: 1.18s
# ...
# [883/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0003  Val NMSE: 0.0000  Val NMSE_dB: -56.199783 dB  TrainTime: 6.92s
# [884/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0006  Val NMSE: 0.0000  Val NMSE_dB: -48.320126 dB  TrainTime: 6.98s
# [885/1000] TrainLoss: 0.000000  ValLoss: 0.000001  Val RMSE: 0.0010  Val NMSE: 0.0000  Val NMSE_dB: -44.657395 dB  TrainTime: 7.02s
# [886/1000] TrainLoss: 0.000001  ValLoss: 0.000001  Val RMSE: 0.0008  Val NMSE: 0.0000  Val NMSE_dB: -46.656630 dB  TrainTime: 7.58s
# [887/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0005  Val NMSE: 0.0000  Val NMSE_dB: -50.357348 dB  TrainTime: 9.90s
# [888/1000] TrainLoss: 0.000001  ValLoss: 0.000002  Val RMSE: 0.0016  Val NMSE: 0.0001  Val NMSE_dB: -40.594615 dB  TrainTime: 7.15s
# [889/1000] TrainLoss: 0.000001  ValLoss: 0.000002  Val RMSE: 0.0014  Val NMSE: 0.0001  Val NMSE_dB: -41.462231 dB  TrainTime: 7.39s
# [890/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -52.801023 dB  TrainTime: 7.14s
# [891/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0003  Val NMSE: 0.0000  Val NMSE_dB: -54.961630 dB  TrainTime: 9.05s
# [892/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0006  Val NMSE: 0.0000  Val NMSE_dB: -48.424943 dB  TrainTime: 6.93s
# [893/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -60.251636 dB  TrainTime: 7.10s
# [894/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -51.683136 dB  TrainTime: 7.34s
# [895/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0006  Val NMSE: 0.0000  Val NMSE_dB: -48.697812 dB  TrainTime: 9.63s
# [896/1000] TrainLoss: 0.000001  ValLoss: 0.000001  Val RMSE: 0.0008  Val NMSE: 0.0000  Val NMSE_dB: -46.469876 dB  TrainTime: 7.40s
# [897/1000] TrainLoss: 0.000000  ValLoss: 0.000008  Val RMSE: 0.0029  Val NMSE: 0.0003  Val NMSE_dB: -35.165754 dB  TrainTime: 6.92s
# [898/1000] TrainLoss: 0.000004  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -56.615141 dB  TrainTime: 6.92s
# [899/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -60.301097 dB  TrainTime: 7.25s
# [900/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -59.721208 dB  TrainTime: 9.23s
# [901/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -51.422581 dB  TrainTime: 7.14s
# [902/1000] TrainLoss: 0.000000  ValLoss: 0.000002  Val RMSE: 0.0015  Val NMSE: 0.0001  Val NMSE_dB: -41.040946 dB  TrainTime: 7.23s
# [903/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -58.867926 dB  TrainTime: 7.09s
# [904/1000] TrainLoss: 0.000002  ValLoss: 0.000000  Val RMSE: 0.0007  Val NMSE: 0.0000  Val NMSE_dB: -48.049815 dB  TrainTime: 7.14s
# [905/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0001  Val NMSE: 0.0000  Val NMSE_dB: -60.960861 dB  TrainTime: 9.10s
# [906/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -52.116808 dB  TrainTime: 7.27s
# [907/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0005  Val NMSE: 0.0000  Val NMSE_dB: -51.250873 dB  TrainTime: 7.07s
# [908/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -51.713534 dB  TrainTime: 6.97s
# [909/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -56.740324 dB  TrainTime: 9.31s
# [910/1000] TrainLoss: 0.000000  ValLoss: 0.000001  Val RMSE: 0.0008  Val NMSE: 0.0000  Val NMSE_dB: -46.718371 dB  TrainTime: 7.07s
# [911/1000] TrainLoss: 0.000001  ValLoss: 0.000001  Val RMSE: 0.0008  Val NMSE: 0.0000  Val NMSE_dB: -46.723724 dB  TrainTime: 7.46s
# [912/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -58.085759 dB  TrainTime: 7.17s
# [913/1000] TrainLoss: 0.000004  ValLoss: 0.000000  Val RMSE: 0.0001  Val NMSE: 0.0000  Val NMSE_dB: -61.569160 dB  TrainTime: 7.19s
# [914/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0003  Val NMSE: 0.0000  Val NMSE_dB: -54.605276 dB  TrainTime: 9.53s
# [915/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -53.069312 dB  TrainTime: 7.52s
# [916/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -60.405584 dB  TrainTime: 7.36s
# [917/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0003  Val NMSE: 0.0000  Val NMSE_dB: -55.412069 dB  TrainTime: 7.24s
# [918/1000] TrainLoss: 0.000000  ValLoss: 0.000001  Val RMSE: 0.0012  Val NMSE: 0.0001  Val NMSE_dB: -42.835572 dB  TrainTime: 9.50s
# [919/1000] TrainLoss: 0.000000  ValLoss: 0.000001  Val RMSE: 0.0010  Val NMSE: 0.0000  Val NMSE_dB: -44.549850 dB  TrainTime: 7.47s
# [920/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0003  Val NMSE: 0.0000  Val NMSE_dB: -55.205391 dB  TrainTime: 7.37s
# [921/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0005  Val NMSE: 0.0000  Val NMSE_dB: -49.664034 dB  TrainTime: 7.31s
# [922/1000] TrainLoss: 0.000000  ValLoss: 0.000001  Val RMSE: 0.0008  Val NMSE: 0.0000  Val NMSE_dB: -46.697490 dB  TrainTime: 7.08s
# [923/1000] TrainLoss: 0.000001  ValLoss: 0.000004  Val RMSE: 0.0019  Val NMSE: 0.0001  Val NMSE_dB: -38.689426 dB  TrainTime: 9.40s
# [924/1000] TrainLoss: 0.000002  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -57.862283 dB  TrainTime: 7.17s
# [925/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0006  Val NMSE: 0.0000  Val NMSE_dB: -48.525570 dB  TrainTime: 7.04s
# [926/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0006  Val NMSE: 0.0000  Val NMSE_dB: -49.067350 dB  TrainTime: 7.43s
# [927/1000] TrainLoss: 0.000001  ValLoss: 0.000001  Val RMSE: 0.0007  Val NMSE: 0.0000  Val NMSE_dB: -47.422471 dB  TrainTime: 9.89s
# [928/1000] TrainLoss: 0.000000  ValLoss: 0.000001  Val RMSE: 0.0009  Val NMSE: 0.0000  Val NMSE_dB: -44.945611 dB  TrainTime: 7.23s
# [929/1000] TrainLoss: 0.000001  ValLoss: 0.000001  Val RMSE: 0.0010  Val NMSE: 0.0000  Val NMSE_dB: -44.523008 dB  TrainTime: 7.68s
# [930/1000] TrainLoss: 0.000001  ValLoss: 0.000001  Val RMSE: 0.0009  Val NMSE: 0.0000  Val NMSE_dB: -44.939340 dB  TrainTime: 8.01s
# [931/1000] TrainLoss: 0.000000  ValLoss: 0.000001  Val RMSE: 0.0009  Val NMSE: 0.0000  Val NMSE_dB: -45.185906 dB  TrainTime: 10.36s
# [932/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -52.152523 dB  TrainTime: 7.25s
# [933/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -52.264464 dB  TrainTime: 7.17s
# [934/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0007  Val NMSE: 0.0000  Val NMSE_dB: -47.554770 dB  TrainTime: 7.74s
# [935/1000] TrainLoss: 0.000000  ValLoss: 0.000001  Val RMSE: 0.0011  Val NMSE: 0.0000  Val NMSE_dB: -43.262063 dB  TrainTime: 7.85s
# [936/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -51.778850 dB  TrainTime: 10.39s
# [937/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0006  Val NMSE: 0.0000  Val NMSE_dB: -49.570278 dB  TrainTime: 7.32s
# [938/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -52.956195 dB  TrainTime: 7.76s
# [939/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -58.411728 dB  TrainTime: 7.45s
# [940/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -52.893966 dB  TrainTime: 9.60s
# [941/1000] TrainLoss: 0.000001  ValLoss: 0.000001  Val RMSE: 0.0009  Val NMSE: 0.0000  Val NMSE_dB: -45.461836 dB  TrainTime: 7.31s
# [942/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0003  Val NMSE: 0.0000  Val NMSE_dB: -54.481022 dB  TrainTime: 7.62s
# [943/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -60.730232 dB  TrainTime: 7.49s
# [944/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -57.865540 dB  TrainTime: 9.83s
# [945/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -51.625741 dB  TrainTime: 7.45s
# [946/1000] TrainLoss: 0.000001  ValLoss: 0.000001  Val RMSE: 0.0008  Val NMSE: 0.0000  Val NMSE_dB: -46.442692 dB  TrainTime: 7.77s
# [947/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0005  Val NMSE: 0.0000  Val NMSE_dB: -49.761967 dB  TrainTime: 7.68s
# [948/1000] TrainLoss: 0.000001  ValLoss: 0.000001  Val RMSE: 0.0012  Val NMSE: 0.0000  Val NMSE_dB: -43.043691 dB  TrainTime: 10.14s
# [949/1000] TrainLoss: 0.000003  ValLoss: 0.000000  Val RMSE: 0.0001  Val NMSE: 0.0000  Val NMSE_dB: -61.393647 dB  TrainTime: 8.09s
# [950/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -58.746549 dB  TrainTime: 8.00s
# [951/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0001  Val NMSE: 0.0000  Val NMSE_dB: -61.666864 dB  TrainTime: 7.40s
# [952/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -57.897201 dB  TrainTime: 7.28s
# [953/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0005  Val NMSE: 0.0000  Val NMSE_dB: -50.883518 dB  TrainTime: 9.92s
# [954/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0005  Val NMSE: 0.0000  Val NMSE_dB: -50.423241 dB  TrainTime: 8.35s
# [955/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -51.414428 dB  TrainTime: 7.19s
# [956/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0003  Val NMSE: 0.0000  Val NMSE_dB: -54.907368 dB  TrainTime: 7.55s
# [957/1000] TrainLoss: 0.000001  ValLoss: 0.000001  Val RMSE: 0.0010  Val NMSE: 0.0000  Val NMSE_dB: -44.354088 dB  TrainTime: 10.05s
# [958/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0001  Val NMSE: 0.0000  Val NMSE_dB: -61.454578 dB  TrainTime: 7.02s
# [959/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0001  Val NMSE: 0.0000  Val NMSE_dB: -62.602680 dB  TrainTime: 6.88s
# [960/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0007  Val NMSE: 0.0000  Val NMSE_dB: -48.075666 dB  TrainTime: 7.02s
# [961/1000] TrainLoss: 0.000001  ValLoss: 0.000001  Val RMSE: 0.0009  Val NMSE: 0.0000  Val NMSE_dB: -45.360238 dB  TrainTime: 9.90s
# [962/1000] TrainLoss: 0.000000  ValLoss: 0.000002  Val RMSE: 0.0014  Val NMSE: 0.0001  Val NMSE_dB: -41.827794 dB  TrainTime: 6.81s
# [963/1000] TrainLoss: 0.000001  ValLoss: 0.000001  Val RMSE: 0.0011  Val NMSE: 0.0000  Val NMSE_dB: -43.564980 dB  TrainTime: 6.68s
# [964/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -60.025517 dB  TrainTime: 6.85s
# [965/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0005  Val NMSE: 0.0000  Val NMSE_dB: -51.114983 dB  TrainTime: 6.92s
# [966/1000] TrainLoss: 0.000000  ValLoss: 0.000001  Val RMSE: 0.0010  Val NMSE: 0.0000  Val NMSE_dB: -44.835478 dB  TrainTime: 9.69s
# [967/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -51.842108 dB  TrainTime: 6.91s
# [968/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -52.543514 dB  TrainTime: 8.14s
# [969/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0001  Val NMSE: 0.0000  Val NMSE_dB: -64.522587 dB  TrainTime: 7.54s
# [970/1000] TrainLoss: 0.000000  ValLoss: 0.000001  Val RMSE: 0.0010  Val NMSE: 0.0000  Val NMSE_dB: -44.806390 dB  TrainTime: 10.11s
# [971/1000] TrainLoss: 0.000013  ValLoss: 0.000000  Val RMSE: 0.0003  Val NMSE: 0.0000  Val NMSE_dB: -54.983910 dB  TrainTime: 7.83s
# [972/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -59.431942 dB  TrainTime: 7.36s
# [973/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -58.916304 dB  TrainTime: 7.45s
# [974/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -59.881076 dB  TrainTime: 7.97s
# [975/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0001  Val NMSE: 0.0000  Val NMSE_dB: -61.675986 dB  TrainTime: 9.90s
# [976/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0001  Val NMSE: 0.0000  Val NMSE_dB: -64.055127 dB  TrainTime: 8.05s
# [977/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0001  Val NMSE: 0.0000  Val NMSE_dB: -61.056155 dB  TrainTime: 7.54s
# [978/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0001  Val NMSE: 0.0000  Val NMSE_dB: -63.690223 dB  TrainTime: 7.73s
# [979/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -58.509396 dB  TrainTime: 10.07s
# [980/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -60.370565 dB  TrainTime: 7.24s
# [981/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0005  Val NMSE: 0.0000  Val NMSE_dB: -49.655813 dB  TrainTime: 7.50s
# [982/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0005  Val NMSE: 0.0000  Val NMSE_dB: -49.946453 dB  TrainTime: 8.95s
# [983/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -51.681261 dB  TrainTime: 9.57s
# [984/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0006  Val NMSE: 0.0000  Val NMSE_dB: -49.313790 dB  TrainTime: 7.62s
# [985/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -58.338195 dB  TrainTime: 7.25s
# [986/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -56.613888 dB  TrainTime: 7.74s
# [987/1000] TrainLoss: 0.000000  ValLoss: 0.000003  Val RMSE: 0.0018  Val NMSE: 0.0001  Val NMSE_dB: -39.396103 dB  TrainTime: 9.55s
# [988/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -57.715667 dB  TrainTime: 7.62s
# [989/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -52.345565 dB  TrainTime: 8.53s
# [990/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -52.483961 dB  TrainTime: 7.85s
# [991/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -53.275215 dB  TrainTime: 7.52s
# [992/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -52.812240 dB  TrainTime: 9.70s
# [993/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0005  Val NMSE: 0.0000  Val NMSE_dB: -50.637979 dB  TrainTime: 7.21s
# [994/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0006  Val NMSE: 0.0000  Val NMSE_dB: -48.993849 dB  TrainTime: 7.18s
# [995/1000] TrainLoss: 0.000001  ValLoss: 0.000000  Val RMSE: 0.0003  Val NMSE: 0.0000  Val NMSE_dB: -55.955881 dB  TrainTime: 7.05s
# [996/1000] TrainLoss: 0.000000  ValLoss: 0.000003  Val RMSE: 0.0019  Val NMSE: 0.0001  Val NMSE_dB: -39.027156 dB  TrainTime: 9.38s
# [997/1000] TrainLoss: 0.000003  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -60.662214 dB  TrainTime: 7.05s
# [998/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -60.165415 dB  TrainTime: 7.03s
# [999/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0004  Val NMSE: 0.0000  Val NMSE_dB: -51.956483 dB  TrainTime: 7.11s
# [1000/1000] TrainLoss: 0.000000  ValLoss: 0.000000  Val RMSE: 0.0002  Val NMSE: 0.0000  Val NMSE_dB: -59.605090 dB  TrainTime: 6.98s
# ============================================================
# => Best ValLoss   : 0.000000   (epoch 969)
# => Best Val NMSE  : 0.0000   (epoch 969)
# => Best Val RMSE  : 0.0001   (epoch 969)
# => Best Val NMSE_dB: -64.5226 dB (epoch 969)
# ============================================================
#
# LWM training log saved to /home/dlghdbs200/LWM_denver/LWM_epoch1000_user.txt

# %% [markdown]
# # inference time

# %%
x_single, y_single = val_set[0]
#x_single.shape [1,8,1,2]
x_single = x_single.unsqueeze(0).to(device)
y_single = y_single.unsqueeze(0).to(device)

# %%
x_gpu.shape
# Out:
# torch.Size([1, 1, 8, 1, 2])
