# %% [markdown]
# # Library

# %%
import pandas as pd
import matplotlib as plt
import re

# %% [markdown]
# # LWM

# %%
file_path = "LWM_epoch150_antenna.txt"

LWM_train_pattern = re.compile(r"TrainLoss:\s*([0-9.]+)")
LWM_val_pattern = re.compile(r"ValLoss:\s*([0-9.]+)")
LWM_NMSE_dB_pattern = re.compile(r"Val NMSE_dB:\s*([-0-9.]+)")

LWM_train_loss = []
LWM_val_loss = []
LWM_NMSE_dB = []

# read file
with open(file_path, "r") as f:
    for line in f:
        train_loss = LWM_train_pattern.search(line)
        val_loss = LWM_val_pattern.search(line)
        NMSE_dB = LWM_NMSE_dB_pattern.search(line)

        if train_loss and val_loss and NMSE_dB:
            LWM_train_loss.append(float(train_loss.group(1)))
            LWM_val_loss.append(float(val_loss.group(1)))
            LWM_NMSE_dB.append(float(NMSE_dB.group(1)))

print("Train_loss : ",LWM_train_loss[:10])
print("Val loss: ",LWM_val_loss[:10])
print("NMSE_dB : ",LWM_NMSE_dB[:10])
# Out:
# Train_loss :  [0.034498, 0.016886, 0.008144, 0.00737, 0.006983, 0.006737, 0.006582, 0.006421, 0.006346, 0.006283]
# Val loss:  [0.026478, 0.008052, 0.00698, 0.006767, 0.006531, 0.006698, 0.006413, 0.00637, 0.006378, 0.00617]
# NMSE_dB :  [-0.306701, -5.501832, -6.112752, -6.238443, -6.385355, -6.246545, -6.468886, -6.481504, -6.477755, -6.632496]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(LWM_train_loss, label='Train Loss')
plt.plot(LWM_val_loss, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('LWM Training and Validation Loss')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

plt.figure(figsize=(10,5))
plt.plot(LWM_NMSE_dB, label='Val NMSE (dB)', color='green')
plt.xlabel('Epoch')
plt.ylabel('NMSE (dB)')
plt.title('Validation NMSE (dB) over Epochs')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# # CNN

# %%
file_path = "CNN_epoch500_antenna.txt"

CNN_train_pattern = re.compile(r"TrainLoss:\s*([0-9.]+)")
CNN_val_pattern = re.compile(r"ValLoss:\s*([0-9.]+)")
CNN_NMSE_dB_pattern = re.compile(r"Val NMSE_dB:\s*([-0-9.]+)")

CNN_train_loss = []
CNN_val_loss = []
CNN_NMSE_dB = []

# read file
with open(file_path, "r") as f:
    for line in f:
        train_loss = CNN_train_pattern.search(line)
        val_loss = CNN_val_pattern.search(line)
        NMSE_dB = CNN_NMSE_dB_pattern.search(line)

        if train_loss and val_loss and NMSE_dB:
            CNN_train_loss.append(float(train_loss.group(1)))
            CNN_val_loss.append(float(val_loss.group(1)))
            CNN_NMSE_dB.append(float(NMSE_dB.group(1)))

print("Train_loss : ",CNN_train_loss[:10])
print("Val loss: ",CNN_val_loss[:10])
print("NMSE_dB : ",CNN_NMSE_dB[:10])
# Out:
# Train_loss :  [0.012462, 0.006746, 0.006441, 0.006309, 0.006235, 0.006168, 0.006109, 0.006083, 0.006047, 0.006021]
# Val loss:  [0.007254, 0.006739, 0.006827, 0.006484, 0.006406, 0.006322, 0.006456, 0.006298, 0.006316, 0.00636]
# NMSE_dB :  [-5.969443, -6.26215, -6.181576, -6.419889, -6.4722, -6.531012, -6.436716, -6.541573, -6.534811, -6.479689]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(CNN_train_loss, label='Train Loss')
plt.plot(CNN_val_loss, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('CNN Training and Validation Loss')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

plt.figure(figsize=(10,5))
plt.plot(CNN_NMSE_dB, label='Val NMSE (dB)', color='green')
plt.xlabel('Epoch')
plt.ylabel('NMSE (dB)')
plt.title('Validation NMSE (dB) over Epochs')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# # MLP

# %%
file_path = "MLP_epoch500_antenna.txt"

MLP_train_pattern = re.compile(r"TrainLoss:\s*([0-9.]+)")
MLP_val_pattern = re.compile(r"ValLoss:\s*([0-9.]+)")
MLP_NMSE_dB_pattern = re.compile(r"Val NMSE_dB:\s*([-0-9.]+)")

MLP_train_loss = []
MLP_val_loss = []
MLP_NMSE_dB = []

# read file
with open(file_path, "r") as f:
    for line in f:
        train_loss = MLP_train_pattern.search(line)
        val_loss = MLP_val_pattern.search(line)
        NMSE_dB = MLP_NMSE_dB_pattern.search(line)

        if train_loss and val_loss and NMSE_dB:
            MLP_train_loss.append(float(train_loss.group(1)))
            MLP_val_loss.append(float(val_loss.group(1)))
            MLP_NMSE_dB.append(float(NMSE_dB.group(1)))

print("Train_loss : ",MLP_train_loss[:10])
print("Val loss: ",MLP_val_loss[:10])
print("NMSE_dB : ",MLP_NMSE_dB[:10])
# Out:
# Train_loss :  [0.010325, 0.007134, 0.006727, 0.006544, 0.006405, 0.006332, 0.006275, 0.006203, 0.006162, 0.006127]
# Val loss:  [0.006837, 0.006493, 0.006298, 0.006252, 0.00618, 0.006093, 0.006138, 0.006027, 0.00602, 0.006035]
# NMSE_dB :  [-6.23485, -6.43548, -6.551085, -6.573792, -6.61934, -6.681349, -6.654241, -6.731905, -6.738804, -6.71979]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(MLP_train_loss, label='Train Loss')
plt.plot(MLP_val_loss, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('MLP Training and Validation Loss')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

plt.figure(figsize=(10,5))
plt.plot(MLP_NMSE_dB, label='Val NMSE (dB)', color='green')
plt.xlabel('Epoch')
plt.ylabel('NMSE (dB)')
plt.title('Validation NMSE (dB) over Epochs')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
