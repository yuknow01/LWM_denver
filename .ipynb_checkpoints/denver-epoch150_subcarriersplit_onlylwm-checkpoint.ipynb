# %% [markdown]
# ## dataset denver download if you download than pass

# %%
# !pip install deepmimo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: deepmimo in /home/dlghdbs200/.local/lib/python3.10/site-packages (4.0.0b10)
# Requirement already satisfied: scipy>=1.6.2 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from deepmimo) (1.15.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from deepmimo) (2.32.4)
# Requirement already satisfied: tqdm>=4.59.0 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from deepmimo) (4.67.1)
# Requirement already satisfied: matplotlib>=3.8.2 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from deepmimo) (3.10.3)
# Requirement already satisfied: numpy<2.3,>=1.19.5 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from deepmimo) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.2->deepmimo) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.8.2->deepmimo) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from matplotlib>=3.8.2->deepmimo) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from matplotlib>=3.8.2->deepmimo) (1.3.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from matplotlib>=3.8.2->deepmimo) (1.4.8)
# Requirement already satisfied: fonttools>=4.22.0 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from matplotlib>=3.8.2->deepmimo) (4.58.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.2->deepmimo) (2.9.0.post0)
# Requirement already satisfied: pillow>=8 in /home/dlghdbs200/.local/lib/python3.10/site-packages (from matplotlib>=3.8.2->deepmimo) (11.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->deepmimo) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->deepmimo) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->deepmimo) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->deepmimo) (2020.6.20)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8.2->deepmimo) (1.16.0)

# %%
import deepmimo as dm

# Search for scenarios matching criteria
scenarios = dm.search()

# %%
import deepmimo as dm

# Download a specific scenario
dm.download('city_18_denver_28')
# Out:
# Scenario "city_18_denver_28" already exists in /home/dlghdbs200/LWM_denver/deepmimo_scenarios

# %%
from .summary import summary, plot_summary
print(summary.__file__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 from .summary import summary, plot_summary
#       2 print(summary.__file__)
#
# ImportError: attempted relative import with no known parent package

# %% [markdown]
# # library

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import TensorDataset, DataLoader, random_split
import DeepMIMOv3
import numpy as np
from pprint import pprint

import matplotlib.pyplot as plt
import time
import math
import torch
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import IterableDataset
import numpy as np
import time, gc
from tqdm import tqdm
import numpy as np
import torch
import random
import torch.nn as nn
from lwm_model import lwm
from torch.optim import Adam
from pathlib import Path
import torch, time

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # dataset load

# %%
import deepmimo as dm

# Load dataset
dataset = dm.load("city_18_denver_28")

# Access dataset properties
aoa_az = dataset.aoa_az
aoa_el = dataset.aoa_el
inter_pos = dataset.inter_pos

# Compute specific channel information
# los = dataset.compute_los()
channels = dataset.compute_channels()
pl = dataset.compute_pathloss()
# Out:
# Loading TXRX PAIR: TXset 1 (tx_idx 0) & RXset 0 (rx_idxs 43248)
# Loading TXRX PAIR: TXset 2 (tx_idx 0) & RXset 0 (rx_idxs 43248)
# Loading TXRX PAIR: TXset 3 (tx_idx 0) & RXset 0 (rx_idxs 43248)
# Generating channels: 100%|█████████████████████████████████████████████████████| 43248/43248 [00:01<00:00, 32853.84it/s]
# Generating channels: 100%|█████████████████████████████████████████████████████| 43248/43248 [00:01<00:00, 29700.59it/s]
# Generating channels: 100%|█████████████████████████████████████████████████████| 43248/43248 [00:01<00:00, 34101.86it/s]

# %% [markdown]
# # Datashape
# deepmimo/generator/dataset.py def compute_channels in here channel data shape
#
#             numpy.ndarray: MIMO channel matrix with shape [n_users, n_rx_ant, n_tx_ant, n_subcarriers]
#                           if freq_domain=True, otherwise [n_users, n_rx_ant, n_tx_ant, n_paths]

# %% [markdown]
# # three TxSet(1,2,3)
# “For 43,248 users, 1 user antenna, 8 BS antennas, and 1 propagation path.”
# (users, user antenna, BS antennas, PL)

# %%
channels[1].shape
# Out:
# (43248, 1, 8, 1)

# %%
channels[0]
# Out:
# array([[[[-4.0636469e-10-2.4687419e-10j],
#          [ 4.0486328e-10+2.4921543e-10j],
#          [-4.0334483e-10-2.5152960e-10j],
#          ...,
#          [ 3.9869291e-10+2.5830790e-10j],
#          [-3.9711204e-10-2.6051203e-10j],
#          [ 3.9551701e-10+2.6268823e-10j]]],
#
#
#        [[[ 1.5214810e-10-7.0644335e-10j],
#          [-1.5652508e-10+7.0226053e-10j],
#          [ 1.6082487e-10-6.9803024e-10j],
#          ...,
#          [-1.7325429e-10+6.8506756e-10j],
#          [ 1.7723865e-10-6.8066053e-10j],
#          [-1.8114261e-10+6.7621270e-10j]]],
#
#
#        [[[ 7.6910278e-10+1.6763185e-11j],
#          [-7.6921619e-10-1.8937532e-11j],
#          [ 7.6933526e-10+2.1130594e-11j],
#          ...,
#          [-7.6972168e-10-2.7824850e-11j],
#          [ 7.6985857e-10+3.0095502e-11j],
#          [-7.6999856e-10-3.2386184e-11j]]],
#
#
#        ...,
#
#
#        [[[ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          ...,
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j]]],
#
#
#        [[[ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          ...,
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j]]],
#
#
#        [[[ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          ...,
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j],
#          [ 0.0000000e+00+0.0000000e+00j]]]],
#       shape=(43248, 1, 8, 1), dtype=complex64)

# %%
len(channels[0][0][0])
# Out:
# 8

# %%
channels[1][2][0][3]
# Out:
# array([1.3398023e-09-1.4365638e-09j], dtype=complex64)

# %% [markdown]
# # data preprocessing

# %% [markdown]
# ## How to predict
# H1,H2,H3 -> all data union <br>
# Tx_antenna split <br>
# Sliding-window version: Predicts the next antenna response from a few adjacent antennas (local spatial reconstruction).
#
# In summary, this code converts complex antenna channel data into real-valued, normalized tensors and prepares it for training.
#
# Three complex inputs (`H1`, `H2`, `H3`, each shaped `(N, 1, 8, 1)`) are merged into one dataset `(3N, 1, 8, 1)`. The real and imaginary parts are separated, forming `(3N, 1, 8, 1, 2)`. Each sample is normalized using its L2 norm.
#
# A sliding window is then applied along the antenna axis:
#
# * **Input:** 3 consecutive antennas (`win_in = 3`)
# * **Target:** the next antenna (`win_out = 1`)
#
# This produces 5 windows per sample (`(num_pos * 3N, 1, 3, 1, 2)` for inputs and `(num_pos * 3N, 1, 1, 1, 2)` for targets).
#
# Finally, data is split by antenna index:
#
# * **Training:** target index < 6
# * **Validation:** target index ≥ 6
#
# Both subsets are converted into PyTorch `DataLoader`s for efficient training and evaluation.

# %%
import torch, numpy as np
from torch.utils.data import TensorDataset, DataLoader

# ---------- 0) Load & combine three channels ----------
H1, H2, H3 = channels[0], channels[1], channels[2]     # each: (N, 1, 8, 1), complex
X = np.concatenate([H1, H2, H3], axis=0)               # (3N, 1, 8, 1)
y = X.copy()

# ---------- 1) Real/Imag split ----------
X = np.stack([X.real, X.imag], axis=-1).astype(np.float32)  # (3N, 1, 8, 1, 2)
y = np.stack([y.real, y.imag], axis=-1).astype(np.float32)

# ---------- 2) Torch + per-sample normalization ----------
X_t = torch.from_numpy(X).float()
y_t = torch.from_numpy(y).float()
eps = 1e-8
scale = torch.linalg.vector_norm(X_t.view(X_t.size(0), -1), dim=1, keepdim=True).clamp_min(eps)
X_t = X_t / scale.view(-1,1,1,1,1)
y_t = y_t / scale.view(-1,1,1,1,1)

# ---------- 3) Build antenna-axis sliding windows (3 in -> 1 out) ----------
N3, _, n_tx, _, _ = X_t.shape     # n_tx should be 8 here
assert n_tx >= 4, "Need at least 4 antennas for 3->1 split."
win_in, win_out = 3, 1
num_pos = n_tx - (win_in + win_out) + 1      # 8 - 4 + 1 = 5

X_chunks, Y_chunks, tgt_idx_list = [], [], []
for p in range(num_pos):
    X_chunks.append(X_t[:, :, p:p+win_in, :, :])                  # (3N,1,3,1,2)
    Y_chunks.append(y_t[:, :, p+win_in:p+win_in+win_out, :, :])   # (3N,1,1,1,2)
    tgt_idx_list.append(torch.full((N3,), p+win_in, dtype=torch.long))

X_win = torch.cat(X_chunks, dim=0)     # (num_pos*3N, 1, 3, 1, 2)
Y_win = torch.cat(Y_chunks, dim=0)     # (num_pos*3N, 1, 1, 1, 2)
tgt_idx = torch.cat(tgt_idx_list, dim=0)  # (num_pos*3N,)
print("Windows per sample:", num_pos)
print("Shapes -> X_win:", X_win.shape, "Y_win:", Y_win.shape)

# ---------- 4) Split by target-antenna: train(0..5), val(6..7) ----------
train_ant = 6                              # target idx < 6 => train
mask_tr = (tgt_idx < train_ant)
mask_va = ~mask_tr

X_tr, Y_tr = X_win[mask_tr], Y_win[mask_tr]
X_va, Y_va = X_win[mask_va], Y_win[mask_va]

# ---------- 5) DataLoaders (dataset carries only X,Y to avoid unpack errors) ----------
train_set = TensorDataset(X_tr, Y_tr)
val_set   = TensorDataset(X_va, Y_va)

train_loader = DataLoader(train_set, batch_size=1024, shuffle=True)
val_loader   = DataLoader(val_set,   batch_size=2048, shuffle=False)

print(f"Train/Val samples: {len(train_set)} / {len(val_set)}")
print(f"Example shapes -> X: {X_tr.shape}, y: {Y_tr.shape}")
# Out:
# Windows per sample: 5
# Shapes -> X_win: torch.Size([648720, 1, 3, 1, 2]) Y_win: torch.Size([648720, 1, 1, 1, 2])
# Train/Val samples: 389232 / 259488
# Example shapes -> X: torch.Size([389232, 1, 3, 1, 2]), y: torch.Size([389232, 1, 1, 1, 2])

# %%
X.shape
# Out:
# (129744, 1, 8, 1, 2)

# %%
y.shape
# Out:
# (129744, 1, 8, 1, 2)

# %%
val_set[12000]
# Out:
# (tensor([[[[0., 0.]],
#
#           [[0., 0.]],
#
#           [[0., 0.]]]]),
#  tensor([[[[0., 0.]]]]))

# %% [markdown]
# # Model define

# %%
class MLP(nn.Module):
    def __init__(self, hidden=256, depth=3, pdrop=0.1):
        super().__init__()
        d_in, d_out = 3*2, 1*2  # (3 antennas * real+imag, 1 antenna * real+imag)
        layers, d = [], d_in
        for _ in range(depth - 1):
            layers += [nn.Linear(d, hidden), nn.ReLU(), nn.Dropout(pdrop)]
            d = hidden
        layers += [nn.Linear(d, d_out)]
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        b = x.size(0)
        x = x.view(b, -1)        # (B, 6)
        y = self.net(x)          # (B, 2)
        return y.view(b, 1, 1, 1, 2)



class CNN1D(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv1d(2, 32, 3, padding=1), nn.ReLU(),
            nn.Conv1d(32, 64, 3, padding=1), nn.ReLU()
        )
        self.decoder = nn.Sequential(
            nn.Conv1d(64, 32, 3, padding=1), nn.ReLU(),
            nn.Conv1d(32, 2, 3, padding=1)
        )
        self.pool = nn.AdaptiveAvgPool1d(1)  # (B,2,3) -> (B,2,1)

    def forward(self, x):                    # x: (B,1,3,1,2)
        B, _, L, _, C = x.shape
        assert L == 3 and C == 2, f"expected (B,1,3,1,2), got {x.shape}"
        # (B,1,3,1,2) -> (B,3,1,2) -> (B,2,3)
        x = x.squeeze(1).permute(0, 3, 1, 2).squeeze(-1)   # (B,2,3)
        z = self.encoder(x)                                # (B,64,3)
        z = self.decoder(z)                                # (B,2,3)
        z = self.pool(z)                                   # (B,2,1)
        return z.permute(0, 2, 1).unsqueeze(1).unsqueeze(3)  # (B,1,1,1,2)

# %%
class LWM_denver(nn.Module):
    def __init__(self, d_model=64, n_layers=12, max_len=129):
        super().__init__()
        self.core = None
        self.config = {
            "d_model": d_model,
            "n_layers": n_layers,
            "max_len": max_len
        }

    def build_core(self, L, D, device):
        from lwm_model import lwm
        self.core = lwm(
            element_length=D,
            d_model=self.config["d_model"],
            n_layers=self.config["n_layers"],
            max_len=self.config["max_len"]
        ).to(device)

    def forward(self, x):
        B, _, L, _, D = x.shape   # (B,1,3,1,2)
        x_seq = x.squeeze(1).squeeze(-2).float()  # (B,3,2)
        if self.core is None:
            self.build_core(L, D, x.device)
        # forward
        y_hat, _ = self.core(x_seq, torch.arange(L, device=x.device).unsqueeze(0).repeat(B, 1))
        # Take last token output only (predict next antenna)
        y_last = y_hat[:, -1:, :]  # (B,1,2)
        return y_last.unsqueeze(1).unsqueeze(-2)  # (B,1,1,1,2)

# %% [markdown]
# # Evaluate

# %%
def train_one_epoch(model, dataloader, criterion, optimizer):
    model.train()
    total_loss = 0.0
    for x, y in dataloader:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        pred = model(x)
        loss = criterion(pred, y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * x.size(0)
    return total_loss / len(dataloader.dataset)


def evaluate(model, dataloader, criterion):
    model.eval()
    total_loss, total_mse, total_nmse = 0.0, 0.0, 0.0
    with torch.no_grad():
        for x, y in dataloader:
            x, y = x.to(device), y.to(device)
            pred = model(x)
            loss = criterion(pred, y)
            mse = torch.mean((pred - y) ** 2).item()
            nmse = mse / torch.mean(y ** 2).item()
            total_loss += loss.item() * x.size(0)
            total_mse += mse * x.size(0)
            total_nmse += nmse * x.size(0)

    avg_loss = total_loss / len(dataloader.dataset)
    avg_rmse = (total_mse / len(dataloader.dataset)) ** 0.5
    avg_nmse = total_nmse / len(dataloader.dataset)
    avg_nmse_db = 10 * np.log10(avg_nmse + 1e-12)
    return avg_loss, avg_rmse, avg_nmse, avg_nmse_db

# %%
def run(model, epochs=150, lr=1e-3, weight_decay=0.0, show_every=1):
    model = model.to(device)
    criterion = nn.MSELoss(reduction="mean")
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

    best_loss = float("inf")
    best_nmse = float("inf")
    best_rmse = float("inf")
    best_nmse_db = float("inf")

    best_epoch_loss = 0
    best_epoch_nmse = 0
    best_epoch_rmse = 0
    best_epoch_nmse_db = 0

    for ep in range(1, epochs + 1):
        t0 = time.time()
        train_loss = train_one_epoch(model, train_loader, criterion, optimizer)
        val_loss, rmse, nmse, nmse_db = evaluate(model, val_loader, criterion)
        dt = time.time() - t0

        # Track best values
        if val_loss < best_loss:
            best_loss = val_loss
            best_epoch_loss = ep

        if nmse < best_nmse:
            best_nmse = nmse
            best_epoch_nmse = ep

        if rmse < best_rmse:
            best_rmse = rmse
            best_epoch_rmse = ep

        if nmse_db < best_nmse_db:
            best_nmse_db = nmse_db
            best_epoch_nmse_db = ep

        # Logging
        if ep % show_every == 0:
            print(f"[{ep:02d}/{epochs:03d}] "
                  f"TrainLoss: {train_loss:.6f}  "
                  f"ValLoss: {val_loss:.6f}  "
                  f"Val RMSE: {rmse:.4f}  "
                  f"Val NMSE: {nmse:.4f}  "
                  f"Val NMSE_dB: {nmse_db:.6f} dB  "
                  f"TrainTime: {dt:.2f}s")

    # Summary of best metrics
    print("=" * 60)
    print(f"=> Best ValLoss   : {best_loss:.6f}   (epoch {best_epoch_loss})")
    print(f"=> Best Val NMSE  : {best_nmse:.4f}   (epoch {best_epoch_nmse})")
    print(f"=> Best Val RMSE  : {best_rmse:.4f}   (epoch {best_epoch_rmse})")
    print(f"=> Best Val NMSE_dB: {best_nmse_db:.4f} dB (epoch {best_epoch_nmse_db})")
    print("=" * 60)

    return model

# %%
import sys, os, contextlib
device = "cuda" if torch.cuda.is_available() else "cpu"
epochs = 500

# --- Tee that mirrors stdout to both console and a file ---
class Tee:
    def __init__(self, filename, mode="w", encoding="utf-8"):
        os.makedirs(os.path.dirname(filename), exist_ok=True)
        self.file = open(filename, mode, encoding=encoding)
        self.stdout = sys.stdout

    def write(self, data):
        self.file.write(data)
        self.stdout.write(data)

    def flush(self):
        self.file.flush()
        self.stdout.flush()

    def close(self):
        self.file.close()

    # context manager support
    def __enter__(self):
        return self

    def __exit__(self, exc_type, exc, tb):
        self.close()
        # don't suppress exceptions
        return False

# ----------------------------------------------------------
# 
base_dir = "/home/dlghdbs200/LWM_denver"

print("=== MLP Training ===")
mlp = MLP(hidden=256, depth=3, pdrop=0.1)
mlp_path = os.path.join(base_dir, "MLP_epoch500_antenna.txt")
with Tee(mlp_path, "w") as tee:
    with contextlib.redirect_stdout(tee):
        print("=== Training MLP ===")
        run(mlp, epochs=epochs, lr=1e-3)
print(f"\nMLP training log saved to {mlp_path}")

print("\n=== CNN Training ===")
cnn = CNN1D()
cnn_path = os.path.join(base_dir, "CNN_epoch500_antenna.txt")
with Tee(cnn_path, "w") as tee:
    with contextlib.redirect_stdout(tee):
        print("=== Training CNN ===")
        run(cnn, epochs=epochs, lr=1e-3)
print(f"\nCNN training log saved to {cnn_path}")

print("\n=== LWM Training ===")

lwm_model = LWM_denver(d_model=64, n_layers=12)
lwm_path = os.path.join(base_dir, "LWM_epoch500_antenna.txt")
with Tee(lwm_path, "w") as tee:
    with contextlib.redirect_stdout(tee):
        print("=== Training LWM ===")
        sample_x, _ = next(iter(train_loader))
        L = sample_x.shape[2]
        D = sample_x.shape[-1]
        lwm_model.build_core(L=L, D=D, device=device)
        run(lwm_model, epochs=epochs, lr=1e-3)
print(f"\nLWM training log saved to {lwm_path}")
# Out:
# === MLP Training ===
# === Training MLP ===
# [01/500] TrainLoss: 0.010325  ValLoss: 0.006837  Val RMSE: 0.0827  Val NMSE: 0.2380  Val NMSE_dB: -6.234850 dB  TrainTime: 5.20s
# [02/500] TrainLoss: 0.007134  ValLoss: 0.006493  Val RMSE: 0.0806  Val NMSE: 0.2272  Val NMSE_dB: -6.435480 dB  TrainTime: 5.08s
# [03/500] TrainLoss: 0.006727  ValLoss: 0.006298  Val RMSE: 0.0794  Val NMSE: 0.2213  Val NMSE_dB: -6.551085 dB  TrainTime: 5.27s
# [04/500] TrainLoss: 0.006544  ValLoss: 0.006252  Val RMSE: 0.0791  Val NMSE: 0.2201  Val NMSE_dB: -6.573792 dB  TrainTime: 8.45s
# [05/500] TrainLoss: 0.006405  ValLoss: 0.006180  Val RMSE: 0.0786  Val NMSE: 0.2178  Val NMSE_dB: -6.619340 dB  TrainTime: 4.46s
# [06/500] TrainLoss: 0.006332  ValLoss: 0.006093  Val RMSE: 0.0781  Val NMSE: 0.2147  Val NMSE_dB: -6.681349 dB  TrainTime: 4.70s
# [07/500] TrainLoss: 0.006275  ValLoss: 0.006138  Val RMSE: 0.0783  Val NMSE: 0.2161  Val NMSE_dB: -6.654241 dB  TrainTime: 4.67s
# [08/500] TrainLoss: 0.006203  ValLoss: 0.006027  Val RMSE: 0.0776  Val NMSE: 0.2122  Val NMSE_dB: -6.731905 dB  TrainTime: 4.88s
# [09/500] TrainLoss: 0.006162  ValLoss: 0.006020  Val RMSE: 0.0776  Val NMSE: 0.2119  Val NMSE_dB: -6.738804 dB  TrainTime: 4.61s
# [10/500] TrainLoss: 0.006127  ValLoss: 0.006035  Val RMSE: 0.0777  Val NMSE: 0.2128  Val NMSE_dB: -6.719790 dB  TrainTime: 4.85s
# [11/500] TrainLoss: 0.006084  ValLoss: 0.006020  Val RMSE: 0.0776  Val NMSE: 0.2123  Val NMSE_dB: -6.730396 dB  TrainTime: 7.52s
# [12/500] TrainLoss: 0.006046  ValLoss: 0.005967  Val RMSE: 0.0772  Val NMSE: 0.2101  Val NMSE_dB: -6.775749 dB  TrainTime: 4.43s
# [13/500] TrainLoss: 0.006031  ValLoss: 0.005968  Val RMSE: 0.0772  Val NMSE: 0.2105  Val NMSE_dB: -6.767583 dB  TrainTime: 4.71s
# [14/500] TrainLoss: 0.006002  ValLoss: 0.005954  Val RMSE: 0.0772  Val NMSE: 0.2095  Val NMSE_dB: -6.787770 dB  TrainTime: 4.56s
# [15/500] TrainLoss: 0.005977  ValLoss: 0.005928  Val RMSE: 0.0770  Val NMSE: 0.2090  Val NMSE_dB: -6.799081 dB  TrainTime: 4.83s
# [16/500] TrainLoss: 0.005950  ValLoss: 0.005909  Val RMSE: 0.0769  Val NMSE: 0.2085  Val NMSE_dB: -6.809875 dB  TrainTime: 4.91s
# [17/500] TrainLoss: 0.005934  ValLoss: 0.005867  Val RMSE: 0.0766  Val NMSE: 0.2066  Val NMSE_dB: -6.849151 dB  TrainTime: 5.28s
# [18/500] TrainLoss: 0.005904  ValLoss: 0.005916  Val RMSE: 0.0769  Val NMSE: 0.2087  Val NMSE_dB: -6.804913 dB  TrainTime: 7.46s
# [19/500] TrainLoss: 0.005894  ValLoss: 0.005853  Val RMSE: 0.0765  Val NMSE: 0.2062  Val NMSE_dB: -6.856625 dB  TrainTime: 4.84s
# [20/500] TrainLoss: 0.005886  ValLoss: 0.005890  Val RMSE: 0.0767  Val NMSE: 0.2074  Val NMSE_dB: -6.831320 dB  TrainTime: 5.01s
# [21/500] TrainLoss: 0.005867  ValLoss: 0.005807  Val RMSE: 0.0762  Val NMSE: 0.2048  Val NMSE_dB: -6.887482 dB  TrainTime: 5.09s
# [22/500] TrainLoss: 0.005850  ValLoss: 0.005798  Val RMSE: 0.0761  Val NMSE: 0.2040  Val NMSE_dB: -6.903988 dB  TrainTime: 5.09s
# [23/500] TrainLoss: 0.005857  ValLoss: 0.005830  Val RMSE: 0.0764  Val NMSE: 0.2053  Val NMSE_dB: -6.876582 dB  TrainTime: 4.96s
# [24/500] TrainLoss: 0.005840  ValLoss: 0.005836  Val RMSE: 0.0764  Val NMSE: 0.2055  Val NMSE_dB: -6.871526 dB  TrainTime: 6.88s
# [25/500] TrainLoss: 0.005827  ValLoss: 0.005823  Val RMSE: 0.0763  Val NMSE: 0.2048  Val NMSE_dB: -6.887496 dB  TrainTime: 4.73s
# [26/500] TrainLoss: 0.005801  ValLoss: 0.005769  Val RMSE: 0.0760  Val NMSE: 0.2029  Val NMSE_dB: -6.926678 dB  TrainTime: 4.88s
# [27/500] TrainLoss: 0.005795  ValLoss: 0.005788  Val RMSE: 0.0761  Val NMSE: 0.2041  Val NMSE_dB: -6.901415 dB  TrainTime: 4.68s
# [28/500] TrainLoss: 0.005793  ValLoss: 0.005773  Val RMSE: 0.0760  Val NMSE: 0.2032  Val NMSE_dB: -6.921239 dB  TrainTime: 4.44s
# [29/500] TrainLoss: 0.005774  ValLoss: 0.005822  Val RMSE: 0.0763  Val NMSE: 0.2052  Val NMSE_dB: -6.879028 dB  TrainTime: 4.81s
# [30/500] TrainLoss: 0.005772  ValLoss: 0.005787  Val RMSE: 0.0761  Val NMSE: 0.2040  Val NMSE_dB: -6.902692 dB  TrainTime: 4.54s
# [31/500] TrainLoss: 0.005756  ValLoss: 0.005758  Val RMSE: 0.0759  Val NMSE: 0.2026  Val NMSE_dB: -6.933933 dB  TrainTime: 7.96s
# [32/500] TrainLoss: 0.005758  ValLoss: 0.005772  Val RMSE: 0.0760  Val NMSE: 0.2031  Val NMSE_dB: -6.923336 dB  TrainTime: 4.89s
# [33/500] TrainLoss: 0.005755  ValLoss: 0.005791  Val RMSE: 0.0761  Val NMSE: 0.2041  Val NMSE_dB: -6.902147 dB  TrainTime: 5.12s
# [34/500] TrainLoss: 0.005740  ValLoss: 0.005761  Val RMSE: 0.0759  Val NMSE: 0.2028  Val NMSE_dB: -6.928554 dB  TrainTime: 4.83s
# [35/500] TrainLoss: 0.005736  ValLoss: 0.005760  Val RMSE: 0.0759  Val NMSE: 0.2030  Val NMSE_dB: -6.925601 dB  TrainTime: 5.13s
# [36/500] TrainLoss: 0.005728  ValLoss: 0.005728  Val RMSE: 0.0757  Val NMSE: 0.2018  Val NMSE_dB: -6.950891 dB  TrainTime: 5.09s
# [37/500] TrainLoss: 0.005716  ValLoss: 0.005736  Val RMSE: 0.0757  Val NMSE: 0.2023  Val NMSE_dB: -6.939330 dB  TrainTime: 7.35s
# [38/500] TrainLoss: 0.005720  ValLoss: 0.005815  Val RMSE: 0.0763  Val NMSE: 0.2050  Val NMSE_dB: -6.883019 dB  TrainTime: 4.73s
# [39/500] TrainLoss: 0.005712  ValLoss: 0.005694  Val RMSE: 0.0755  Val NMSE: 0.2006  Val NMSE_dB: -6.977346 dB  TrainTime: 5.60s
# [40/500] TrainLoss: 0.005710  ValLoss: 0.005727  Val RMSE: 0.0757  Val NMSE: 0.2017  Val NMSE_dB: -6.953249 dB  TrainTime: 5.13s
# [41/500] TrainLoss: 0.005700  ValLoss: 0.005703  Val RMSE: 0.0755  Val NMSE: 0.2008  Val NMSE_dB: -6.971785 dB  TrainTime: 4.72s
# [42/500] TrainLoss: 0.005695  ValLoss: 0.005713  Val RMSE: 0.0756  Val NMSE: 0.2011  Val NMSE_dB: -6.964980 dB  TrainTime: 4.77s
# [43/500] TrainLoss: 0.005696  ValLoss: 0.005710  Val RMSE: 0.0756  Val NMSE: 0.2010  Val NMSE_dB: -6.968333 dB  TrainTime: 4.48s
# [44/500] TrainLoss: 0.005692  ValLoss: 0.005701  Val RMSE: 0.0755  Val NMSE: 0.2008  Val NMSE_dB: -6.971886 dB  TrainTime: 7.48s
# [45/500] TrainLoss: 0.005682  ValLoss: 0.005736  Val RMSE: 0.0757  Val NMSE: 0.2020  Val NMSE_dB: -6.945745 dB  TrainTime: 4.63s
# [46/500] TrainLoss: 0.005676  ValLoss: 0.005724  Val RMSE: 0.0757  Val NMSE: 0.2016  Val NMSE_dB: -6.954956 dB  TrainTime: 4.86s
# [47/500] TrainLoss: 0.005670  ValLoss: 0.005740  Val RMSE: 0.0758  Val NMSE: 0.2023  Val NMSE_dB: -6.941096 dB  TrainTime: 4.41s
# [48/500] TrainLoss: 0.005671  ValLoss: 0.005723  Val RMSE: 0.0756  Val NMSE: 0.2017  Val NMSE_dB: -6.952536 dB  TrainTime: 4.99s
# [49/500] TrainLoss: 0.005664  ValLoss: 0.005760  Val RMSE: 0.0759  Val NMSE: 0.2032  Val NMSE_dB: -6.920749 dB  TrainTime: 4.90s
# [50/500] TrainLoss: 0.005676  ValLoss: 0.005704  Val RMSE: 0.0755  Val NMSE: 0.2009  Val NMSE_dB: -6.970287 dB  TrainTime: 4.82s
# [51/500] TrainLoss: 0.005654  ValLoss: 0.005715  Val RMSE: 0.0756  Val NMSE: 0.2011  Val NMSE_dB: -6.965695 dB  TrainTime: 7.46s
# [52/500] TrainLoss: 0.005659  ValLoss: 0.005680  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.989540 dB  TrainTime: 4.76s
# [53/500] TrainLoss: 0.005658  ValLoss: 0.005732  Val RMSE: 0.0757  Val NMSE: 0.2019  Val NMSE_dB: -6.948787 dB  TrainTime: 4.70s
# [54/500] TrainLoss: 0.005655  ValLoss: 0.005784  Val RMSE: 0.0761  Val NMSE: 0.2036  Val NMSE_dB: -6.911251 dB  TrainTime: 4.50s
# [55/500] TrainLoss: 0.005650  ValLoss: 0.005756  Val RMSE: 0.0759  Val NMSE: 0.2027  Val NMSE_dB: -6.930708 dB  TrainTime: 4.78s
# [56/500] TrainLoss: 0.005653  ValLoss: 0.005719  Val RMSE: 0.0756  Val NMSE: 0.2015  Val NMSE_dB: -6.958025 dB  TrainTime: 4.55s
# [57/500] TrainLoss: 0.005639  ValLoss: 0.005711  Val RMSE: 0.0756  Val NMSE: 0.2014  Val NMSE_dB: -6.960040 dB  TrainTime: 4.98s
# [58/500] TrainLoss: 0.005642  ValLoss: 0.005681  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.990107 dB  TrainTime: 7.38s
# [59/500] TrainLoss: 0.005638  ValLoss: 0.005725  Val RMSE: 0.0757  Val NMSE: 0.2013  Val NMSE_dB: -6.962116 dB  TrainTime: 5.12s
# [60/500] TrainLoss: 0.005634  ValLoss: 0.005701  Val RMSE: 0.0755  Val NMSE: 0.2007  Val NMSE_dB: -6.973555 dB  TrainTime: 4.61s
# [61/500] TrainLoss: 0.005636  ValLoss: 0.005715  Val RMSE: 0.0756  Val NMSE: 0.2011  Val NMSE_dB: -6.965687 dB  TrainTime: 4.73s
# [62/500] TrainLoss: 0.005632  ValLoss: 0.005705  Val RMSE: 0.0755  Val NMSE: 0.2009  Val NMSE_dB: -6.971281 dB  TrainTime: 4.96s
# [63/500] TrainLoss: 0.005634  ValLoss: 0.005690  Val RMSE: 0.0754  Val NMSE: 0.2002  Val NMSE_dB: -6.984413 dB  TrainTime: 4.65s
# [64/500] TrainLoss: 0.005629  ValLoss: 0.005731  Val RMSE: 0.0757  Val NMSE: 0.2020  Val NMSE_dB: -6.946610 dB  TrainTime: 7.89s
# [65/500] TrainLoss: 0.005627  ValLoss: 0.005707  Val RMSE: 0.0755  Val NMSE: 0.2010  Val NMSE_dB: -6.969120 dB  TrainTime: 5.39s
# [66/500] TrainLoss: 0.005622  ValLoss: 0.005680  Val RMSE: 0.0754  Val NMSE: 0.1999  Val NMSE_dB: -6.992415 dB  TrainTime: 5.19s
# [67/500] TrainLoss: 0.005619  ValLoss: 0.005704  Val RMSE: 0.0755  Val NMSE: 0.2010  Val NMSE_dB: -6.968424 dB  TrainTime: 4.80s
# [68/500] TrainLoss: 0.005607  ValLoss: 0.005732  Val RMSE: 0.0757  Val NMSE: 0.2020  Val NMSE_dB: -6.946934 dB  TrainTime: 4.94s
# [69/500] TrainLoss: 0.005611  ValLoss: 0.005672  Val RMSE: 0.0753  Val NMSE: 0.2000  Val NMSE_dB: -6.989068 dB  TrainTime: 4.56s
# [70/500] TrainLoss: 0.005606  ValLoss: 0.005656  Val RMSE: 0.0752  Val NMSE: 0.1993  Val NMSE_dB: -7.004622 dB  TrainTime: 5.01s
# [71/500] TrainLoss: 0.005612  ValLoss: 0.005688  Val RMSE: 0.0754  Val NMSE: 0.2004  Val NMSE_dB: -6.980095 dB  TrainTime: 7.78s
# [72/500] TrainLoss: 0.005599  ValLoss: 0.005689  Val RMSE: 0.0754  Val NMSE: 0.1999  Val NMSE_dB: -6.991641 dB  TrainTime: 4.70s
# [73/500] TrainLoss: 0.005604  ValLoss: 0.005709  Val RMSE: 0.0756  Val NMSE: 0.2009  Val NMSE_dB: -6.971237 dB  TrainTime: 4.70s
# [74/500] TrainLoss: 0.005604  ValLoss: 0.005687  Val RMSE: 0.0754  Val NMSE: 0.2001  Val NMSE_dB: -6.988193 dB  TrainTime: 4.66s
# [75/500] TrainLoss: 0.005591  ValLoss: 0.005680  Val RMSE: 0.0754  Val NMSE: 0.1999  Val NMSE_dB: -6.990879 dB  TrainTime: 5.08s
# [76/500] TrainLoss: 0.005606  ValLoss: 0.005680  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.989863 dB  TrainTime: 4.64s
# [77/500] TrainLoss: 0.005583  ValLoss: 0.005653  Val RMSE: 0.0752  Val NMSE: 0.1989  Val NMSE_dB: -7.014656 dB  TrainTime: 7.54s
# [78/500] TrainLoss: 0.005588  ValLoss: 0.005717  Val RMSE: 0.0756  Val NMSE: 0.2011  Val NMSE_dB: -6.965378 dB  TrainTime: 4.71s
# [79/500] TrainLoss: 0.005585  ValLoss: 0.005706  Val RMSE: 0.0755  Val NMSE: 0.2004  Val NMSE_dB: -6.980867 dB  TrainTime: 4.43s
# [80/500] TrainLoss: 0.005588  ValLoss: 0.005730  Val RMSE: 0.0757  Val NMSE: 0.2017  Val NMSE_dB: -6.953595 dB  TrainTime: 4.71s
# [81/500] TrainLoss: 0.005588  ValLoss: 0.005688  Val RMSE: 0.0754  Val NMSE: 0.2003  Val NMSE_dB: -6.982178 dB  TrainTime: 4.82s
# [82/500] TrainLoss: 0.005590  ValLoss: 0.005704  Val RMSE: 0.0755  Val NMSE: 0.2009  Val NMSE_dB: -6.970821 dB  TrainTime: 4.51s
# [83/500] TrainLoss: 0.005577  ValLoss: 0.005678  Val RMSE: 0.0753  Val NMSE: 0.1999  Val NMSE_dB: -6.992243 dB  TrainTime: 5.00s
# [84/500] TrainLoss: 0.005587  ValLoss: 0.005673  Val RMSE: 0.0753  Val NMSE: 0.1998  Val NMSE_dB: -6.993347 dB  TrainTime: 7.28s
# [85/500] TrainLoss: 0.005577  ValLoss: 0.005686  Val RMSE: 0.0754  Val NMSE: 0.2001  Val NMSE_dB: -6.987536 dB  TrainTime: 5.34s
# [86/500] TrainLoss: 0.005571  ValLoss: 0.005722  Val RMSE: 0.0756  Val NMSE: 0.2014  Val NMSE_dB: -6.960315 dB  TrainTime: 5.34s
# [87/500] TrainLoss: 0.005571  ValLoss: 0.005666  Val RMSE: 0.0753  Val NMSE: 0.1993  Val NMSE_dB: -7.005195 dB  TrainTime: 5.11s
# [88/500] TrainLoss: 0.005575  ValLoss: 0.005668  Val RMSE: 0.0753  Val NMSE: 0.1997  Val NMSE_dB: -6.996820 dB  TrainTime: 4.81s
# [89/500] TrainLoss: 0.005570  ValLoss: 0.005694  Val RMSE: 0.0755  Val NMSE: 0.2005  Val NMSE_dB: -6.979380 dB  TrainTime: 5.44s
# [90/500] TrainLoss: 0.005569  ValLoss: 0.005752  Val RMSE: 0.0758  Val NMSE: 0.2023  Val NMSE_dB: -6.939606 dB  TrainTime: 4.82s
# [91/500] TrainLoss: 0.005558  ValLoss: 0.005715  Val RMSE: 0.0756  Val NMSE: 0.2009  Val NMSE_dB: -6.971053 dB  TrainTime: 8.13s
# [92/500] TrainLoss: 0.005570  ValLoss: 0.005701  Val RMSE: 0.0755  Val NMSE: 0.2008  Val NMSE_dB: -6.973037 dB  TrainTime: 4.91s
# [93/500] TrainLoss: 0.005577  ValLoss: 0.005690  Val RMSE: 0.0754  Val NMSE: 0.2006  Val NMSE_dB: -6.977718 dB  TrainTime: 5.22s
# [94/500] TrainLoss: 0.005567  ValLoss: 0.005676  Val RMSE: 0.0753  Val NMSE: 0.2000  Val NMSE_dB: -6.990489 dB  TrainTime: 5.34s
# [95/500] TrainLoss: 0.005573  ValLoss: 0.005691  Val RMSE: 0.0754  Val NMSE: 0.2003  Val NMSE_dB: -6.983478 dB  TrainTime: 4.99s
# [96/500] TrainLoss: 0.005562  ValLoss: 0.005712  Val RMSE: 0.0756  Val NMSE: 0.2013  Val NMSE_dB: -6.960623 dB  TrainTime: 6.95s
# [97/500] TrainLoss: 0.005568  ValLoss: 0.005666  Val RMSE: 0.0753  Val NMSE: 0.1993  Val NMSE_dB: -7.004466 dB  TrainTime: 8.22s
# [98/500] TrainLoss: 0.005555  ValLoss: 0.005680  Val RMSE: 0.0754  Val NMSE: 0.1999  Val NMSE_dB: -6.991763 dB  TrainTime: 4.74s
# [99/500] TrainLoss: 0.005553  ValLoss: 0.005693  Val RMSE: 0.0755  Val NMSE: 0.2002  Val NMSE_dB: -6.986081 dB  TrainTime: 5.02s
# [100/500] TrainLoss: 0.005561  ValLoss: 0.005672  Val RMSE: 0.0753  Val NMSE: 0.1996  Val NMSE_dB: -6.998009 dB  TrainTime: 4.77s
# [101/500] TrainLoss: 0.005545  ValLoss: 0.005669  Val RMSE: 0.0753  Val NMSE: 0.1996  Val NMSE_dB: -6.998020 dB  TrainTime: 5.48s
# [102/500] TrainLoss: 0.005556  ValLoss: 0.005681  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.989091 dB  TrainTime: 5.49s
# [103/500] TrainLoss: 0.005545  ValLoss: 0.005635  Val RMSE: 0.0751  Val NMSE: 0.1983  Val NMSE_dB: -7.026938 dB  TrainTime: 7.52s
# [104/500] TrainLoss: 0.005557  ValLoss: 0.005674  Val RMSE: 0.0753  Val NMSE: 0.1997  Val NMSE_dB: -6.996393 dB  TrainTime: 5.19s
# [105/500] TrainLoss: 0.005550  ValLoss: 0.005700  Val RMSE: 0.0755  Val NMSE: 0.2006  Val NMSE_dB: -6.977293 dB  TrainTime: 4.63s
# [106/500] TrainLoss: 0.005546  ValLoss: 0.005673  Val RMSE: 0.0753  Val NMSE: 0.1998  Val NMSE_dB: -6.994869 dB  TrainTime: 5.14s
# [107/500] TrainLoss: 0.005540  ValLoss: 0.005694  Val RMSE: 0.0755  Val NMSE: 0.2005  Val NMSE_dB: -6.978843 dB  TrainTime: 5.11s
# [108/500] TrainLoss: 0.005539  ValLoss: 0.005657  Val RMSE: 0.0752  Val NMSE: 0.1992  Val NMSE_dB: -7.006070 dB  TrainTime: 4.84s
# [109/500] TrainLoss: 0.005540  ValLoss: 0.005665  Val RMSE: 0.0753  Val NMSE: 0.1994  Val NMSE_dB: -7.003696 dB  TrainTime: 7.78s
# [110/500] TrainLoss: 0.005543  ValLoss: 0.005673  Val RMSE: 0.0753  Val NMSE: 0.1999  Val NMSE_dB: -6.991966 dB  TrainTime: 5.07s
# [111/500] TrainLoss: 0.005541  ValLoss: 0.005736  Val RMSE: 0.0757  Val NMSE: 0.2016  Val NMSE_dB: -6.954776 dB  TrainTime: 4.44s
# [112/500] TrainLoss: 0.005537  ValLoss: 0.005699  Val RMSE: 0.0755  Val NMSE: 0.2006  Val NMSE_dB: -6.976680 dB  TrainTime: 4.71s
# [113/500] TrainLoss: 0.005543  ValLoss: 0.005710  Val RMSE: 0.0756  Val NMSE: 0.2011  Val NMSE_dB: -6.965866 dB  TrainTime: 4.75s
# [114/500] TrainLoss: 0.005543  ValLoss: 0.005685  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.989852 dB  TrainTime: 4.65s
# [115/500] TrainLoss: 0.005529  ValLoss: 0.005676  Val RMSE: 0.0753  Val NMSE: 0.1999  Val NMSE_dB: -6.991780 dB  TrainTime: 4.93s
# [116/500] TrainLoss: 0.005531  ValLoss: 0.005675  Val RMSE: 0.0753  Val NMSE: 0.1997  Val NMSE_dB: -6.996431 dB  TrainTime: 7.52s
# [117/500] TrainLoss: 0.005536  ValLoss: 0.005673  Val RMSE: 0.0753  Val NMSE: 0.1995  Val NMSE_dB: -7.000221 dB  TrainTime: 4.88s
# [118/500] TrainLoss: 0.005529  ValLoss: 0.005674  Val RMSE: 0.0753  Val NMSE: 0.1996  Val NMSE_dB: -6.998092 dB  TrainTime: 4.92s
# [119/500] TrainLoss: 0.005525  ValLoss: 0.005675  Val RMSE: 0.0753  Val NMSE: 0.2000  Val NMSE_dB: -6.989664 dB  TrainTime: 4.66s
# [120/500] TrainLoss: 0.005535  ValLoss: 0.005672  Val RMSE: 0.0753  Val NMSE: 0.1994  Val NMSE_dB: -7.002763 dB  TrainTime: 4.96s
# [121/500] TrainLoss: 0.005527  ValLoss: 0.005652  Val RMSE: 0.0752  Val NMSE: 0.1987  Val NMSE_dB: -7.018103 dB  TrainTime: 5.04s
# [122/500] TrainLoss: 0.005532  ValLoss: 0.005676  Val RMSE: 0.0753  Val NMSE: 0.1997  Val NMSE_dB: -6.995652 dB  TrainTime: 4.85s
# [123/500] TrainLoss: 0.005526  ValLoss: 0.005679  Val RMSE: 0.0754  Val NMSE: 0.1998  Val NMSE_dB: -6.993415 dB  TrainTime: 7.32s
# [124/500] TrainLoss: 0.005529  ValLoss: 0.005652  Val RMSE: 0.0752  Val NMSE: 0.1989  Val NMSE_dB: -7.014644 dB  TrainTime: 4.86s
# [125/500] TrainLoss: 0.005522  ValLoss: 0.005679  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.989591 dB  TrainTime: 4.86s
# [126/500] TrainLoss: 0.005526  ValLoss: 0.005660  Val RMSE: 0.0752  Val NMSE: 0.1993  Val NMSE_dB: -7.004397 dB  TrainTime: 5.15s
# [127/500] TrainLoss: 0.005525  ValLoss: 0.005675  Val RMSE: 0.0753  Val NMSE: 0.1997  Val NMSE_dB: -6.996729 dB  TrainTime: 5.05s
# [128/500] TrainLoss: 0.005516  ValLoss: 0.005713  Val RMSE: 0.0756  Val NMSE: 0.2011  Val NMSE_dB: -6.966220 dB  TrainTime: 4.98s
# [129/500] TrainLoss: 0.005523  ValLoss: 0.005669  Val RMSE: 0.0753  Val NMSE: 0.1995  Val NMSE_dB: -7.000911 dB  TrainTime: 7.58s
# [130/500] TrainLoss: 0.005519  ValLoss: 0.005659  Val RMSE: 0.0752  Val NMSE: 0.1992  Val NMSE_dB: -7.008036 dB  TrainTime: 4.72s
# [131/500] TrainLoss: 0.005521  ValLoss: 0.005673  Val RMSE: 0.0753  Val NMSE: 0.1996  Val NMSE_dB: -6.998841 dB  TrainTime: 5.17s
# [132/500] TrainLoss: 0.005512  ValLoss: 0.005681  Val RMSE: 0.0754  Val NMSE: 0.1998  Val NMSE_dB: -6.994863 dB  TrainTime: 4.51s
# [133/500] TrainLoss: 0.005520  ValLoss: 0.005723  Val RMSE: 0.0757  Val NMSE: 0.2012  Val NMSE_dB: -6.964667 dB  TrainTime: 5.02s
# [134/500] TrainLoss: 0.005511  ValLoss: 0.005653  Val RMSE: 0.0752  Val NMSE: 0.1988  Val NMSE_dB: -7.015542 dB  TrainTime: 5.08s
# [135/500] TrainLoss: 0.005513  ValLoss: 0.005669  Val RMSE: 0.0753  Val NMSE: 0.1995  Val NMSE_dB: -7.001429 dB  TrainTime: 4.87s
# [136/500] TrainLoss: 0.005510  ValLoss: 0.005729  Val RMSE: 0.0757  Val NMSE: 0.2017  Val NMSE_dB: -6.951909 dB  TrainTime: 7.07s
# [137/500] TrainLoss: 0.005512  ValLoss: 0.005676  Val RMSE: 0.0753  Val NMSE: 0.1998  Val NMSE_dB: -6.994680 dB  TrainTime: 4.81s
# [138/500] TrainLoss: 0.005504  ValLoss: 0.005671  Val RMSE: 0.0753  Val NMSE: 0.1996  Val NMSE_dB: -6.998518 dB  TrainTime: 4.49s
# [139/500] TrainLoss: 0.005499  ValLoss: 0.005702  Val RMSE: 0.0755  Val NMSE: 0.2004  Val NMSE_dB: -6.981187 dB  TrainTime: 4.86s
# [140/500] TrainLoss: 0.005511  ValLoss: 0.005689  Val RMSE: 0.0754  Val NMSE: 0.2002  Val NMSE_dB: -6.985580 dB  TrainTime: 4.58s
# [141/500] TrainLoss: 0.005508  ValLoss: 0.005687  Val RMSE: 0.0754  Val NMSE: 0.1999  Val NMSE_dB: -6.991743 dB  TrainTime: 4.83s
# [142/500] TrainLoss: 0.005512  ValLoss: 0.005684  Val RMSE: 0.0754  Val NMSE: 0.2001  Val NMSE_dB: -6.986779 dB  TrainTime: 4.89s
# [143/500] TrainLoss: 0.005508  ValLoss: 0.005656  Val RMSE: 0.0752  Val NMSE: 0.1987  Val NMSE_dB: -7.017362 dB  TrainTime: 7.05s
# [144/500] TrainLoss: 0.005509  ValLoss: 0.005662  Val RMSE: 0.0752  Val NMSE: 0.1993  Val NMSE_dB: -7.003858 dB  TrainTime: 5.09s
# [145/500] TrainLoss: 0.005503  ValLoss: 0.005690  Val RMSE: 0.0754  Val NMSE: 0.1998  Val NMSE_dB: -6.993178 dB  TrainTime: 4.53s
# [146/500] TrainLoss: 0.005500  ValLoss: 0.005704  Val RMSE: 0.0755  Val NMSE: 0.2009  Val NMSE_dB: -6.969251 dB  TrainTime: 4.81s
# [147/500] TrainLoss: 0.005506  ValLoss: 0.005671  Val RMSE: 0.0753  Val NMSE: 0.1993  Val NMSE_dB: -7.003843 dB  TrainTime: 5.00s
# [148/500] TrainLoss: 0.005499  ValLoss: 0.005676  Val RMSE: 0.0753  Val NMSE: 0.1996  Val NMSE_dB: -6.998928 dB  TrainTime: 4.58s
# [149/500] TrainLoss: 0.005500  ValLoss: 0.005751  Val RMSE: 0.0758  Val NMSE: 0.2024  Val NMSE_dB: -6.938824 dB  TrainTime: 4.73s
# [150/500] TrainLoss: 0.005512  ValLoss: 0.005690  Val RMSE: 0.0754  Val NMSE: 0.2002  Val NMSE_dB: -6.984365 dB  TrainTime: 7.38s
# [151/500] TrainLoss: 0.005503  ValLoss: 0.005679  Val RMSE: 0.0754  Val NMSE: 0.1998  Val NMSE_dB: -6.993599 dB  TrainTime: 4.43s
# [152/500] TrainLoss: 0.005490  ValLoss: 0.005741  Val RMSE: 0.0758  Val NMSE: 0.2019  Val NMSE_dB: -6.948248 dB  TrainTime: 4.82s
# [153/500] TrainLoss: 0.005498  ValLoss: 0.005704  Val RMSE: 0.0755  Val NMSE: 0.2005  Val NMSE_dB: -6.979179 dB  TrainTime: 4.57s
# [154/500] TrainLoss: 0.005491  ValLoss: 0.005698  Val RMSE: 0.0755  Val NMSE: 0.2004  Val NMSE_dB: -6.980407 dB  TrainTime: 4.84s
# [155/500] TrainLoss: 0.005497  ValLoss: 0.005666  Val RMSE: 0.0753  Val NMSE: 0.1994  Val NMSE_dB: -7.003160 dB  TrainTime: 4.98s
# [156/500] TrainLoss: 0.005493  ValLoss: 0.005691  Val RMSE: 0.0754  Val NMSE: 0.2001  Val NMSE_dB: -6.987601 dB  TrainTime: 7.01s
# [157/500] TrainLoss: 0.005501  ValLoss: 0.005653  Val RMSE: 0.0752  Val NMSE: 0.1989  Val NMSE_dB: -7.013628 dB  TrainTime: 4.85s
# [158/500] TrainLoss: 0.005501  ValLoss: 0.005661  Val RMSE: 0.0752  Val NMSE: 0.1993  Val NMSE_dB: -7.005790 dB  TrainTime: 4.85s
# [159/500] TrainLoss: 0.005497  ValLoss: 0.005709  Val RMSE: 0.0756  Val NMSE: 0.2009  Val NMSE_dB: -6.969463 dB  TrainTime: 4.70s
# [160/500] TrainLoss: 0.005497  ValLoss: 0.005664  Val RMSE: 0.0753  Val NMSE: 0.1993  Val NMSE_dB: -7.005244 dB  TrainTime: 4.54s
# [161/500] TrainLoss: 0.005488  ValLoss: 0.005646  Val RMSE: 0.0751  Val NMSE: 0.1987  Val NMSE_dB: -7.017944 dB  TrainTime: 4.69s
# [162/500] TrainLoss: 0.005489  ValLoss: 0.005675  Val RMSE: 0.0753  Val NMSE: 0.1995  Val NMSE_dB: -7.000150 dB  TrainTime: 4.93s
# [163/500] TrainLoss: 0.005491  ValLoss: 0.005696  Val RMSE: 0.0755  Val NMSE: 0.2008  Val NMSE_dB: -6.972972 dB  TrainTime: 7.29s
# [164/500] TrainLoss: 0.005497  ValLoss: 0.005701  Val RMSE: 0.0755  Val NMSE: 0.2005  Val NMSE_dB: -6.979317 dB  TrainTime: 4.82s
# [165/500] TrainLoss: 0.005490  ValLoss: 0.005652  Val RMSE: 0.0752  Val NMSE: 0.1987  Val NMSE_dB: -7.017018 dB  TrainTime: 4.70s
# [166/500] TrainLoss: 0.005485  ValLoss: 0.005664  Val RMSE: 0.0753  Val NMSE: 0.1992  Val NMSE_dB: -7.007624 dB  TrainTime: 4.74s
# [167/500] TrainLoss: 0.005486  ValLoss: 0.005687  Val RMSE: 0.0754  Val NMSE: 0.2002  Val NMSE_dB: -6.986140 dB  TrainTime: 4.37s
# [168/500] TrainLoss: 0.005487  ValLoss: 0.005674  Val RMSE: 0.0753  Val NMSE: 0.1996  Val NMSE_dB: -6.998166 dB  TrainTime: 4.96s
# [169/500] TrainLoss: 0.005487  ValLoss: 0.005653  Val RMSE: 0.0752  Val NMSE: 0.1990  Val NMSE_dB: -7.012210 dB  TrainTime: 4.85s
# [170/500] TrainLoss: 0.005484  ValLoss: 0.005678  Val RMSE: 0.0754  Val NMSE: 0.1997  Val NMSE_dB: -6.995225 dB  TrainTime: 7.28s
# [171/500] TrainLoss: 0.005483  ValLoss: 0.005653  Val RMSE: 0.0752  Val NMSE: 0.1989  Val NMSE_dB: -7.013628 dB  TrainTime: 4.67s
# [172/500] TrainLoss: 0.005482  ValLoss: 0.005685  Val RMSE: 0.0754  Val NMSE: 0.1998  Val NMSE_dB: -6.993829 dB  TrainTime: 4.41s
# [173/500] TrainLoss: 0.005493  ValLoss: 0.005685  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.989819 dB  TrainTime: 4.71s
# [174/500] TrainLoss: 0.005478  ValLoss: 0.005703  Val RMSE: 0.0755  Val NMSE: 0.2005  Val NMSE_dB: -6.979261 dB  TrainTime: 4.83s
# [175/500] TrainLoss: 0.005485  ValLoss: 0.005675  Val RMSE: 0.0753  Val NMSE: 0.1996  Val NMSE_dB: -6.998219 dB  TrainTime: 4.78s
# [176/500] TrainLoss: 0.005482  ValLoss: 0.005662  Val RMSE: 0.0752  Val NMSE: 0.1992  Val NMSE_dB: -7.007093 dB  TrainTime: 4.75s
# [177/500] TrainLoss: 0.005477  ValLoss: 0.005660  Val RMSE: 0.0752  Val NMSE: 0.1992  Val NMSE_dB: -7.007577 dB  TrainTime: 7.31s
# [178/500] TrainLoss: 0.005479  ValLoss: 0.005660  Val RMSE: 0.0752  Val NMSE: 0.1990  Val NMSE_dB: -7.011917 dB  TrainTime: 4.43s
# [179/500] TrainLoss: 0.005469  ValLoss: 0.005661  Val RMSE: 0.0752  Val NMSE: 0.1990  Val NMSE_dB: -7.011750 dB  TrainTime: 4.83s
# [180/500] TrainLoss: 0.005477  ValLoss: 0.005684  Val RMSE: 0.0754  Val NMSE: 0.1999  Val NMSE_dB: -6.991111 dB  TrainTime: 4.56s
# [181/500] TrainLoss: 0.005485  ValLoss: 0.005662  Val RMSE: 0.0752  Val NMSE: 0.1992  Val NMSE_dB: -7.008136 dB  TrainTime: 4.86s
# [182/500] TrainLoss: 0.005480  ValLoss: 0.005666  Val RMSE: 0.0753  Val NMSE: 0.1993  Val NMSE_dB: -7.005219 dB  TrainTime: 4.99s
# [183/500] TrainLoss: 0.005480  ValLoss: 0.005678  Val RMSE: 0.0754  Val NMSE: 0.1997  Val NMSE_dB: -6.997187 dB  TrainTime: 4.45s
# [184/500] TrainLoss: 0.005480  ValLoss: 0.005689  Val RMSE: 0.0754  Val NMSE: 0.2001  Val NMSE_dB: -6.987564 dB  TrainTime: 7.26s
# [185/500] TrainLoss: 0.005475  ValLoss: 0.005704  Val RMSE: 0.0755  Val NMSE: 0.2008  Val NMSE_dB: -6.971317 dB  TrainTime: 4.88s
# [186/500] TrainLoss: 0.005481  ValLoss: 0.005666  Val RMSE: 0.0753  Val NMSE: 0.1991  Val NMSE_dB: -7.009999 dB  TrainTime: 4.88s
# [187/500] TrainLoss: 0.005469  ValLoss: 0.005714  Val RMSE: 0.0756  Val NMSE: 0.2009  Val NMSE_dB: -6.969481 dB  TrainTime: 4.92s
# [188/500] TrainLoss: 0.005478  ValLoss: 0.005650  Val RMSE: 0.0752  Val NMSE: 0.1989  Val NMSE_dB: -7.013485 dB  TrainTime: 4.57s
# [189/500] TrainLoss: 0.005474  ValLoss: 0.005692  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.989365 dB  TrainTime: 4.54s
# [190/500] TrainLoss: 0.005468  ValLoss: 0.005640  Val RMSE: 0.0751  Val NMSE: 0.1986  Val NMSE_dB: -7.019970 dB  TrainTime: 7.42s
# [191/500] TrainLoss: 0.005475  ValLoss: 0.005668  Val RMSE: 0.0753  Val NMSE: 0.1994  Val NMSE_dB: -7.003837 dB  TrainTime: 4.68s
# [192/500] TrainLoss: 0.005467  ValLoss: 0.005668  Val RMSE: 0.0753  Val NMSE: 0.1995  Val NMSE_dB: -6.999552 dB  TrainTime: 4.95s
# [193/500] TrainLoss: 0.005468  ValLoss: 0.005664  Val RMSE: 0.0753  Val NMSE: 0.1990  Val NMSE_dB: -7.011329 dB  TrainTime: 4.78s
# [194/500] TrainLoss: 0.005470  ValLoss: 0.005640  Val RMSE: 0.0751  Val NMSE: 0.1983  Val NMSE_dB: -7.026777 dB  TrainTime: 5.09s
# [195/500] TrainLoss: 0.005457  ValLoss: 0.005692  Val RMSE: 0.0754  Val NMSE: 0.2003  Val NMSE_dB: -6.983948 dB  TrainTime: 5.14s
# [196/500] TrainLoss: 0.005472  ValLoss: 0.005702  Val RMSE: 0.0755  Val NMSE: 0.2007  Val NMSE_dB: -6.975324 dB  TrainTime: 4.62s
# [197/500] TrainLoss: 0.005472  ValLoss: 0.005683  Val RMSE: 0.0754  Val NMSE: 0.1999  Val NMSE_dB: -6.992696 dB  TrainTime: 7.67s
# [198/500] TrainLoss: 0.005465  ValLoss: 0.005657  Val RMSE: 0.0752  Val NMSE: 0.1989  Val NMSE_dB: -7.014026 dB  TrainTime: 4.68s
# [199/500] TrainLoss: 0.005466  ValLoss: 0.005673  Val RMSE: 0.0753  Val NMSE: 0.1996  Val NMSE_dB: -6.998931 dB  TrainTime: 4.87s
# [200/500] TrainLoss: 0.005460  ValLoss: 0.005687  Val RMSE: 0.0754  Val NMSE: 0.1999  Val NMSE_dB: -6.990868 dB  TrainTime: 4.88s
# [201/500] TrainLoss: 0.005466  ValLoss: 0.005706  Val RMSE: 0.0755  Val NMSE: 0.2004  Val NMSE_dB: -6.980617 dB  TrainTime: 4.82s
# [202/500] TrainLoss: 0.005473  ValLoss: 0.005677  Val RMSE: 0.0753  Val NMSE: 0.1997  Val NMSE_dB: -6.996484 dB  TrainTime: 4.79s
# [203/500] TrainLoss: 0.005464  ValLoss: 0.005658  Val RMSE: 0.0752  Val NMSE: 0.1990  Val NMSE_dB: -7.010925 dB  TrainTime: 5.37s
# [204/500] TrainLoss: 0.005458  ValLoss: 0.005677  Val RMSE: 0.0753  Val NMSE: 0.1995  Val NMSE_dB: -6.999932 dB  TrainTime: 7.16s
# [205/500] TrainLoss: 0.005459  ValLoss: 0.005657  Val RMSE: 0.0752  Val NMSE: 0.1991  Val NMSE_dB: -7.008426 dB  TrainTime: 5.08s
# [206/500] TrainLoss: 0.005453  ValLoss: 0.005678  Val RMSE: 0.0754  Val NMSE: 0.1996  Val NMSE_dB: -6.998387 dB  TrainTime: 4.77s
# [207/500] TrainLoss: 0.005459  ValLoss: 0.005663  Val RMSE: 0.0753  Val NMSE: 0.1994  Val NMSE_dB: -7.003792 dB  TrainTime: 4.85s
# [208/500] TrainLoss: 0.005457  ValLoss: 0.005648  Val RMSE: 0.0752  Val NMSE: 0.1988  Val NMSE_dB: -7.015063 dB  TrainTime: 4.63s
# [209/500] TrainLoss: 0.005464  ValLoss: 0.005700  Val RMSE: 0.0755  Val NMSE: 0.2006  Val NMSE_dB: -6.976691 dB  TrainTime: 5.14s
# [210/500] TrainLoss: 0.005455  ValLoss: 0.005683  Val RMSE: 0.0754  Val NMSE: 0.1997  Val NMSE_dB: -6.995827 dB  TrainTime: 7.81s
# [211/500] TrainLoss: 0.005462  ValLoss: 0.005656  Val RMSE: 0.0752  Val NMSE: 0.1987  Val NMSE_dB: -7.016990 dB  TrainTime: 5.14s
# [212/500] TrainLoss: 0.005467  ValLoss: 0.005715  Val RMSE: 0.0756  Val NMSE: 0.2010  Val NMSE_dB: -6.968022 dB  TrainTime: 4.91s
# [213/500] TrainLoss: 0.005453  ValLoss: 0.005660  Val RMSE: 0.0752  Val NMSE: 0.1990  Val NMSE_dB: -7.012523 dB  TrainTime: 5.21s
# [214/500] TrainLoss: 0.005450  ValLoss: 0.005657  Val RMSE: 0.0752  Val NMSE: 0.1986  Val NMSE_dB: -7.019709 dB  TrainTime: 4.92s
# [215/500] TrainLoss: 0.005463  ValLoss: 0.005695  Val RMSE: 0.0755  Val NMSE: 0.2001  Val NMSE_dB: -6.988178 dB  TrainTime: 4.71s
# [216/500] TrainLoss: 0.005465  ValLoss: 0.005671  Val RMSE: 0.0753  Val NMSE: 0.1994  Val NMSE_dB: -7.002689 dB  TrainTime: 4.98s
# [217/500] TrainLoss: 0.005462  ValLoss: 0.005669  Val RMSE: 0.0753  Val NMSE: 0.1991  Val NMSE_dB: -7.010369 dB  TrainTime: 7.49s
# [218/500] TrainLoss: 0.005453  ValLoss: 0.005685  Val RMSE: 0.0754  Val NMSE: 0.1997  Val NMSE_dB: -6.996468 dB  TrainTime: 5.02s
# [219/500] TrainLoss: 0.005458  ValLoss: 0.005647  Val RMSE: 0.0751  Val NMSE: 0.1987  Val NMSE_dB: -7.017981 dB  TrainTime: 4.77s
# [220/500] TrainLoss: 0.005453  ValLoss: 0.005642  Val RMSE: 0.0751  Val NMSE: 0.1985  Val NMSE_dB: -7.021943 dB  TrainTime: 4.79s
# [221/500] TrainLoss: 0.005452  ValLoss: 0.005664  Val RMSE: 0.0753  Val NMSE: 0.1994  Val NMSE_dB: -7.002829 dB  TrainTime: 4.84s
# [222/500] TrainLoss: 0.005461  ValLoss: 0.005674  Val RMSE: 0.0753  Val NMSE: 0.1995  Val NMSE_dB: -7.000458 dB  TrainTime: 4.45s
# [223/500] TrainLoss: 0.005445  ValLoss: 0.005694  Val RMSE: 0.0755  Val NMSE: 0.2002  Val NMSE_dB: -6.985988 dB  TrainTime: 7.42s
# [224/500] TrainLoss: 0.005449  ValLoss: 0.005666  Val RMSE: 0.0753  Val NMSE: 0.1991  Val NMSE_dB: -7.009835 dB  TrainTime: 4.83s
# [225/500] TrainLoss: 0.005448  ValLoss: 0.005656  Val RMSE: 0.0752  Val NMSE: 0.1986  Val NMSE_dB: -7.019365 dB  TrainTime: 5.01s
# [226/500] TrainLoss: 0.005444  ValLoss: 0.005654  Val RMSE: 0.0752  Val NMSE: 0.1988  Val NMSE_dB: -7.014956 dB  TrainTime: 4.74s
# [227/500] TrainLoss: 0.005451  ValLoss: 0.005660  Val RMSE: 0.0752  Val NMSE: 0.1992  Val NMSE_dB: -7.007691 dB  TrainTime: 4.83s
# [228/500] TrainLoss: 0.005457  ValLoss: 0.005704  Val RMSE: 0.0755  Val NMSE: 0.2005  Val NMSE_dB: -6.978661 dB  TrainTime: 4.71s
# [229/500] TrainLoss: 0.005453  ValLoss: 0.005651  Val RMSE: 0.0752  Val NMSE: 0.1987  Val NMSE_dB: -7.017839 dB  TrainTime: 4.80s
# [230/500] TrainLoss: 0.005447  ValLoss: 0.005695  Val RMSE: 0.0755  Val NMSE: 0.2003  Val NMSE_dB: -6.982466 dB  TrainTime: 7.59s
# [231/500] TrainLoss: 0.005449  ValLoss: 0.005662  Val RMSE: 0.0752  Val NMSE: 0.1991  Val NMSE_dB: -7.010024 dB  TrainTime: 5.08s
# [232/500] TrainLoss: 0.005444  ValLoss: 0.005679  Val RMSE: 0.0754  Val NMSE: 0.1997  Val NMSE_dB: -6.995165 dB  TrainTime: 4.40s
# [233/500] TrainLoss: 0.005448  ValLoss: 0.005682  Val RMSE: 0.0754  Val NMSE: 0.1999  Val NMSE_dB: -6.991986 dB  TrainTime: 4.63s
# [234/500] TrainLoss: 0.005445  ValLoss: 0.005679  Val RMSE: 0.0754  Val NMSE: 0.1999  Val NMSE_dB: -6.991119 dB  TrainTime: 4.66s
# [235/500] TrainLoss: 0.005451  ValLoss: 0.005687  Val RMSE: 0.0754  Val NMSE: 0.1999  Val NMSE_dB: -6.991017 dB  TrainTime: 4.51s
# [236/500] TrainLoss: 0.005441  ValLoss: 0.005723  Val RMSE: 0.0757  Val NMSE: 0.2014  Val NMSE_dB: -6.958826 dB  TrainTime: 4.79s
# [237/500] TrainLoss: 0.005450  ValLoss: 0.005674  Val RMSE: 0.0753  Val NMSE: 0.1999  Val NMSE_dB: -6.991662 dB  TrainTime: 7.80s
# [238/500] TrainLoss: 0.005443  ValLoss: 0.005659  Val RMSE: 0.0752  Val NMSE: 0.1993  Val NMSE_dB: -7.005548 dB  TrainTime: 4.57s
# [239/500] TrainLoss: 0.005442  ValLoss: 0.005669  Val RMSE: 0.0753  Val NMSE: 0.1994  Val NMSE_dB: -7.003736 dB  TrainTime: 4.75s
# [240/500] TrainLoss: 0.005442  ValLoss: 0.005724  Val RMSE: 0.0757  Val NMSE: 0.2012  Val NMSE_dB: -6.964323 dB  TrainTime: 4.82s
# [241/500] TrainLoss: 0.005444  ValLoss: 0.005654  Val RMSE: 0.0752  Val NMSE: 0.1989  Val NMSE_dB: -7.013045 dB  TrainTime: 4.70s
# [242/500] TrainLoss: 0.005447  ValLoss: 0.005675  Val RMSE: 0.0753  Val NMSE: 0.1995  Val NMSE_dB: -7.000940 dB  TrainTime: 4.74s
# [243/500] TrainLoss: 0.005440  ValLoss: 0.005669  Val RMSE: 0.0753  Val NMSE: 0.1993  Val NMSE_dB: -7.004608 dB  TrainTime: 4.93s
# [244/500] TrainLoss: 0.005438  ValLoss: 0.005684  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.990696 dB  TrainTime: 7.34s
# [245/500] TrainLoss: 0.005438  ValLoss: 0.005671  Val RMSE: 0.0753  Val NMSE: 0.1994  Val NMSE_dB: -7.003487 dB  TrainTime: 4.80s
# [246/500] TrainLoss: 0.005446  ValLoss: 0.005673  Val RMSE: 0.0753  Val NMSE: 0.1996  Val NMSE_dB: -6.998484 dB  TrainTime: 4.33s
# [247/500] TrainLoss: 0.005441  ValLoss: 0.005705  Val RMSE: 0.0755  Val NMSE: 0.2006  Val NMSE_dB: -6.977553 dB  TrainTime: 4.69s
# [248/500] TrainLoss: 0.005445  ValLoss: 0.005663  Val RMSE: 0.0753  Val NMSE: 0.1994  Val NMSE_dB: -7.001870 dB  TrainTime: 4.43s
# [249/500] TrainLoss: 0.005446  ValLoss: 0.005682  Val RMSE: 0.0754  Val NMSE: 0.1999  Val NMSE_dB: -6.991255 dB  TrainTime: 4.94s
# [250/500] TrainLoss: 0.005444  ValLoss: 0.005667  Val RMSE: 0.0753  Val NMSE: 0.1992  Val NMSE_dB: -7.008149 dB  TrainTime: 4.69s
# [251/500] TrainLoss: 0.005432  ValLoss: 0.005679  Val RMSE: 0.0754  Val NMSE: 0.1995  Val NMSE_dB: -7.001260 dB  TrainTime: 7.73s
# [252/500] TrainLoss: 0.005431  ValLoss: 0.005724  Val RMSE: 0.0757  Val NMSE: 0.2013  Val NMSE_dB: -6.961100 dB  TrainTime: 4.46s
# [253/500] TrainLoss: 0.005442  ValLoss: 0.005707  Val RMSE: 0.0755  Val NMSE: 0.2008  Val NMSE_dB: -6.972792 dB  TrainTime: 4.71s
# [254/500] TrainLoss: 0.005435  ValLoss: 0.005650  Val RMSE: 0.0752  Val NMSE: 0.1988  Val NMSE_dB: -7.015924 dB  TrainTime: 4.64s
# [255/500] TrainLoss: 0.005441  ValLoss: 0.005694  Val RMSE: 0.0755  Val NMSE: 0.2003  Val NMSE_dB: -6.982893 dB  TrainTime: 4.85s
# [256/500] TrainLoss: 0.005430  ValLoss: 0.005726  Val RMSE: 0.0757  Val NMSE: 0.2013  Val NMSE_dB: -6.961547 dB  TrainTime: 4.68s
# [257/500] TrainLoss: 0.005438  ValLoss: 0.005670  Val RMSE: 0.0753  Val NMSE: 0.1995  Val NMSE_dB: -6.999871 dB  TrainTime: 5.04s
# [258/500] TrainLoss: 0.005431  ValLoss: 0.005690  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.989197 dB  TrainTime: 7.20s
# [259/500] TrainLoss: 0.005435  ValLoss: 0.005652  Val RMSE: 0.0752  Val NMSE: 0.1988  Val NMSE_dB: -7.016800 dB  TrainTime: 5.00s
# [260/500] TrainLoss: 0.005446  ValLoss: 0.005682  Val RMSE: 0.0754  Val NMSE: 0.1996  Val NMSE_dB: -6.997691 dB  TrainTime: 4.57s
# [261/500] TrainLoss: 0.005440  ValLoss: 0.005678  Val RMSE: 0.0754  Val NMSE: 0.1995  Val NMSE_dB: -7.000548 dB  TrainTime: 4.69s
# [262/500] TrainLoss: 0.005447  ValLoss: 0.005699  Val RMSE: 0.0755  Val NMSE: 0.2003  Val NMSE_dB: -6.982405 dB  TrainTime: 4.78s
# [263/500] TrainLoss: 0.005432  ValLoss: 0.005730  Val RMSE: 0.0757  Val NMSE: 0.2016  Val NMSE_dB: -6.955086 dB  TrainTime: 4.87s
# [264/500] TrainLoss: 0.005440  ValLoss: 0.005693  Val RMSE: 0.0755  Val NMSE: 0.2000  Val NMSE_dB: -6.990136 dB  TrainTime: 7.90s
# [265/500] TrainLoss: 0.005436  ValLoss: 0.005640  Val RMSE: 0.0751  Val NMSE: 0.1984  Val NMSE_dB: -7.023814 dB  TrainTime: 4.83s
# [266/500] TrainLoss: 0.005438  ValLoss: 0.005705  Val RMSE: 0.0755  Val NMSE: 0.2005  Val NMSE_dB: -6.978765 dB  TrainTime: 4.91s
# [267/500] TrainLoss: 0.005430  ValLoss: 0.005731  Val RMSE: 0.0757  Val NMSE: 0.2014  Val NMSE_dB: -6.959549 dB  TrainTime: 4.96s
# [268/500] TrainLoss: 0.005428  ValLoss: 0.005662  Val RMSE: 0.0752  Val NMSE: 0.1995  Val NMSE_dB: -6.999977 dB  TrainTime: 4.37s
# [269/500] TrainLoss: 0.005420  ValLoss: 0.005671  Val RMSE: 0.0753  Val NMSE: 0.1997  Val NMSE_dB: -6.996517 dB  TrainTime: 5.10s
# [270/500] TrainLoss: 0.005427  ValLoss: 0.005696  Val RMSE: 0.0755  Val NMSE: 0.2002  Val NMSE_dB: -6.986436 dB  TrainTime: 4.60s
# [271/500] TrainLoss: 0.005439  ValLoss: 0.005697  Val RMSE: 0.0755  Val NMSE: 0.2001  Val NMSE_dB: -6.987131 dB  TrainTime: 7.61s
# [272/500] TrainLoss: 0.005430  ValLoss: 0.005644  Val RMSE: 0.0751  Val NMSE: 0.1984  Val NMSE_dB: -7.024106 dB  TrainTime: 4.58s
# [273/500] TrainLoss: 0.005427  ValLoss: 0.005729  Val RMSE: 0.0757  Val NMSE: 0.2014  Val NMSE_dB: -6.959391 dB  TrainTime: 4.49s
# [274/500] TrainLoss: 0.005422  ValLoss: 0.005689  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.990029 dB  TrainTime: 4.93s
# [275/500] TrainLoss: 0.005435  ValLoss: 0.005684  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.990092 dB  TrainTime: 4.30s
# [276/500] TrainLoss: 0.005431  ValLoss: 0.005700  Val RMSE: 0.0755  Val NMSE: 0.2005  Val NMSE_dB: -6.979620 dB  TrainTime: 4.84s
# [277/500] TrainLoss: 0.005441  ValLoss: 0.005706  Val RMSE: 0.0755  Val NMSE: 0.2007  Val NMSE_dB: -6.974162 dB  TrainTime: 4.91s
# [278/500] TrainLoss: 0.005421  ValLoss: 0.005690  Val RMSE: 0.0754  Val NMSE: 0.1999  Val NMSE_dB: -6.992215 dB  TrainTime: 7.67s
# [279/500] TrainLoss: 0.005427  ValLoss: 0.005665  Val RMSE: 0.0753  Val NMSE: 0.1988  Val NMSE_dB: -7.016161 dB  TrainTime: 4.63s
# [280/500] TrainLoss: 0.005423  ValLoss: 0.005684  Val RMSE: 0.0754  Val NMSE: 0.1999  Val NMSE_dB: -6.992642 dB  TrainTime: 4.42s
# [281/500] TrainLoss: 0.005437  ValLoss: 0.005682  Val RMSE: 0.0754  Val NMSE: 0.1998  Val NMSE_dB: -6.993627 dB  TrainTime: 4.96s
# [282/500] TrainLoss: 0.005427  ValLoss: 0.005726  Val RMSE: 0.0757  Val NMSE: 0.2014  Val NMSE_dB: -6.958642 dB  TrainTime: 4.74s
# [283/500] TrainLoss: 0.005432  ValLoss: 0.005651  Val RMSE: 0.0752  Val NMSE: 0.1987  Val NMSE_dB: -7.016953 dB  TrainTime: 5.24s
# [284/500] TrainLoss: 0.005428  ValLoss: 0.005713  Val RMSE: 0.0756  Val NMSE: 0.2009  Val NMSE_dB: -6.969949 dB  TrainTime: 5.11s
# [285/500] TrainLoss: 0.005420  ValLoss: 0.005696  Val RMSE: 0.0755  Val NMSE: 0.2005  Val NMSE_dB: -6.978400 dB  TrainTime: 7.80s
# [286/500] TrainLoss: 0.005424  ValLoss: 0.005698  Val RMSE: 0.0755  Val NMSE: 0.2004  Val NMSE_dB: -6.981703 dB  TrainTime: 4.58s
# [287/500] TrainLoss: 0.005425  ValLoss: 0.005682  Val RMSE: 0.0754  Val NMSE: 0.1998  Val NMSE_dB: -6.995012 dB  TrainTime: 5.00s
# [288/500] TrainLoss: 0.005417  ValLoss: 0.005704  Val RMSE: 0.0755  Val NMSE: 0.2004  Val NMSE_dB: -6.980093 dB  TrainTime: 4.99s
# [289/500] TrainLoss: 0.005431  ValLoss: 0.005678  Val RMSE: 0.0753  Val NMSE: 0.1997  Val NMSE_dB: -6.996020 dB  TrainTime: 5.27s
# [290/500] TrainLoss: 0.005425  ValLoss: 0.005683  Val RMSE: 0.0754  Val NMSE: 0.1999  Val NMSE_dB: -6.992475 dB  TrainTime: 5.21s
# [291/500] TrainLoss: 0.005421  ValLoss: 0.005686  Val RMSE: 0.0754  Val NMSE: 0.2002  Val NMSE_dB: -6.985089 dB  TrainTime: 7.82s
# [292/500] TrainLoss: 0.005419  ValLoss: 0.005733  Val RMSE: 0.0757  Val NMSE: 0.2016  Val NMSE_dB: -6.955185 dB  TrainTime: 4.29s
# [293/500] TrainLoss: 0.005428  ValLoss: 0.005680  Val RMSE: 0.0754  Val NMSE: 0.1996  Val NMSE_dB: -6.998688 dB  TrainTime: 4.57s
# [294/500] TrainLoss: 0.005427  ValLoss: 0.005688  Val RMSE: 0.0754  Val NMSE: 0.1997  Val NMSE_dB: -6.995962 dB  TrainTime: 4.23s
# [295/500] TrainLoss: 0.005422  ValLoss: 0.005754  Val RMSE: 0.0759  Val NMSE: 0.2023  Val NMSE_dB: -6.940508 dB  TrainTime: 4.83s
# [296/500] TrainLoss: 0.005424  ValLoss: 0.005661  Val RMSE: 0.0752  Val NMSE: 0.1990  Val NMSE_dB: -7.012343 dB  TrainTime: 4.53s
# [297/500] TrainLoss: 0.005430  ValLoss: 0.005734  Val RMSE: 0.0757  Val NMSE: 0.2018  Val NMSE_dB: -6.950538 dB  TrainTime: 4.97s
# [298/500] TrainLoss: 0.005418  ValLoss: 0.005694  Val RMSE: 0.0755  Val NMSE: 0.1999  Val NMSE_dB: -6.991171 dB  TrainTime: 7.61s
# [299/500] TrainLoss: 0.005422  ValLoss: 0.005708  Val RMSE: 0.0756  Val NMSE: 0.2008  Val NMSE_dB: -6.972819 dB  TrainTime: 4.26s
# [300/500] TrainLoss: 0.005429  ValLoss: 0.005684  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.990548 dB  TrainTime: 4.58s
# [301/500] TrainLoss: 0.005428  ValLoss: 0.005693  Val RMSE: 0.0755  Val NMSE: 0.2004  Val NMSE_dB: -6.980134 dB  TrainTime: 4.78s
# [302/500] TrainLoss: 0.005424  ValLoss: 0.005679  Val RMSE: 0.0754  Val NMSE: 0.1994  Val NMSE_dB: -7.002955 dB  TrainTime: 4.62s
# [303/500] TrainLoss: 0.005415  ValLoss: 0.005642  Val RMSE: 0.0751  Val NMSE: 0.1983  Val NMSE_dB: -7.025867 dB  TrainTime: 4.66s
# [304/500] TrainLoss: 0.005412  ValLoss: 0.005718  Val RMSE: 0.0756  Val NMSE: 0.2013  Val NMSE_dB: -6.960786 dB  TrainTime: 4.69s
# [305/500] TrainLoss: 0.005416  ValLoss: 0.005706  Val RMSE: 0.0755  Val NMSE: 0.2008  Val NMSE_dB: -6.971554 dB  TrainTime: 7.52s
# [306/500] TrainLoss: 0.005416  ValLoss: 0.005689  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.990035 dB  TrainTime: 4.36s
# [307/500] TrainLoss: 0.005422  ValLoss: 0.005697  Val RMSE: 0.0755  Val NMSE: 0.1999  Val NMSE_dB: -6.992267 dB  TrainTime: 4.81s
# [308/500] TrainLoss: 0.005424  ValLoss: 0.005637  Val RMSE: 0.0751  Val NMSE: 0.1979  Val NMSE_dB: -7.035811 dB  TrainTime: 4.86s
# [309/500] TrainLoss: 0.005415  ValLoss: 0.005687  Val RMSE: 0.0754  Val NMSE: 0.1998  Val NMSE_dB: -6.993801 dB  TrainTime: 4.49s
# [310/500] TrainLoss: 0.005415  ValLoss: 0.005706  Val RMSE: 0.0755  Val NMSE: 0.2004  Val NMSE_dB: -6.982084 dB  TrainTime: 4.81s
# [311/500] TrainLoss: 0.005420  ValLoss: 0.005675  Val RMSE: 0.0753  Val NMSE: 0.1997  Val NMSE_dB: -6.996975 dB  TrainTime: 4.36s
# [312/500] TrainLoss: 0.005421  ValLoss: 0.005682  Val RMSE: 0.0754  Val NMSE: 0.1995  Val NMSE_dB: -6.999921 dB  TrainTime: 7.15s
# [313/500] TrainLoss: 0.005419  ValLoss: 0.005686  Val RMSE: 0.0754  Val NMSE: 0.1997  Val NMSE_dB: -6.995938 dB  TrainTime: 4.88s
# [314/500] TrainLoss: 0.005413  ValLoss: 0.005713  Val RMSE: 0.0756  Val NMSE: 0.2006  Val NMSE_dB: -6.976667 dB  TrainTime: 5.04s
# [315/500] TrainLoss: 0.005421  ValLoss: 0.005739  Val RMSE: 0.0758  Val NMSE: 0.2020  Val NMSE_dB: -6.947456 dB  TrainTime: 4.87s
# [316/500] TrainLoss: 0.005411  ValLoss: 0.005679  Val RMSE: 0.0754  Val NMSE: 0.1998  Val NMSE_dB: -6.994146 dB  TrainTime: 4.64s
# [317/500] TrainLoss: 0.005409  ValLoss: 0.005675  Val RMSE: 0.0753  Val NMSE: 0.1996  Val NMSE_dB: -6.999425 dB  TrainTime: 4.93s
# [318/500] TrainLoss: 0.005420  ValLoss: 0.005708  Val RMSE: 0.0756  Val NMSE: 0.2007  Val NMSE_dB: -6.974896 dB  TrainTime: 4.80s
# [319/500] TrainLoss: 0.005417  ValLoss: 0.005684  Val RMSE: 0.0754  Val NMSE: 0.1998  Val NMSE_dB: -6.994058 dB  TrainTime: 7.92s
# [320/500] TrainLoss: 0.005410  ValLoss: 0.005689  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.989853 dB  TrainTime: 4.70s
# [321/500] TrainLoss: 0.005409  ValLoss: 0.005673  Val RMSE: 0.0753  Val NMSE: 0.1995  Val NMSE_dB: -7.000815 dB  TrainTime: 4.71s
# [322/500] TrainLoss: 0.005423  ValLoss: 0.005640  Val RMSE: 0.0751  Val NMSE: 0.1984  Val NMSE_dB: -7.024053 dB  TrainTime: 4.77s
# [323/500] TrainLoss: 0.005404  ValLoss: 0.005677  Val RMSE: 0.0753  Val NMSE: 0.1996  Val NMSE_dB: -6.997394 dB  TrainTime: 4.75s
# [324/500] TrainLoss: 0.005406  ValLoss: 0.005685  Val RMSE: 0.0754  Val NMSE: 0.2001  Val NMSE_dB: -6.987002 dB  TrainTime: 4.82s
# [325/500] TrainLoss: 0.005411  ValLoss: 0.005663  Val RMSE: 0.0753  Val NMSE: 0.1992  Val NMSE_dB: -7.007996 dB  TrainTime: 7.66s
# [326/500] TrainLoss: 0.005415  ValLoss: 0.005681  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.989372 dB  TrainTime: 4.88s
# [327/500] TrainLoss: 0.005409  ValLoss: 0.005682  Val RMSE: 0.0754  Val NMSE: 0.1996  Val NMSE_dB: -6.999294 dB  TrainTime: 4.64s
# [328/500] TrainLoss: 0.005406  ValLoss: 0.005687  Val RMSE: 0.0754  Val NMSE: 0.1998  Val NMSE_dB: -6.993282 dB  TrainTime: 4.31s
# [329/500] TrainLoss: 0.005420  ValLoss: 0.005672  Val RMSE: 0.0753  Val NMSE: 0.1995  Val NMSE_dB: -7.001352 dB  TrainTime: 4.76s
# [330/500] TrainLoss: 0.005398  ValLoss: 0.005669  Val RMSE: 0.0753  Val NMSE: 0.1990  Val NMSE_dB: -7.010429 dB  TrainTime: 4.48s
# [331/500] TrainLoss: 0.005411  ValLoss: 0.005704  Val RMSE: 0.0755  Val NMSE: 0.2003  Val NMSE_dB: -6.982135 dB  TrainTime: 4.79s
# [332/500] TrainLoss: 0.005408  ValLoss: 0.005665  Val RMSE: 0.0753  Val NMSE: 0.1994  Val NMSE_dB: -7.003649 dB  TrainTime: 7.53s
# [333/500] TrainLoss: 0.005404  ValLoss: 0.005683  Val RMSE: 0.0754  Val NMSE: 0.1996  Val NMSE_dB: -6.998946 dB  TrainTime: 4.46s
# [334/500] TrainLoss: 0.005406  ValLoss: 0.005663  Val RMSE: 0.0753  Val NMSE: 0.1991  Val NMSE_dB: -7.008720 dB  TrainTime: 4.76s
# [335/500] TrainLoss: 0.005414  ValLoss: 0.005693  Val RMSE: 0.0754  Val NMSE: 0.2001  Val NMSE_dB: -6.987238 dB  TrainTime: 4.42s
# [336/500] TrainLoss: 0.005417  ValLoss: 0.005659  Val RMSE: 0.0752  Val NMSE: 0.1989  Val NMSE_dB: -7.013210 dB  TrainTime: 4.92s
# [337/500] TrainLoss: 0.005407  ValLoss: 0.005699  Val RMSE: 0.0755  Val NMSE: 0.1999  Val NMSE_dB: -6.991392 dB  TrainTime: 4.77s
# [338/500] TrainLoss: 0.005416  ValLoss: 0.005685  Val RMSE: 0.0754  Val NMSE: 0.1999  Val NMSE_dB: -6.991666 dB  TrainTime: 4.81s
# [339/500] TrainLoss: 0.005412  ValLoss: 0.005713  Val RMSE: 0.0756  Val NMSE: 0.2010  Val NMSE_dB: -6.968839 dB  TrainTime: 7.54s
# [340/500] TrainLoss: 0.005413  ValLoss: 0.005678  Val RMSE: 0.0753  Val NMSE: 0.1998  Val NMSE_dB: -6.994232 dB  TrainTime: 4.71s
# [341/500] TrainLoss: 0.005406  ValLoss: 0.005677  Val RMSE: 0.0753  Val NMSE: 0.1994  Val NMSE_dB: -7.002568 dB  TrainTime: 4.68s
# [342/500] TrainLoss: 0.005402  ValLoss: 0.005694  Val RMSE: 0.0755  Val NMSE: 0.2001  Val NMSE_dB: -6.987883 dB  TrainTime: 4.84s
# [343/500] TrainLoss: 0.005408  ValLoss: 0.005710  Val RMSE: 0.0756  Val NMSE: 0.2011  Val NMSE_dB: -6.966466 dB  TrainTime: 4.38s
# [344/500] TrainLoss: 0.005398  ValLoss: 0.005672  Val RMSE: 0.0753  Val NMSE: 0.1993  Val NMSE_dB: -7.005522 dB  TrainTime: 4.77s
# [345/500] TrainLoss: 0.005417  ValLoss: 0.005706  Val RMSE: 0.0755  Val NMSE: 0.2004  Val NMSE_dB: -6.980562 dB  TrainTime: 4.42s
# [346/500] TrainLoss: 0.005401  ValLoss: 0.005691  Val RMSE: 0.0754  Val NMSE: 0.1998  Val NMSE_dB: -6.994862 dB  TrainTime: 7.51s
# [347/500] TrainLoss: 0.005402  ValLoss: 0.005763  Val RMSE: 0.0759  Val NMSE: 0.2028  Val NMSE_dB: -6.929603 dB  TrainTime: 4.82s
# [348/500] TrainLoss: 0.005406  ValLoss: 0.005650  Val RMSE: 0.0752  Val NMSE: 0.1987  Val NMSE_dB: -7.017200 dB  TrainTime: 4.95s
# [349/500] TrainLoss: 0.005407  ValLoss: 0.005730  Val RMSE: 0.0757  Val NMSE: 0.2012  Val NMSE_dB: -6.963025 dB  TrainTime: 4.77s
# [350/500] TrainLoss: 0.005404  ValLoss: 0.005680  Val RMSE: 0.0754  Val NMSE: 0.1998  Val NMSE_dB: -6.994582 dB  TrainTime: 4.76s
# [351/500] TrainLoss: 0.005403  ValLoss: 0.005684  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.989027 dB  TrainTime: 4.65s
# [352/500] TrainLoss: 0.005407  ValLoss: 0.005674  Val RMSE: 0.0753  Val NMSE: 0.1994  Val NMSE_dB: -7.002933 dB  TrainTime: 4.48s
# [353/500] TrainLoss: 0.005407  ValLoss: 0.005677  Val RMSE: 0.0753  Val NMSE: 0.1996  Val NMSE_dB: -6.997611 dB  TrainTime: 7.52s
# [354/500] TrainLoss: 0.005394  ValLoss: 0.005692  Val RMSE: 0.0754  Val NMSE: 0.2000  Val NMSE_dB: -6.989760 dB  TrainTime: 4.94s
# [355/500] TrainLoss: 0.005402  ValLoss: 0.005683  Val RMSE: 0.0754  Val NMSE: 0.1999  Val NMSE_dB: -6.992148 dB  TrainTime: 4.27s
# [356/500] TrainLoss: 0.005395  ValLoss: 0.005722  Val RMSE: 0.0756  Val NMSE: 0.2012  Val NMSE_dB: -6.963156 dB  TrainTime: 4.73s
# [357/500] TrainLoss: 0.005401  ValLoss: 0.005698  Val RMSE: 0.0755  Val NMSE: 0.2001  Val NMSE_dB: -6.987361 dB  TrainTime: 4.71s
# [358/500] TrainLoss: 0.005395  ValLoss: 0.005727  Val RMSE: 0.0757  Val NMSE: 0.2013  Val NMSE_dB: -6.962040 dB  TrainTime: 4.34s
# [359/500] TrainLoss: 0.005409  ValLoss: 0.005657  Val RMSE: 0.0752  Val NMSE: 0.1988  Val NMSE_dB: -7.015755 dB  TrainTime: 4.89s
# [360/500] TrainLoss: 0.005398  ValLoss: 0.005682  Val RMSE: 0.0754  Val NMSE: 0.1998  Val NMSE_dB: -6.993647 dB  TrainTime: 7.55s
# [361/500] TrainLoss: 0.005404  ValLoss: 0.005674  Val RMSE: 0.0753  Val NMSE: 0.1993  Val NMSE_dB: -7.004814 dB  TrainTime: 4.99s
# [362/500] TrainLoss: 0.005396  ValLoss: 0.005700  Val RMSE: 0.0755  Val NMSE: 0.2001  Val NMSE_dB: -6.986685 dB  TrainTime: 4.63s
# [363/500] TrainLoss: 0.005401  ValLoss: 0.005669  Val RMSE: 0.0753  Val NMSE: 0.1992  Val NMSE_dB: -7.007250 dB  TrainTime: 4.64s
# [364/500] TrainLoss: 0.005395  ValLoss: 0.005719  Val RMSE: 0.0756  Val NMSE: 0.2010  Val NMSE_dB: -6.968998 dB  TrainTime: 4.41s
# [365/500] TrainLoss: 0.005400  ValLoss: 0.005724  Val RMSE: 0.0757  Val NMSE: 0.2011  Val NMSE_dB: -6.965254 dB  TrainTime: 4.81s
# [366/500] TrainLoss: 0.005403  ValLoss: 0.005676  Val RMSE: 0.0753  Val NMSE: 0.1995  Val NMSE_dB: -7.000575 dB  TrainTime: 4.51s
# [367/500] TrainLoss: 0.005402  ValLoss: 0.005660  Val RMSE: 0.0752  Val NMSE: 0.1990  Val NMSE_dB: -7.010814 dB  TrainTime: 7.91s
# [368/500] TrainLoss: 0.005391  ValLoss: 0.005665  Val RMSE: 0.0753  Val NMSE: 0.1994  Val NMSE_dB: -7.002113 dB  TrainTime: 4.54s
# [369/500] TrainLoss: 0.005400  ValLoss: 0.005726  Val RMSE: 0.0757  Val NMSE: 0.2013  Val NMSE_dB: -6.961226 dB  TrainTime: 4.99s
# ...
# [426/500] TrainLoss: 0.005009  ValLoss: 0.005769  Val RMSE: 0.0760  Val NMSE: 0.2028  Val NMSE_dB: -6.930285 dB  TrainTime: 5.23s
# [427/500] TrainLoss: 0.005009  ValLoss: 0.005805  Val RMSE: 0.0762  Val NMSE: 0.2040  Val NMSE_dB: -6.903081 dB  TrainTime: 5.20s
# [428/500] TrainLoss: 0.005012  ValLoss: 0.005811  Val RMSE: 0.0762  Val NMSE: 0.2041  Val NMSE_dB: -6.902190 dB  TrainTime: 5.10s
# [429/500] TrainLoss: 0.005008  ValLoss: 0.005770  Val RMSE: 0.0760  Val NMSE: 0.2026  Val NMSE_dB: -6.932961 dB  TrainTime: 5.37s
# [430/500] TrainLoss: 0.005006  ValLoss: 0.005844  Val RMSE: 0.0764  Val NMSE: 0.2056  Val NMSE_dB: -6.868748 dB  TrainTime: 7.28s
# [431/500] TrainLoss: 0.005015  ValLoss: 0.005794  Val RMSE: 0.0761  Val NMSE: 0.2038  Val NMSE_dB: -6.907507 dB  TrainTime: 5.23s
# [432/500] TrainLoss: 0.005016  ValLoss: 0.005815  Val RMSE: 0.0763  Val NMSE: 0.2045  Val NMSE_dB: -6.892553 dB  TrainTime: 5.09s
# [433/500] TrainLoss: 0.005003  ValLoss: 0.005781  Val RMSE: 0.0760  Val NMSE: 0.2031  Val NMSE_dB: -6.922875 dB  TrainTime: 5.15s
# [434/500] TrainLoss: 0.005002  ValLoss: 0.005913  Val RMSE: 0.0769  Val NMSE: 0.2077  Val NMSE_dB: -6.826266 dB  TrainTime: 5.49s
# [435/500] TrainLoss: 0.005003  ValLoss: 0.005789  Val RMSE: 0.0761  Val NMSE: 0.2036  Val NMSE_dB: -6.912165 dB  TrainTime: 5.23s
# [436/500] TrainLoss: 0.005013  ValLoss: 0.005844  Val RMSE: 0.0764  Val NMSE: 0.2057  Val NMSE_dB: -6.867464 dB  TrainTime: 7.54s
# [437/500] TrainLoss: 0.005005  ValLoss: 0.005769  Val RMSE: 0.0760  Val NMSE: 0.2028  Val NMSE_dB: -6.929547 dB  TrainTime: 5.37s
# [438/500] TrainLoss: 0.004998  ValLoss: 0.005882  Val RMSE: 0.0767  Val NMSE: 0.2068  Val NMSE_dB: -6.845002 dB  TrainTime: 5.26s
# [439/500] TrainLoss: 0.005013  ValLoss: 0.005929  Val RMSE: 0.0770  Val NMSE: 0.2086  Val NMSE_dB: -6.806151 dB  TrainTime: 5.45s
# [440/500] TrainLoss: 0.005010  ValLoss: 0.005933  Val RMSE: 0.0770  Val NMSE: 0.2090  Val NMSE_dB: -6.799452 dB  TrainTime: 4.98s
# [441/500] TrainLoss: 0.005007  ValLoss: 0.005814  Val RMSE: 0.0762  Val NMSE: 0.2045  Val NMSE_dB: -6.892256 dB  TrainTime: 5.17s
# [442/500] TrainLoss: 0.004998  ValLoss: 0.005758  Val RMSE: 0.0759  Val NMSE: 0.2024  Val NMSE_dB: -6.938581 dB  TrainTime: 7.90s
# [443/500] TrainLoss: 0.005005  ValLoss: 0.005806  Val RMSE: 0.0762  Val NMSE: 0.2039  Val NMSE_dB: -6.906380 dB  TrainTime: 5.27s
# [444/500] TrainLoss: 0.005007  ValLoss: 0.005811  Val RMSE: 0.0762  Val NMSE: 0.2044  Val NMSE_dB: -6.895036 dB  TrainTime: 5.45s
# [445/500] TrainLoss: 0.004998  ValLoss: 0.005800  Val RMSE: 0.0762  Val NMSE: 0.2042  Val NMSE_dB: -6.899950 dB  TrainTime: 5.37s
# [446/500] TrainLoss: 0.005013  ValLoss: 0.005763  Val RMSE: 0.0759  Val NMSE: 0.2026  Val NMSE_dB: -6.934304 dB  TrainTime: 5.23s
# [447/500] TrainLoss: 0.004992  ValLoss: 0.005939  Val RMSE: 0.0771  Val NMSE: 0.2090  Val NMSE_dB: -6.799048 dB  TrainTime: 5.38s
# [448/500] TrainLoss: 0.004998  ValLoss: 0.005816  Val RMSE: 0.0763  Val NMSE: 0.2043  Val NMSE_dB: -6.897784 dB  TrainTime: 7.57s
# [449/500] TrainLoss: 0.005001  ValLoss: 0.005923  Val RMSE: 0.0770  Val NMSE: 0.2085  Val NMSE_dB: -6.807952 dB  TrainTime: 5.63s
# [450/500] TrainLoss: 0.005004  ValLoss: 0.005874  Val RMSE: 0.0766  Val NMSE: 0.2066  Val NMSE_dB: -6.848779 dB  TrainTime: 5.42s
# [451/500] TrainLoss: 0.005002  ValLoss: 0.005802  Val RMSE: 0.0762  Val NMSE: 0.2039  Val NMSE_dB: -6.906315 dB  TrainTime: 5.24s
# [452/500] TrainLoss: 0.005003  ValLoss: 0.005809  Val RMSE: 0.0762  Val NMSE: 0.2045  Val NMSE_dB: -6.893101 dB  TrainTime: 5.47s
# [453/500] TrainLoss: 0.004996  ValLoss: 0.005776  Val RMSE: 0.0760  Val NMSE: 0.2029  Val NMSE_dB: -6.927833 dB  TrainTime: 5.49s
# [454/500] TrainLoss: 0.004994  ValLoss: 0.005765  Val RMSE: 0.0759  Val NMSE: 0.2025  Val NMSE_dB: -6.935769 dB  TrainTime: 7.52s
# [455/500] TrainLoss: 0.005002  ValLoss: 0.005888  Val RMSE: 0.0767  Val NMSE: 0.2072  Val NMSE_dB: -6.835175 dB  TrainTime: 5.28s
# [456/500] TrainLoss: 0.005008  ValLoss: 0.005782  Val RMSE: 0.0760  Val NMSE: 0.2032  Val NMSE_dB: -6.921792 dB  TrainTime: 5.31s
# [457/500] TrainLoss: 0.005009  ValLoss: 0.006002  Val RMSE: 0.0775  Val NMSE: 0.2110  Val NMSE_dB: -6.757510 dB  TrainTime: 5.13s
# [458/500] TrainLoss: 0.005004  ValLoss: 0.005766  Val RMSE: 0.0759  Val NMSE: 0.2027  Val NMSE_dB: -6.931388 dB  TrainTime: 5.25s
# [459/500] TrainLoss: 0.004998  ValLoss: 0.005830  Val RMSE: 0.0764  Val NMSE: 0.2051  Val NMSE_dB: -6.879629 dB  TrainTime: 5.26s
# [460/500] TrainLoss: 0.004996  ValLoss: 0.005848  Val RMSE: 0.0765  Val NMSE: 0.2060  Val NMSE_dB: -6.860540 dB  TrainTime: 7.44s
# [461/500] TrainLoss: 0.005001  ValLoss: 0.005783  Val RMSE: 0.0760  Val NMSE: 0.2033  Val NMSE_dB: -6.918049 dB  TrainTime: 5.15s
# [462/500] TrainLoss: 0.004989  ValLoss: 0.005789  Val RMSE: 0.0761  Val NMSE: 0.2036  Val NMSE_dB: -6.911228 dB  TrainTime: 5.35s
# [463/500] TrainLoss: 0.004996  ValLoss: 0.005785  Val RMSE: 0.0761  Val NMSE: 0.2030  Val NMSE_dB: -6.924305 dB  TrainTime: 5.12s
# [464/500] TrainLoss: 0.005010  ValLoss: 0.005797  Val RMSE: 0.0761  Val NMSE: 0.2036  Val NMSE_dB: -6.912194 dB  TrainTime: 5.30s
# [465/500] TrainLoss: 0.004984  ValLoss: 0.005841  Val RMSE: 0.0764  Val NMSE: 0.2051  Val NMSE_dB: -6.881056 dB  TrainTime: 5.23s
# [466/500] TrainLoss: 0.005005  ValLoss: 0.005828  Val RMSE: 0.0763  Val NMSE: 0.2048  Val NMSE_dB: -6.886295 dB  TrainTime: 7.42s
# [467/500] TrainLoss: 0.004997  ValLoss: 0.005788  Val RMSE: 0.0761  Val NMSE: 0.2035  Val NMSE_dB: -6.914559 dB  TrainTime: 5.09s
# [468/500] TrainLoss: 0.004992  ValLoss: 0.005898  Val RMSE: 0.0768  Val NMSE: 0.2074  Val NMSE_dB: -6.831839 dB  TrainTime: 5.08s
# [469/500] TrainLoss: 0.004996  ValLoss: 0.005823  Val RMSE: 0.0763  Val NMSE: 0.2049  Val NMSE_dB: -6.885625 dB  TrainTime: 5.36s
# [470/500] TrainLoss: 0.004997  ValLoss: 0.005833  Val RMSE: 0.0764  Val NMSE: 0.2051  Val NMSE_dB: -6.879976 dB  TrainTime: 4.90s
# [471/500] TrainLoss: 0.004996  ValLoss: 0.005827  Val RMSE: 0.0763  Val NMSE: 0.2049  Val NMSE_dB: -6.885187 dB  TrainTime: 5.54s
# [472/500] TrainLoss: 0.004992  ValLoss: 0.005855  Val RMSE: 0.0765  Val NMSE: 0.2062  Val NMSE_dB: -6.857601 dB  TrainTime: 5.05s
# [473/500] TrainLoss: 0.004994  ValLoss: 0.005802  Val RMSE: 0.0762  Val NMSE: 0.2041  Val NMSE_dB: -6.901107 dB  TrainTime: 7.03s
# [474/500] TrainLoss: 0.004993  ValLoss: 0.005788  Val RMSE: 0.0761  Val NMSE: 0.2035  Val NMSE_dB: -6.913734 dB  TrainTime: 5.22s
# [475/500] TrainLoss: 0.004991  ValLoss: 0.006112  Val RMSE: 0.0782  Val NMSE: 0.2151  Val NMSE_dB: -6.674442 dB  TrainTime: 5.17s
# [476/500] TrainLoss: 0.004992  ValLoss: 0.005814  Val RMSE: 0.0763  Val NMSE: 0.2045  Val NMSE_dB: -6.892446 dB  TrainTime: 5.27s
# [477/500] TrainLoss: 0.004991  ValLoss: 0.005782  Val RMSE: 0.0760  Val NMSE: 0.2034  Val NMSE_dB: -6.917362 dB  TrainTime: 4.90s
# [478/500] TrainLoss: 0.004993  ValLoss: 0.005821  Val RMSE: 0.0763  Val NMSE: 0.2045  Val NMSE_dB: -6.892514 dB  TrainTime: 5.12s
# [479/500] TrainLoss: 0.004991  ValLoss: 0.005840  Val RMSE: 0.0764  Val NMSE: 0.2053  Val NMSE_dB: -6.876814 dB  TrainTime: 7.58s
# [480/500] TrainLoss: 0.004986  ValLoss: 0.005771  Val RMSE: 0.0760  Val NMSE: 0.2029  Val NMSE_dB: -6.928231 dB  TrainTime: 5.10s
# [481/500] TrainLoss: 0.005007  ValLoss: 0.005856  Val RMSE: 0.0765  Val NMSE: 0.2059  Val NMSE_dB: -6.862535 dB  TrainTime: 5.27s
# [482/500] TrainLoss: 0.004988  ValLoss: 0.005922  Val RMSE: 0.0770  Val NMSE: 0.2085  Val NMSE_dB: -6.809061 dB  TrainTime: 5.35s
# [483/500] TrainLoss: 0.004978  ValLoss: 0.005823  Val RMSE: 0.0763  Val NMSE: 0.2049  Val NMSE_dB: -6.883960 dB  TrainTime: 5.22s
# [484/500] TrainLoss: 0.004987  ValLoss: 0.005814  Val RMSE: 0.0763  Val NMSE: 0.2045  Val NMSE_dB: -6.892980 dB  TrainTime: 5.10s
# [485/500] TrainLoss: 0.004995  ValLoss: 0.005784  Val RMSE: 0.0760  Val NMSE: 0.2033  Val NMSE_dB: -6.918931 dB  TrainTime: 7.26s
# [486/500] TrainLoss: 0.004996  ValLoss: 0.005813  Val RMSE: 0.0762  Val NMSE: 0.2045  Val NMSE_dB: -6.893776 dB  TrainTime: 5.08s
# [487/500] TrainLoss: 0.004984  ValLoss: 0.005898  Val RMSE: 0.0768  Val NMSE: 0.2073  Val NMSE_dB: -6.833117 dB  TrainTime: 5.22s
# [488/500] TrainLoss: 0.004984  ValLoss: 0.005924  Val RMSE: 0.0770  Val NMSE: 0.2082  Val NMSE_dB: -6.816060 dB  TrainTime: 4.87s
# [489/500] TrainLoss: 0.004999  ValLoss: 0.005810  Val RMSE: 0.0762  Val NMSE: 0.2041  Val NMSE_dB: -6.901923 dB  TrainTime: 5.30s
# [490/500] TrainLoss: 0.004991  ValLoss: 0.005768  Val RMSE: 0.0760  Val NMSE: 0.2029  Val NMSE_dB: -6.926196 dB  TrainTime: 5.14s
# [491/500] TrainLoss: 0.004980  ValLoss: 0.006005  Val RMSE: 0.0775  Val NMSE: 0.2113  Val NMSE_dB: -6.750947 dB  TrainTime: 5.28s
# [492/500] TrainLoss: 0.004985  ValLoss: 0.005916  Val RMSE: 0.0769  Val NMSE: 0.2078  Val NMSE_dB: -6.824530 dB  TrainTime: 7.23s
# [493/500] TrainLoss: 0.004988  ValLoss: 0.005783  Val RMSE: 0.0760  Val NMSE: 0.2033  Val NMSE_dB: -6.918029 dB  TrainTime: 5.27s
# [494/500] TrainLoss: 0.004982  ValLoss: 0.005823  Val RMSE: 0.0763  Val NMSE: 0.2047  Val NMSE_dB: -6.887807 dB  TrainTime: 5.09s
# [495/500] TrainLoss: 0.004988  ValLoss: 0.005863  Val RMSE: 0.0766  Val NMSE: 0.2063  Val NMSE_dB: -6.854692 dB  TrainTime: 5.21s
# [496/500] TrainLoss: 0.004987  ValLoss: 0.005786  Val RMSE: 0.0761  Val NMSE: 0.2036  Val NMSE_dB: -6.911627 dB  TrainTime: 4.97s
# [497/500] TrainLoss: 0.004984  ValLoss: 0.005855  Val RMSE: 0.0765  Val NMSE: 0.2060  Val NMSE_dB: -6.860341 dB  TrainTime: 5.10s
# [498/500] TrainLoss: 0.004981  ValLoss: 0.005826  Val RMSE: 0.0763  Val NMSE: 0.2049  Val NMSE_dB: -6.884846 dB  TrainTime: 7.37s
# [499/500] TrainLoss: 0.004979  ValLoss: 0.005810  Val RMSE: 0.0762  Val NMSE: 0.2042  Val NMSE_dB: -6.898869 dB  TrainTime: 5.25s
# [500/500] TrainLoss: 0.004977  ValLoss: 0.005857  Val RMSE: 0.0765  Val NMSE: 0.2057  Val NMSE_dB: -6.868076 dB  TrainTime: 5.11s
# ============================================================
# => Best ValLoss   : 0.005717   (epoch 183)
# => Best Val NMSE  : 0.2012   (epoch 183)
# => Best Val RMSE  : 0.0756   (epoch 183)
# => Best Val NMSE_dB: -6.9635 dB (epoch 183)
# ============================================================
#
# CNN training log saved to /home/dlghdbs200/LWM_denver/CNN_epoch500_antenna.txt
#
# === LWM Training ===
# === Training LWM ===
# [01/500] TrainLoss: 0.031527  ValLoss: 0.019676  Val RMSE: 0.1403  Val NMSE: 0.6711  Val NMSE_dB: -1.731929 dB  TrainTime: 27.42s
# [02/500] TrainLoss: 0.012847  ValLoss: 0.008323  Val RMSE: 0.0912  Val NMSE: 0.2947  Val NMSE_dB: -5.306591 dB  TrainTime: 24.87s
# [03/500] TrainLoss: 0.007920  ValLoss: 0.007144  Val RMSE: 0.0845  Val NMSE: 0.2512  Val NMSE_dB: -5.999048 dB  TrainTime: 28.04s
# [04/500] TrainLoss: 0.007283  ValLoss: 0.006721  Val RMSE: 0.0820  Val NMSE: 0.2358  Val NMSE_dB: -6.274716 dB  TrainTime: 27.54s
# [05/500] TrainLoss: 0.006926  ValLoss: 0.006867  Val RMSE: 0.0829  Val NMSE: 0.2447  Val NMSE_dB: -6.113956 dB  TrainTime: 27.41s
# [06/500] TrainLoss: 0.006707  ValLoss: 0.006660  Val RMSE: 0.0816  Val NMSE: 0.2347  Val NMSE_dB: -6.295539 dB  TrainTime: 27.50s
# [07/500] TrainLoss: 0.006568  ValLoss: 0.006612  Val RMSE: 0.0813  Val NMSE: 0.2340  Val NMSE_dB: -6.307384 dB  TrainTime: 25.80s
# [08/500] TrainLoss: 0.006427  ValLoss: 0.006860  Val RMSE: 0.0828  Val NMSE: 0.2443  Val NMSE_dB: -6.120538 dB  TrainTime: 27.72s
# [09/500] TrainLoss: 0.006331  ValLoss: 0.006174  Val RMSE: 0.0786  Val NMSE: 0.2178  Val NMSE_dB: -6.618596 dB  TrainTime: 28.50s
# [10/500] TrainLoss: 0.006237  ValLoss: 0.006210  Val RMSE: 0.0788  Val NMSE: 0.2195  Val NMSE_dB: -6.584749 dB  TrainTime: 29.04s
# [11/500] TrainLoss: 0.006162  ValLoss: 0.006382  Val RMSE: 0.0799  Val NMSE: 0.2250  Val NMSE_dB: -6.477479 dB  TrainTime: 28.13s
# [12/500] TrainLoss: 0.006112  ValLoss: 0.006164  Val RMSE: 0.0785  Val NMSE: 0.2178  Val NMSE_dB: -6.619332 dB  TrainTime: 27.03s
# [13/500] TrainLoss: 0.006026  ValLoss: 0.006106  Val RMSE: 0.0781  Val NMSE: 0.2146  Val NMSE_dB: -6.683236 dB  TrainTime: 27.86s
# [14/500] TrainLoss: 0.005999  ValLoss: 0.006400  Val RMSE: 0.0800  Val NMSE: 0.2272  Val NMSE_dB: -6.436242 dB  TrainTime: 28.63s
# [15/500] TrainLoss: 0.005940  ValLoss: 0.006247  Val RMSE: 0.0790  Val NMSE: 0.2206  Val NMSE_dB: -6.563534 dB  TrainTime: 27.73s
# [16/500] TrainLoss: 0.005905  ValLoss: 0.005973  Val RMSE: 0.0773  Val NMSE: 0.2102  Val NMSE_dB: -6.773768 dB  TrainTime: 27.81s
# [17/500] TrainLoss: 0.005901  ValLoss: 0.005983  Val RMSE: 0.0774  Val NMSE: 0.2095  Val NMSE_dB: -6.787456 dB  TrainTime: 26.61s
# [18/500] TrainLoss: 0.005835  ValLoss: 0.006214  Val RMSE: 0.0788  Val NMSE: 0.2198  Val NMSE_dB: -6.579735 dB  TrainTime: 27.51s
# [19/500] TrainLoss: 0.005833  ValLoss: 0.006651  Val RMSE: 0.0816  Val NMSE: 0.2378  Val NMSE_dB: -6.238710 dB  TrainTime: 27.92s
# [20/500] TrainLoss: 0.005811  ValLoss: 0.006290  Val RMSE: 0.0793  Val NMSE: 0.2225  Val NMSE_dB: -6.525898 dB  TrainTime: 29.27s
# [21/500] TrainLoss: 0.005764  ValLoss: 0.005940  Val RMSE: 0.0771  Val NMSE: 0.2092  Val NMSE_dB: -6.794096 dB  TrainTime: 30.01s
# [22/500] TrainLoss: 0.005748  ValLoss: 0.006331  Val RMSE: 0.0796  Val NMSE: 0.2245  Val NMSE_dB: -6.487457 dB  TrainTime: 28.95s
# [23/500] TrainLoss: 0.005701  ValLoss: 0.005906  Val RMSE: 0.0768  Val NMSE: 0.2073  Val NMSE_dB: -6.833122 dB  TrainTime: 28.00s
# [24/500] TrainLoss: 0.005698  ValLoss: 0.005972  Val RMSE: 0.0773  Val NMSE: 0.2106  Val NMSE_dB: -6.766421 dB  TrainTime: 27.01s
# [25/500] TrainLoss: 0.005663  ValLoss: 0.005947  Val RMSE: 0.0771  Val NMSE: 0.2092  Val NMSE_dB: -6.795402 dB  TrainTime: 27.49s
# [26/500] TrainLoss: 0.005639  ValLoss: 0.006060  Val RMSE: 0.0778  Val NMSE: 0.2141  Val NMSE_dB: -6.693051 dB  TrainTime: 27.32s
# [27/500] TrainLoss: 0.005623  ValLoss: 0.005805  Val RMSE: 0.0762  Val NMSE: 0.2040  Val NMSE_dB: -6.903587 dB  TrainTime: 27.75s
# [28/500] TrainLoss: 0.005618  ValLoss: 0.006075  Val RMSE: 0.0779  Val NMSE: 0.2139  Val NMSE_dB: -6.697381 dB  TrainTime: 27.57s
# [29/500] TrainLoss: 0.005568  ValLoss: 0.006048  Val RMSE: 0.0778  Val NMSE: 0.2127  Val NMSE_dB: -6.722615 dB  TrainTime: 27.66s
# [30/500] TrainLoss: 0.005553  ValLoss: 0.005844  Val RMSE: 0.0764  Val NMSE: 0.2047  Val NMSE_dB: -6.888905 dB  TrainTime: 26.98s
# [31/500] TrainLoss: 0.005549  ValLoss: 0.006001  Val RMSE: 0.0775  Val NMSE: 0.2116  Val NMSE_dB: -6.744544 dB  TrainTime: 27.45s
# [32/500] TrainLoss: 0.005520  ValLoss: 0.006142  Val RMSE: 0.0784  Val NMSE: 0.2160  Val NMSE_dB: -6.654513 dB  TrainTime: 27.39s
# [33/500] TrainLoss: 0.005491  ValLoss: 0.005986  Val RMSE: 0.0774  Val NMSE: 0.2107  Val NMSE_dB: -6.763790 dB  TrainTime: 27.57s
# [34/500] TrainLoss: 0.005478  ValLoss: 0.005815  Val RMSE: 0.0763  Val NMSE: 0.2044  Val NMSE_dB: -6.894591 dB  TrainTime: 27.51s
# [35/500] TrainLoss: 0.005462  ValLoss: 0.005857  Val RMSE: 0.0765  Val NMSE: 0.2059  Val NMSE_dB: -6.863627 dB  TrainTime: 27.54s
# [36/500] TrainLoss: 0.005435  ValLoss: 0.005955  Val RMSE: 0.0772  Val NMSE: 0.2094  Val NMSE_dB: -6.791134 dB  TrainTime: 27.51s
# [37/500] TrainLoss: 0.005411  ValLoss: 0.005820  Val RMSE: 0.0763  Val NMSE: 0.2045  Val NMSE_dB: -6.892191 dB  TrainTime: 27.60s
# [38/500] TrainLoss: 0.005398  ValLoss: 0.005918  Val RMSE: 0.0769  Val NMSE: 0.2086  Val NMSE_dB: -6.806626 dB  TrainTime: 26.98s
# [39/500] TrainLoss: 0.005381  ValLoss: 0.005892  Val RMSE: 0.0768  Val NMSE: 0.2075  Val NMSE_dB: -6.829636 dB  TrainTime: 27.97s
# [40/500] TrainLoss: 0.005369  ValLoss: 0.005819  Val RMSE: 0.0763  Val NMSE: 0.2040  Val NMSE_dB: -6.904195 dB  TrainTime: 27.82s
# [41/500] TrainLoss: 0.005376  ValLoss: 0.005908  Val RMSE: 0.0769  Val NMSE: 0.2079  Val NMSE_dB: -6.820852 dB  TrainTime: 28.09s
# [42/500] TrainLoss: 0.005335  ValLoss: 0.005984  Val RMSE: 0.0774  Val NMSE: 0.2109  Val NMSE_dB: -6.759173 dB  TrainTime: 27.94s
# [43/500] TrainLoss: 0.005313  ValLoss: 0.006253  Val RMSE: 0.0791  Val NMSE: 0.2223  Val NMSE_dB: -6.530261 dB  TrainTime: 27.66s
# [44/500] TrainLoss: 0.005307  ValLoss: 0.005902  Val RMSE: 0.0768  Val NMSE: 0.2075  Val NMSE_dB: -6.830009 dB  TrainTime: 28.78s

# %% [markdown]
# # inference time
